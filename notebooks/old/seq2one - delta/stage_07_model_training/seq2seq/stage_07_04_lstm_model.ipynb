# %% [markdown]
# <a href="https://colab.research.google.com/github/GUNAPILLCO/neural_profit/blob/main/notebooks/stage_07_model_training/stage_07_04_lstm_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Stage_07_04 - LSTM (Seq2Seq)**

# %% [markdown]
# ## **Introducción**

# %% [markdown]
# Este notebook introduce el modelo **Encoder–Decoder LSTM** aplicado a la predicción seq2seq intradía del índice MNQ.
#
# El enfoque LSTM sigue una estructura clásica **seq2seq**:
# el **encoder** resume la información histórica contenida en la ventana de entrada, mientras que el **decoder** genera la secuencia futura completa de retornos. A diferencia del MLP, el LSTM incorpora memoria temporal explícita, lo que le permite modelar dependencias dinámicas dentro de la serie.
#
# En el contexto intradía, los modelos LSTM son una referencia estándar por su estabilidad y capacidad para capturar patrones temporales, pero presentan un **riesgo elevado de sobreajuste** debido a su alta capacidad y memoria de largo plazo.
#
# Por este motivo, su uso requiere una **regularización cuidadosa**, basada en:
# - **Early stopping obligatorio** como principal mecanismo de control.
# - **Dropout en entradas y salidas** (evitando dropout recurrente).
# - **Tamaño moderado del estado oculto**.
# - **Número limitado de capas**.
# - **Penalización L2 suave** en los pesos (opcional).
#
# Siguiendo el marco del libro, el LSTM se interpreta como un **modelo potente pero sensible**, que solo generaliza correctamente cuando se restringe su capacidad y se respeta estrictamente la validación fuera de muestra (VALID ONLY).
#
# En los siguientes pasos se define, entrena y evalúa el modelo LSTM bajo el mismo esquema experimental utilizado para MLP y GRU, permitiendo una comparación directa y coherente entre arquitecturas.

# %% [markdown]
# ## **1. Imports + paths**

# %%
# Permite anotaciones modernas en Python < 3.11.
from __future__ import annotations

import os
import json
import time
import random
from pathlib import Path
import numpy as np

import numpy as np
from typing import Any, Dict, List, Iterable, Tuple
# Si usa sklearn en algún modelo/baseline
# from sklearn.linear_model import Ridge

# Dataclass: contenedor simple e inmutable para configuración.
from dataclasses import dataclass
# Joblib para cargar scalers .pkl (sklearn).
import joblib

from pathlib import Path
import sys
import importlib

# %%
# ---------------------------------------------------------------------
# Configuración de rutas (DVC-friendly)
# ---------------------------------------------------------------------
# Estas rutas son RELATIVAS al repositorio.
# DVC necesita paths locales y determinísticos.
# Si mañana quiere apuntar a Drive, se hace vía DVC remote o symlink,
# NO cambiando la lógica del stage.

# PARA EL DVC:

#VENTANAS 60MIN
IN_WINDOW_TRAIN_60_Z = Path(os.environ.get("IN_WINDOW_TRAIN_60_Z", "data/windows/scaled/windows_train_60_z.npz"))
IN_WINDOW_VALID_60_Z = Path(os.environ.get("IN_WINDOW_VALID_60_Z", "data/windows/scaled/windows_valid_60_z.npz"))
IN_WINDOW_TEST_60_Z = Path(os.environ.get("IN_WINDOW_TEST_60_Z", "data/windows/scaled/windows_test_60_z.npz"))
IN_SCALER_60 = Path(os.environ.get("IN_SCALER_60", "data/windows/scaled/scaler_60.pkl"))

#VENTANAS 90MIN
IN_WINDOW_TRAIN_90_Z = Path(os.environ.get("IN_WINDOW_TRAIN_90_Z", "data/windows/scaled/windows_train_90_z.npz"))
IN_WINDOW_VALID_90_Z = Path(os.environ.get("IN_WINDOW_VALID_90_Z", "data/windows/scaled/windows_valid_90_z.npz"))
IN_WINDOW_TEST_90_Z = Path(os.environ.get("IN_WINDOW_TEST_90_Z", "data/windows/scaled/windows_test_90_z.npz"))
IN_SCALER_90 = Path(os.environ.get("IN_SCALER_90", "data/windows/scaled/scaler_90.pkl"))

#ARTIFACTS

# Summary del stage_03a (donde está delta_target_p70 por horizonte).
IN_TARGET_INVESTIGATION_SUMMARY = Path(os.environ.get("IN_TARGET_INVESTIGATION_SUMMARY", "reports/stage_03a_target_investigation_summary.json"))

# Summary del stage_06 (donde está window_size y n_features por horizonte).
IN_WINDOWS_SCALING_SUMMARY =Path(os.environ.get("IN_WINDOWS_SCALING_SUMMARY", "reports/stage_06_window_scaling_seq2seq_summary.json"))

#OUT_MODEL_METRICS = Path(os.environ.get("OUT_MODEL_METRICS", f"reports/stage_07__model_metrics.json"))

# %%
from google.colab import drive
drive.mount('/content/drive')

# --------------------------------------------------
# Ruta base en Google Drive
# --------------------------------------------------
# Ajuste si su estructura cambia
DRIVE_DIR =   Path(os.environ.get("DRIVE_DIR", "/content/drive/MyDrive/neural_profit/"))
# Out:
# Mounted at /content/drive

# %%
#PARA LA NOTEBOOK
IN_WINDOW_TRAIN_60_Z = DRIVE_DIR / IN_WINDOW_TRAIN_60_Z
IN_WINDOW_VALID_60_Z = DRIVE_DIR / IN_WINDOW_VALID_60_Z
IN_WINDOW_TEST_60_Z = DRIVE_DIR / IN_WINDOW_TEST_60_Z
IN_SCALER_60 = DRIVE_DIR / IN_SCALER_60

IN_WINDOW_TRAIN_90_Z = DRIVE_DIR / IN_WINDOW_TRAIN_90_Z
IN_WINDOW_VALID_90_Z=DRIVE_DIR / IN_WINDOW_VALID_90_Z
IN_WINDOW_TEST_90_Z = DRIVE_DIR / IN_WINDOW_TEST_90_Z
IN_SCALER_90 = DRIVE_DIR / IN_SCALER_90

IN_WINDOWS_SCALING_SUMMARY = DRIVE_DIR / IN_WINDOWS_SCALING_SUMMARY
IN_TARGET_INVESTIGATION_SUMMARY = DRIVE_DIR / IN_TARGET_INVESTIGATION_SUMMARY

# %% [markdown]
# ## **2. Reproducibilidad**

# %%
def set_seeds(seed: int = 42) -> None:
    random.seed(seed)
    np.random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)

set_seeds(42)

# %% [markdown]
# ## **3. Configuración**

# %%
def _read_json(path: Path) -> Dict[str, Any]:
    """Lee un JSON y devuelve un dict Python (con validación básica de existencia)."""
    # Verifica que el archivo exista antes de abrirlo.
    if not path.exists():
        # Si no existe, corta la ejecución con un error claro.
        raise FileNotFoundError(f"No existe el JSON: {path}")
    # Abre el archivo en modo lectura, asegurando UTF-8.
    with path.open("r", encoding="utf-8") as f:
        # Parsea el contenido JSON y lo devuelve como dict.
        return json.load(f)

# %%
# Config final para entrenar (modelo, horizonte).
@dataclass(frozen=True)
class StageConfig:
    # Horizonte (60 o 90).
    horizon: int
    # Largo de ventana (timesteps) desde stage_06.
    seq_len: int
    # Cantidad de features desde stage_06 para ese horizonte.
    n_features: int
    # Nombres de features (orden exacto) para ese horizonte.
    feature_names: List[str]
    # Nombre del target para ese horizonte.
    target_name: List[str]
    # Umbral mínimo económico (DELTA_BASE).
    delta_base: float
    # Umbral de oportunidad (DELTA_OP) leído del stage_03a.
    delta_op: float

# %%
# Construye un StageConfig leyendo ambos reports.
def load_state_from_reports(
    horizon: int,
    #model_name: str,
    *,
    in_windows_scaling_summary: Path = IN_WINDOWS_SCALING_SUMMARY,
    in_target_investigation_summary: Path = IN_TARGET_INVESTIGATION_SUMMARY,
) -> StageConfig:
    # Valida horizonte permitido.
    if horizon not in (60, 90):
        raise ValueError("horizon debe ser 60 o 90")

    # Carga JSON del stage_06.
    w = _read_json(in_windows_scaling_summary)

    # Carga JSON del stage_03a.
    t = _read_json(in_target_investigation_summary)

    # Lee window_size global (SEQ_LEN).
    seq_len = int(w["details"]["config"]["window_size"])

    # Selecciona dataset del horizonte (ojo: "60" o "90" como string).
    ds = w["details"]["datasets"][str(horizon)]

    # Lee n_features del horizonte.
    n_features = int(ds["n_features"])

    # Lee feature_names del horizonte (aquí se refleja el 1 feature distinto).
    feature_names = list(ds["feature_names"])

    # Lee target del horizonte.
    target_name = ds["target"]

    # Valida consistencia.
    if len(feature_names) != n_features:
        raise ValueError("Inconsistencia entre n_features y feature_names")

    # Define la key de delta_base_med del stage_03a.
    target_base = f"h{horizon}_delta_base_med"
    delta_base = float(t["metrics"][target_base])

    # Define la key de delta_target_p70 del stage_03a.
    target_op = f"h{horizon}_delta_target_p70"
    # Lee DELTA_OP para ese horizonte.
    delta_op = float(t["metrics"][target_op])

    # Devuelve la config lista para entrenar.
    return StageConfig(
        horizon=horizon,
        seq_len=seq_len,
        n_features=n_features,
        feature_names=feature_names,
        target_name=target_name,
        delta_base=float(delta_base),
        delta_op=float(delta_op),
            )

# %%
states_h60 = load_state_from_reports(horizon=60)
states_h60
# Out:
# StageConfig(horizon=60, seq_len=29, n_features=7, feature_names=['open', 'high', 'low', 'close', 'ema_60', 'mom_10_struct', 'roc_60'], target_name='delta_pts_60', delta_base=52.12, delta_op=84.18)

# %%
states_h90 = load_state_from_reports(horizon=90)
states_h90
# Out:
# StageConfig(horizon=90, seq_len=29, n_features=7, feature_names=['open', 'high', 'low', 'close', 'ema_60', 'mom_10_struct', 'roc_30'], target_name='delta_pts_90', delta_base=60.75, delta_op=97.22)

# %% [markdown]
# ## **4. Importar métricas comunes desde .py**

# %%
# 1) Define el root del proyecto (DEBE existir en esta misma celda)
DRIVE_DIR =   Path(os.environ.get("DRIVE_DIR", "/content/drive/MyDrive/neural_profit/"))

# 2) Agrega el root al PYTHONPATH (antes de importar)
if str(DRIVE_DIR) not in sys.path:
    sys.path.insert(0, str(DRIVE_DIR))  # insert(0) para priorizarlo

# 3) Asegura que metrics sea paquete Python
(DRIVE_DIR / "metrics" / "__init__.py").touch(exist_ok=True)

# 4) Invalida cachés de import (importante en Colab)
importlib.invalidate_caches()

# 5) Diagnóstico (le muestra qué ve Python)
#print("DRIVE_DIR:", DRIVE_DIR)
#print("sys.path[0]:", sys.path[0])
#print("metrics exists:", (DRIVE_DIR / "metrics").exists())
#print("metrics __init__:", (DRIVE_DIR / "metrics" / "__init__.py").exists())

# 6) Imports reales
from metrics.seq2seq_metrics import compute_seq2seq_metrics
#from metrics.opportunity_filter_metrics import compute_opportunity_filter_metrics

print("OK - imports metrics.*")
# Out:
# OK - imports metrics.*

# %%
print(compute_seq2seq_metrics.__doc__)
# Out:
#     Calcula métricas simples y comparables para modelos seq2seq.
#
#     Parámetros
#     ----------
#     y_true : np.ndarray
#         Valores reales con shape (n_samples, seq_len) o (n_samples, seq_len, 1)
#     y_pred : np.ndarray
#         Valores predichos con shape (n_samples, seq_len) o (n_samples, seq_len, 1)
#     compute_r2 : bool
#         Si True, calcula R² sobre la secuencia completa concatenada.
#     da_ignore_zeros : bool
#         Si True, ignora casos donde el signo sea 0 (y_true_last==0 o y_pred_last==0)
#         al calcular DA_last. Esto evita ambigüedad en la dirección.
#
#     Retorna
#     -------
#     metrics : dict
#         Diccionario con métricas globales y diagnóstico por paso.

# %% [markdown]
# ## **5. Carga de data windows**

# %%
# --------------------------------------------------
# Función común: carga .npz estándar (X, y)
# --------------------------------------------------
def load_npz_windows(path: Path) -> Tuple[np.ndarray, np.ndarray]:
    """
    Carga ventanas X e y desde un archivo .npz estándar.

    Espera claves:
    - 'X': array (n_samples, seq_len, n_features)
    - 'y' o 'Y': array (n_samples, seq_len) o (n_samples, seq_len, 1)
    """
    # Verifica existencia del archivo.
    if not path.exists():
        raise FileNotFoundError(f"No se encontró el archivo: {path}")

    # Carga el NPZ (lectura).
    data = np.load(path)

    # Lee X (obligatoria).
    if "X" not in data:
        raise KeyError(f"NPZ inválido (falta clave 'X'): {path}")
    X = data["X"]

    # Lee y: soporta 'y' (convención usada) o 'Y' (por compatibilidad).
    if "y" in data:
        y = data["y"]
    elif "Y" in data:
        y = data["Y"]
    else:
        raise KeyError(f"NPZ inválido (falta clave 'y'/'Y'): {path}")

    # Devuelve X e y.
    return X, y

# %%
# --------------------------------------------------
# Función común: carga scaler .pkl (sklearn)
# --------------------------------------------------
def load_scaler(path: Path) -> Any:
    """
    Carga un scaler serializado con joblib (ej. StandardScaler/MinMaxScaler).
    """
    # Verifica existencia del archivo.
    if not path.exists():
        raise FileNotFoundError(f"No se encontró el scaler: {path}")

    # Carga el objeto scaler.
    scaler = joblib.load(path)

    # Devuelve scaler (tipo genérico).
    return scaler

# %%
# --------------------------------------------------
# Carga completa: train/valid/test + scaler por horizonte
# --------------------------------------------------
def load_windows_and_scaler_for_horizon(horizon: int) -> Dict[str, Any]:
    """
    Carga X/y (train/valid/test) y el scaler para un horizonte dado (60 o 90).

    Retorna un dict:
    {
      "horizon": 60,
      "paths": {...},
      "scaler": <StandardScaler>,
      "train": {"X":..., "y":...},
      "valid": {"X":..., "y":...},
      "test":  {"X":..., "y":...},
    }
    """
    # Valida horizonte permitido.
    if horizon not in (60, 90):
        raise ValueError("horizon debe ser 60 o 90")

    # Selecciona paths según horizonte.
    if horizon == 60:
        train_path = IN_WINDOW_TRAIN_60_Z
        valid_path = IN_WINDOW_VALID_60_Z
        test_path  = IN_WINDOW_TEST_60_Z
        scaler_path = IN_SCALER_60
    else:
        train_path = IN_WINDOW_TRAIN_90_Z
        valid_path = IN_WINDOW_VALID_90_Z
        test_path  = IN_WINDOW_TEST_90_Z
        scaler_path = IN_SCALER_90

    # Carga ventanas.
    X_train, y_train = load_npz_windows(train_path)
    X_valid, y_valid = load_npz_windows(valid_path)
    X_test,  y_test  = load_npz_windows(test_path)

    # Carga scaler.
    scaler = load_scaler(scaler_path)

    # Retorna todo empaquetado.
    return {
        "horizon": horizon,
        "paths": {
            "train": str(train_path),
            "valid": str(valid_path),
            "test": str(test_path),
            "scaler": str(scaler_path),
        },
        "scaler": scaler,
        "train": {"X": X_train, "y": y_train},
        "valid": {"X": X_valid, "y": y_valid},
        "test":  {"X": X_test,  "y": y_test},
    }

# %%
# --------------------------------------------------
# Carga efectiva: H60 y H90 (dos datasets distintos)
# --------------------------------------------------

# Carga todo para 60 min.
bundle_60 = load_windows_and_scaler_for_horizon(60)

# Carga todo para 90 min.
bundle_90 = load_windows_and_scaler_for_horizon(90)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.8.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
# --------------------------------------------------
# Verificación rápida
# --------------------------------------------------

# Shapes H60.
print("H60 Train:", bundle_60["train"]["X"].shape, bundle_60["train"]["y"].shape)
print("H60 Valid:", bundle_60["valid"]["X"].shape, bundle_60["valid"]["y"].shape)
print("H60 Test :", bundle_60["test"]["X"].shape,  bundle_60["test"]["y"].shape)

# Shapes H90.
print("H90 Train:", bundle_90["train"]["X"].shape, bundle_90["train"]["y"].shape)
print("H90 Valid:", bundle_90["valid"]["X"].shape, bundle_90["valid"]["y"].shape)
print("H90 Test :", bundle_90["test"]["X"].shape,  bundle_90["test"]["y"].shape)

# Información útil (scaler).
print("Scaler H60:", type(bundle_60["scaler"]).__name__)
print("Scaler H90:", type(bundle_90["scaler"]).__name__)
# Out:
# H60 Train: (912, 29, 7) (912, 29)
# H60 Valid: (195, 29, 7) (195, 29)
# H60 Test : (196, 29, 7) (196, 29)
# H90 Train: (912, 29, 7) (912, 29)
# H90 Valid: (195, 29, 7) (195, 29)
# H90 Test : (196, 29, 7) (196, 29)
# Scaler H60: StandardScaler
# Scaler H90: StandardScaler

# %% [markdown]
# NOTA IMPORTANTE: COMO ACCEDER A LAS VENTANAS
#
# Para el horizonte: `h`
#
#   - Train
#     - `X`: `bundle_h["train"]["X"]`
#     - `y`: `bundle_h["train"]["y"]`
#
#   - Valid
#     - `X`: `bundle_h["valid"]["X"]`
#     - `y`:`bundle_h["valid"]["y"]`
#
#   - Test
#     - `X`: `bundle_h["test"]["X"]`
#     - `y`: `bundle_h["test"]["y"]`
#
#   - Scaler
#     - `bundle_h["scaler"]`

# %% [markdown]
# ## **6. Sanity Check**

# %%
def sanity_check(
    X: np.ndarray,                 # Tensores de entrada: (n_samples, seq_len, n_features)
    y: np.ndarray,                 # Targets: (n_samples, seq_len) o (n_samples, seq_len, 1)
    name: str,                     # Nombre lógico del split (ej: "train_h60", "valid_h90")
    *,
    expected_seq_len: int,         # Largo de secuencia esperado (ej: 29)
    expected_n_features: int,      # Número de features esperado (ej: 8)
) -> None:
    # --------------------------------------------------
    # Chequeos de dimensionalidad
    # --------------------------------------------------

    # X debe ser estrictamente 3D: (muestras, tiempo, features)
    assert X.ndim == 3, (
        f"{name}: X debe ser 3D (n, seq, feat)"
    )

    # y puede ser 2D (n, seq) o 3D (n, seq, 1)
    assert y.ndim in (2, 3), (
        f"{name}: y debe ser 2D o 3D (n, seq) o (n, seq, 1)"
    )

    # --------------------------------------------------
    # Chequeos de consistencia temporal y estructural
    # --------------------------------------------------

    # Verifica que el largo temporal de X coincida con el esperado
    assert X.shape[1] == expected_seq_len, (
        f"{name}: seq_len inesperado en X: {X.shape[1]} != {expected_seq_len}"
    )

    # Verifica que la cantidad de features en X sea la esperada
    assert X.shape[2] == expected_n_features, (
        f"{name}: n_features inesperado en X: {X.shape[2]} != {expected_n_features}"
    )

    # Verifica que y tenga el mismo largo temporal que X
    assert y.shape[1] == expected_seq_len, (
        f"{name}: seq_len inesperado en y: {y.shape[1]} != {expected_seq_len}"
    )

    # --------------------------------------------------
    # Chequeos numéricos (sanidad de valores)
    # --------------------------------------------------

    # Asegura que X no contenga NaN ni infinitos
    assert np.isfinite(X).all(), (
        f"{name}: X contiene NaN/inf"
    )

    # Asegura que y no contenga NaN ni infinitos
    assert np.isfinite(y).all(), (
        f"{name}: y contiene NaN/inf"
    )

# %%
from __future__ import annotations

from typing import Any, Dict
import numpy as np


def run_sanity_checks_for_bundle(bundle: Dict[str, Any], *, tag: str) -> None:
    """
    Ejecuta sanity_check para train/valid/test usando únicamente variables locales.

    Espera un bundle con estructura:
    {
      "horizon": 60,
      "train": {"X":..., "y":...},
      "valid": {"X":..., "y":...},
      "test":  {"X":..., "y":...},
      ...
    }
    """
    # Extrae arrays localmente (no crea globals)
    X_tr = bundle["train"]["X"]
    y_tr = bundle["train"]["y"]

    X_va = bundle["valid"]["X"]
    y_va = bundle["valid"]["y"]

    X_te = bundle["test"]["X"]
    y_te = bundle["test"]["y"]

    # Toma expected_* desde TRAIN (consistencia)
    expected_seq_len = int(X_tr.shape[1])
    expected_n_features = int(X_tr.shape[2])

    # Ejecuta sanity checks por split
    sanity_check(X_tr, y_tr, f"train_{tag}", expected_seq_len=expected_seq_len, expected_n_features=expected_n_features)
    sanity_check(X_va, y_va, f"valid_{tag}", expected_seq_len=expected_seq_len, expected_n_features=expected_n_features)
    sanity_check(X_te, y_te, f"test_{tag}",  expected_seq_len=expected_seq_len, expected_n_features=expected_n_features)

    # Mensaje de OK por bundle/horizonte
    h = bundle.get("horizon", "NA")
    print(f"OK {tag} (h={h}) | seq_len={expected_seq_len} | n_features={expected_n_features}")

    # Opcional: borra referencias locales explícitamente (no es estrictamente necesario)
    del X_tr, y_tr, X_va, y_va, X_te, y_te


def run_sanity_checks_all_horizons(bundle_60: Dict[str, Any], bundle_90: Dict[str, Any]) -> None:
    """Corre sanity checks para ambos horizontes."""
    run_sanity_checks_for_bundle(bundle_60, tag="h60")
    run_sanity_checks_for_bundle(bundle_90, tag="h90")

# %%
run_sanity_checks_all_horizons(bundle_60, bundle_90)
# Out:
# OK h60 (h=60) | seq_len=29 | n_features=7
# OK h90 (h=90) | seq_len=29 | n_features=7

# %% [markdown]
# ## **7. Definición del modelo — placeholder**

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, regularizers

# %% [markdown]
# En un MLP Direct Multi-step:
#
# - El riesgo principal es el sobreajuste por capacidad
# (muchos parámetros, sin estructura temporal explícita).
# - Por eso, la regularización no es opcional, es parte del modelo.
#
# La jerarquía correcta es:
#
# - L2 (weight decay) → mecanismo principal
# - Early stopping en VALID → control dinámico
# - Arquitectura limitada → prevención estructural
# - Dropout leve → solo si hace falta
#
# Tal como indica Jansen:
# - Modelo flexible que requiere regularización explícita para generalizar.

# %% [markdown]
# ### **7.1. Definición de modelo con regularización**

# %%
# ============================================================
# Encoder–Decoder LSTM Seq2Seq (RepeatVector)
# ============================================================
# Estructura:
# - Encoder LSTM resume la ventana histórica
# - RepeatVector replica el contexto para cada paso futuro
# - Decoder LSTM genera la secuencia completa
# - TimeDistributed(Dense) produce la salida final
#
# Regularización aplicada (según criterios):
# - EarlyStopping: se aplica fuera del modelo (obligatorio)
# - Dropout en entradas/salidas (NO recurrent_dropout)
# - Tamaño moderado del hidden state
# - Número de capas limitado (1–2)
# - L2 opcional en los pesos
# ============================================================

from tensorflow import keras
from tensorflow.keras import layers, regularizers


def build_lstm_seq2seq_repeatvector(
    *,
    window_len: int = 29,
    n_features: int = 7,
    horizon_len: int = 29,
    units: int = 64,              # tamaño moderado del hidden state
    num_layers: int = 1,          # 1–2 capas máximo
    dropout: float = 0.10,        # dropout en entradas/salidas
    l2_reg: float | None = None,  # penalización L2 suave (opcional)
    lr: float = 1e-3,
    run_eagerly: bool = True,
) -> keras.Model:
    """
    Encoder–Decoder LSTM (RepeatVector).

    Inputs:
      - X: (window_len, n_features)

    Outputs:
      - y_hat: (horizon_len, 1)
    """
    if num_layers not in (1, 2):
        raise ValueError("num_layers debe ser 1 o 2.")

    # Regularización L2 (opcional)
    kernel_reg = regularizers.l2(l2_reg) if l2_reg is not None else None

    # -------------------------
    # INPUT
    # -------------------------
    enc_in = keras.Input(
        shape=(window_len, n_features),
        name="enc_in"
    )

    # -------------------------
    # ENCODER
    # -------------------------
    x = enc_in

    # Si se usan 2 capas, la primera devuelve secuencia completa
    if num_layers == 2:
        x = layers.LSTM(
            units,
            return_sequences=True,
            dropout=dropout,
            recurrent_dropout=0.0,      # evitamos dropout recurrente
            kernel_regularizer=kernel_reg,
            name="enc_lstm_1",
        )(x)

    # Encoder final: produce vector de contexto (batch, units)
    context = layers.LSTM(
        units,
        return_sequences=False,
        dropout=dropout,
        recurrent_dropout=0.0,
        kernel_regularizer=kernel_reg,
        name="enc_lstm_final",
    )(x)

    # -------------------------
    # REPEAT VECTOR
    # -------------------------
    # (batch, units) -> (batch, horizon_len, units)
    dec_in = layers.RepeatVector(
        horizon_len,
        name="repeat_context"
    )(context)

    # -------------------------
    # DECODER
    # -------------------------
    dec_seq = layers.LSTM(
        units,
        return_sequences=True,
        dropout=dropout,
        recurrent_dropout=0.0,
        kernel_regularizer=kernel_reg,
        name="dec_lstm",
    )(dec_in)

    # -------------------------
    # OUTPUT
    # -------------------------
    y_hat = layers.TimeDistributed(
        layers.Dense(1, activation="linear"),
        name="y_hat",
    )(dec_seq)

    # -------------------------
    # MODEL
    # -------------------------
    model = keras.Model(
        inputs=enc_in,
        outputs=y_hat,
        name="LSTM_Seq2Seq_RepeatVector",
    )

    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=lr),
        loss="mse",
        metrics=[keras.metrics.MAE],
        run_eagerly=run_eagerly,
    )

    return model

# %%
# ---------------------------------------------
# 1) Limpiar sesión para evitar quedarnos con modelos viejos
# ---------------------------------------------
from tensorflow.keras import backend as K
K.clear_session()

# %% [markdown]
# ### **7.2. Helpers**

# %%
def get_seq2seq_xy_from_bundle(bundle_h: dict, *, split: str):
    """
    Helper genérico para modelos RepeatVector (GRU/LSTM):
    - X: (N, window_len, n_features)
    - y: (N, horizon_len, 1)
    """
    X = bundle_h[split]["X"]
    y = to_3d_y(bundle_h[split]["y"])
    return X, y

# %%
import numpy as np

def to_3d_y(y: np.ndarray) -> np.ndarray:
    """
    Normaliza y a 3D para Seq2Seq:
      - (N, H)    -> (N, H, 1)
      - (N, H, 1) -> (N, H, 1)

    Esto es consistente con la salida del GRU Seq2Seq:
      y_hat: (N, H, 1)
    """
    # Caso: y ya es (N, H, 1)
    if y.ndim == 3:
        if y.shape[-1] != 1:
            raise ValueError(f"Se esperaba y con último dim=1, got {y.shape}")
        return y

    # Caso: y viene como (N, H) y lo expandimos a (N, H, 1)
    if y.ndim == 2:
        return y[..., None]

    # Cualquier otra forma no es compatible con este pipeline
    raise ValueError(f"Forma inesperada para y: {y.shape}")

# %% [markdown]
# ### **7.3. Construcción de modelo desde bundles**

# %%
# ============================================================
# build_lstm_model_for_bundle (RepeatVector) – H60 / H90
# ============================================================
# Objetivo:
# - Inferir window_len, n_features y horizon_len desde el bundle (TRAIN)
# - Normalizar y_train a 3D (N, H, 1) para obtener horizon_len de forma robusta
# - Construir el modelo LSTM Seq2Seq (RepeatVector) con regularización estructural
#
# Nota:
# - Esto NO entrena. Solo construye el modelo para un bundle dado (H60 o H90).
# ============================================================

def build_lstm_model_for_bundle(bundle_h: dict):
    # -------------------------
    # Shapes base desde TRAIN
    # -------------------------
    X_train = bundle_h["train"]["X"]  # (N, window_len, n_features)
    y_train = bundle_h["train"]["y"]  # (N, H) o (N, H, 1)

    window_len = int(X_train.shape[1])
    n_features = int(X_train.shape[2])

    # Normaliza y a 3D para inferir horizon_len de forma consistente
    y_train_3d = to_3d_y(y_train)     # (N, H, 1)
    horizon_len = int(y_train_3d.shape[1])

    # -------------------------
    # Construcción del modelo
    # -------------------------
    model = build_lstm_seq2seq_repeatvector(
        window_len=window_len,
        n_features=n_features,
        horizon_len=horizon_len,
        units=64,          # hidden state moderado
        num_layers=1,      # 1–2 capas máximo (por ahora 1)
        dropout=0.10,      # dropout en entradas/salidas
        l2_reg=None,       # opcional: p.ej. 1e-6 o 1e-5 si ve sobreajuste
        lr=1e-3,
        run_eagerly=True,  # robustez en Colab
    )
    return model

# %% [markdown]
# ### **7.4. Verificación de shapes**

# %%
# ---------------------------------------------
# PASO 1) Verificación de shapes para GRU Seq2Seq
# ---------------------------------------------
# Objetivo:
# - Confirmar que los bundles H60 y H90 tienen shapes consistentes
# - Obtener (window_len, n_features, horizon_len) desde TRAIN
# - Verificar que VALID mantiene los mismos (window_len, n_features, horizon_len)
#
# Nota:
# - Esto NO entrena nada. Solo inspecciona y valida dimensiones.
# ---------------------------------------------

def assert_same(a: int, b: int, *, msg: str) -> None:
    """Helper pequeño para levantar error con mensaje claro."""
    if int(a) != int(b):
        raise ValueError(f"{msg} (train={a} vs valid={b})")


def check_bundle_shapes_for_gru(bundle_h: dict, *, tag: str) -> dict:
    """
    Chequea shapes relevantes para un bundle (por ejemplo H60 o H90).

    Retorna un dict con:
      - window_len
      - n_features
      - horizon_len
      - train_shapes (X,y)
      - valid_shapes (X,y)
    """
    # -------------------------
    # TRAIN: shapes base del modelo
    # -------------------------
    X_train = bundle_h["train"]["X"]   # (N, window_len, n_features)
    y_train = bundle_h["train"]["y"]   # (N, H) o (N, H, 1)

    window_len_train = int(X_train.shape[1])
    n_features_train = int(X_train.shape[2])

    # Normalizamos y_train a 3D para leer horizon_len de forma uniforme
    y_train_3d = to_3d_y(y_train)      # (N, H, 1)
    horizon_len_train = int(y_train_3d.shape[1])

    # -------------------------
    # VALID: debe ser consistente con TRAIN
    # -------------------------
    X_valid = bundle_h["valid"]["X"]
    y_valid = bundle_h["valid"]["y"]

    window_len_valid = int(X_valid.shape[1])
    n_features_valid = int(X_valid.shape[2])

    y_valid_3d = to_3d_y(y_valid)
    horizon_len_valid = int(y_valid_3d.shape[1])

    # -------------------------
    # Validaciones de consistencia
    # -------------------------
    assert_same(window_len_train, window_len_valid, msg=f"[{tag}] window_len inconsistente")
    assert_same(n_features_train, n_features_valid, msg=f"[{tag}] n_features inconsistente")
    assert_same(horizon_len_train, horizon_len_valid, msg=f"[{tag}] horizon_len inconsistente")

    # -------------------------
    # Reporte compacto
    # -------------------------
    info = {
        "tag": tag,
        "window_len": window_len_train,
        "n_features": n_features_train,
        "horizon_len": horizon_len_train,
        "train_shapes": {
            "X": tuple(X_train.shape),
            "y_raw": tuple(y_train.shape),
            "y_3d": tuple(y_train_3d.shape),
        },
        "valid_shapes": {
            "X": tuple(X_valid.shape),
            "y_raw": tuple(y_valid.shape),
            "y_3d": tuple(y_valid_3d.shape),
        },
    }

    return info


# -------------------------
# Ejecutar checks para H60 y H90
# -------------------------
info_60 = check_bundle_shapes_for_gru(bundle_60, tag="H60")
info_90 = check_bundle_shapes_for_gru(bundle_90, tag="H90")

# Imprimir resumen legible
print(
    f"[H60] window_len={info_60['window_len']} | n_features={info_60['n_features']} | horizon_len={info_60['horizon_len']}\n"
    f"      train X={info_60['train_shapes']['X']} y_raw={info_60['train_shapes']['y_raw']} y_3d={info_60['train_shapes']['y_3d']}\n"
    f"      valid X={info_60['valid_shapes']['X']} y_raw={info_60['valid_shapes']['y_raw']} y_3d={info_60['valid_shapes']['y_3d']}\n"
)

print(
    f"[H90] window_len={info_90['window_len']} | n_features={info_90['n_features']} | horizon_len={info_90['horizon_len']}\n"
    f"      train X={info_90['train_shapes']['X']} y_raw={info_90['train_shapes']['y_raw']} y_3d={info_90['train_shapes']['y_3d']}\n"
    f"      valid X={info_90['valid_shapes']['X']} y_raw={info_90['valid_shapes']['y_raw']} y_3d={info_90['valid_shapes']['y_3d']}\n"
)
# Out:
# [H60] window_len=29 | n_features=7 | horizon_len=29
#       train X=(912, 29, 7) y_raw=(912, 29) y_3d=(912, 29, 1)
#       valid X=(195, 29, 7) y_raw=(195, 29) y_3d=(195, 29, 1)
#
# [H90] window_len=29 | n_features=7 | horizon_len=29
#       train X=(912, 29, 7) y_raw=(912, 29) y_3d=(912, 29, 1)
#       valid X=(195, 29, 7) y_raw=(195, 29) y_3d=(195, 29, 1)

# %% [markdown]
# ### **7.5. Construcción de modelo por horizontes**

# %%
from tensorflow.keras import backend as K
K.clear_session()  # evita reutilizar tensores/modelos anteriores

# Construye modelos
model_lstm_60 = build_lstm_model_for_bundle(bundle_60)
model_lstm_90 = build_lstm_model_for_bundle(bundle_90)

# Resúmenes para verificar arquitectura y shapes
print("\n" + "="*80)
print("MODEL SUMMARY - LSTM Seq2Seq RepeatVector (H60)")
print("="*80)
model_lstm_60.summary()

print("\n" + "="*80)
print("MODEL SUMMARY - LSTM Seq2Seq RepeatVector (H90)")
print("="*80)
model_lstm_90.summary()

print("\n" + "="*80)
print("SHAPES CHECK")
print("="*80)
print("H60 input:", model_lstm_60.input.shape, "output:", model_lstm_60.output.shape)
print("H90 input:", model_lstm_90.input.shape, "output:", model_lstm_90.output.shape)
# Out:
# ================================================================================
# MODEL SUMMARY - LSTM Seq2Seq RepeatVector (H60)
# ================================================================================
# Model: "LSTM_Seq2Seq_RepeatVector"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ enc_in (InputLayer)             │ (None, 29, 7)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ enc_lstm_final (LSTM)           │ (None, 64)             │        18,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ repeat_context (RepeatVector)   │ (None, 29, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dec_lstm (LSTM)                 │ (None, 29, 64)         │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ y_hat (TimeDistributed)         │ (None, 29, 1)          │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 51,521 (201.25 KB)
#  Trainable params: 51,521 (201.25 KB)
#  Non-trainable params: 0 (0.00 B)
# ================================================================================
# MODEL SUMMARY - LSTM Seq2Seq RepeatVector (H90)
# ================================================================================
# Model: "LSTM_Seq2Seq_RepeatVector"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ enc_in (InputLayer)             │ (None, 29, 7)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ enc_lstm_final (LSTM)           │ (None, 64)             │        18,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ repeat_context (RepeatVector)   │ (None, 29, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dec_lstm (LSTM)                 │ (None, 29, 64)         │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ y_hat (TimeDistributed)         │ (None, 29, 1)          │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 51,521 (201.25 KB)
#  Trainable params: 51,521 (201.25 KB)
#  Non-trainable params: 0 (0.00 B)
# ================================================================================
# SHAPES CHECK
# ================================================================================
# H60 input: (None, 29, 7) output: (None, 29, 1)
# H90 input: (None, 29, 7) output: (None, 29, 1)

# %%
# (Opcional) Confirmar que está en eager
print("H60 run_eagerly:", model_lstm_60.run_eagerly)
print("H90 run_eagerly:", model_lstm_90.run_eagerly)
# Out:
# H60 run_eagerly: True
# H90 run_eagerly: True

# %%
print("H60 inputs:", [t.shape for t in model_lstm_60.inputs], "output:", model_lstm_60.output.shape)
print("H90 inputs:", [t.shape for t in model_lstm_90.inputs], "output:", model_lstm_90.output.shape)
# Out:
# H60 inputs: [(None, 29, 7)] output: (None, 29, 1)
# H90 inputs: [(None, 29, 7)] output: (None, 29, 1)

# %% [markdown]
# ### **7.6. Preparar X/y para TRAIN y VALID**

# %%
# -------------------------
# H60: TRAIN y VALID
# -------------------------
X_train_60, y_train_60_3d = get_seq2seq_xy_from_bundle(bundle_60, split="train")
X_valid_60, y_valid_60_3d = get_seq2seq_xy_from_bundle(bundle_60, split="valid")

print("\n" + "="*80)
print("H60 - DATA CHECK (LSTM RepeatVector)")
print("="*80)
print("X_train:", X_train_60.shape, "y_train:", y_train_60_3d.shape)
print("X_valid:", X_valid_60.shape, "y_valid:", y_valid_60_3d.shape)

# -------------------------
# H90: TRAIN y VALID
# -------------------------
X_train_90, y_train_90_3d = get_seq2seq_xy_from_bundle(bundle_90, split="train")
X_valid_90, y_valid_90_3d = get_seq2seq_xy_from_bundle(bundle_90, split="valid")

print("\n" + "="*80)
print("H90 - DATA CHECK (LSTM RepeatVector)")
print("="*80)
print("X_train:", X_train_90.shape, "y_train:", y_train_90_3d.shape)
print("X_valid:", X_valid_90.shape, "y_valid:", y_valid_90_3d.shape)
# Out:
# ================================================================================
# H60 - DATA CHECK (LSTM RepeatVector)
# ================================================================================
# X_train: (912, 29, 7) y_train: (912, 29, 1)
# X_valid: (195, 29, 7) y_valid: (195, 29, 1)
#
# ================================================================================
# H90 - DATA CHECK (LSTM RepeatVector)
# ================================================================================
# X_train: (912, 29, 7) y_train: (912, 29, 1)
# X_valid: (195, 29, 7) y_valid: (195, 29, 1)

# %% [markdown]
# ### **7.7. Entrenamiento LSTM**

# %%
# ============================================================
# PASO 4) FIT COMPLETO Y ROBUSTO – LSTM RepeatVector (VALID ONLY)
# ============================================================
# Este bloque:
# - Limpia sesión (evita tensores/modelos viejos)
# - Reconstruye modelos LSTM H60 y H90
# - Verifica GPU
# - Verifica shapes críticos antes de entrenar
# - Entrena usando EarlyStopping como regularización principal
# - Usa SOLO TRAIN + VALID (no test)
# ============================================================

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend as K


# -------------------------
# 0) Limpieza de sesión
# -------------------------
# Evita errores por reutilización de grafos/tensores antiguos
K.clear_session()


# -------------------------
# 1) Reconstrucción de modelos (LSTM RepeatVector)
# -------------------------
# IMPORTANTE:
# - build_lstm_model_for_bundle DEBE usar build_lstm_seq2seq_repeatvector(...)
# - El modelo debe estar compilado con run_eagerly=True (robustez en Colab)
model_lstm_60 = build_lstm_model_for_bundle(bundle_60)
model_lstm_90 = build_lstm_model_for_bundle(bundle_90)

# Verificación explícita de ejecución eager
print("run_eagerly H60:", model_lstm_60.run_eagerly)
print("run_eagerly H90:", model_lstm_90.run_eagerly)


# -------------------------
# 2) Verificación de GPU
# -------------------------
gpus = tf.config.list_logical_devices("GPU")
device_name = "/device:GPU:0" if gpus else "/device:CPU:0"
print("Dispositivo a usar:", device_name)


# -------------------------
# 3) Verificaciones de SHAPES (RepeatVector)
# -------------------------
def check_xy_shapes(X_train, y_train, X_valid, y_valid, tag: str):
    """
    Verifica consistencia básica de shapes para:
      fit(X_train, y_train) y validation_data=(X_valid, y_valid)
    """
    # X debe ser 3D: (N, window_len, n_features)
    assert X_train.ndim == 3, f"[{tag}] X_train no es 3D"
    assert X_valid.ndim == 3, f"[{tag}] X_valid no es 3D"

    # y debe ser 3D: (N, horizon_len, 1)
    assert y_train.ndim == 3, f"[{tag}] y_train no es 3D"
    assert y_valid.ndim == 3, f"[{tag}] y_valid no es 3D"
    assert y_train.shape[-1] == 1, f"[{tag}] y_train último dim != 1"
    assert y_valid.shape[-1] == 1, f"[{tag}] y_valid último dim != 1"

    # N consistente
    assert X_train.shape[0] == y_train.shape[0], f"[{tag}] N_train inconsistente"
    assert X_valid.shape[0] == y_valid.shape[0], f"[{tag}] N_valid inconsistente"

    # horizon_len consistente entre train y valid
    assert y_train.shape[1] == y_valid.shape[1], f"[{tag}] horizon_len train/valid inconsistente"

    print(f"[{tag}] Shapes OK:",
          "X_train", X_train.shape, "y_train", y_train.shape,
          "| X_valid", X_valid.shape, "y_valid", y_valid.shape)

# Chequeos (usa variables del PASO 3)
check_xy_shapes(X_train_60, y_train_60_3d, X_valid_60, y_valid_60_3d, tag="H60")
check_xy_shapes(X_train_90, y_train_90_3d, X_valid_90, y_valid_90_3d, tag="H90")


# -------------------------
# 4) EarlyStopping (regularización principal)
# -------------------------
early_stop = keras.callbacks.EarlyStopping(
    monitor="val_loss",
    patience=12,
    restore_best_weights=True,
)


# -------------------------
# 5) Entrenamiento en GPU (VALID ONLY)
# -------------------------
with tf.device(device_name):

    print("\n" + "=" * 80)
    print("FIT – LSTM RepeatVector H60 (VALID ONLY)")
    print("=" * 80)

    hist_lstm_60 = model_lstm_60.fit(
        X_train_60,
        y_train_60_3d,
        validation_data=(X_valid_60, y_valid_60_3d),
        epochs=200,
        batch_size=256,
        callbacks=[early_stop],
        verbose=1,
    )

    print("\n" + "=" * 80)
    print("FIT – LSTM RepeatVector H90 (VALID ONLY)")
    print("=" * 80)

    hist_lstm_90 = model_lstm_90.fit(
        X_train_90,
        y_train_90_3d,
        validation_data=(X_valid_90, y_valid_90_3d),
        epochs=200,
        batch_size=256,
        callbacks=[early_stop],
        verbose=1,
    )
# Out:
# run_eagerly H60: True
# run_eagerly H90: True
# Dispositivo a usar: /device:GPU:0
# [H60] Shapes OK: X_train (912, 29, 7) y_train (912, 29, 1) | X_valid (195, 29, 7) y_valid (195, 29, 1)
# [H90] Shapes OK: X_train (912, 29, 7) y_train (912, 29, 1) | X_valid (195, 29, 7) y_valid (195, 29, 1)
#
# ================================================================================
# FIT – LSTM RepeatVector H60 (VALID ONLY)
# ================================================================================
# Epoch 1/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 214ms/step - loss: 2834.0706 - mean_absolute_error: 37.0215 - val_loss: 2508.5156 - val_mean_absolute_error: 36.4183
# Epoch 2/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 201ms/step - loss: 2842.2134 - mean_absolute_error: 36.7287 - val_loss: 2503.1399 - val_mean_absolute_error: 36.3860
# Epoch 3/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 214ms/step - loss: 2811.9016 - mean_absolute_error: 36.8417 - val_loss: 2495.0850 - val_mean_absolute_error: 36.3379
# Epoch 4/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 203ms/step - loss: 2745.1243 - mean_absolute_error: 36.8853 - val_loss: 2485.3538 - val_mean_absolute_error: 36.2849
# Epoch 5/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 204ms/step - loss: 2747.4556 - mean_absolute_error: 36.3935 - val_loss: 2474.8833 - val_mean_absolute_error: 36.2167
# Epoch 6/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 202ms/step - loss: 2762.8926 - mean_absolute_error: 36.5629 - val_loss: 2465.7314 - val_mean_absolute_error: 36.1483
# Epoch 7/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 203ms/step - loss: 2772.7661 - mean_absolute_error: 36.0535 - val_loss: 2458.7632 - val_mean_absolute_error: 36.0919
# Epoch 8/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 199ms/step - loss: 2785.2671 - mean_absolute_error: 36.7981 - val_loss: 2453.9841 - val_mean_absolute_error: 36.0506
# Epoch 9/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 200ms/step - loss: 2862.1948 - mean_absolute_error: 36.9776 - val_loss: 2443.9062 - val_mean_absolute_error: 35.9646
# Epoch 10/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 199ms/step - loss: 2905.7402 - mean_absolute_error: 37.0603 - val_loss: 2432.0276 - val_mean_absolute_error: 35.8723
# Epoch 11/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 203ms/step - loss: 2723.6501 - mean_absolute_error: 35.8436 - val_loss: 2427.4688 - val_mean_absolute_error: 35.8098
# Epoch 12/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 199ms/step - loss: 2735.2695 - mean_absolute_error: 36.0607 - val_loss: 2418.6240 - val_mean_absolute_error: 35.7456
# Epoch 13/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 200ms/step - loss: 2731.9302 - mean_absolute_error: 36.3490 - val_loss: 2418.4546 - val_mean_absolute_error: 35.7593
# Epoch 14/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 201ms/step - loss: 2718.9971 - mean_absolute_error: 36.0387 - val_loss: 2417.8809 - val_mean_absolute_error: 35.7285
# Epoch 15/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 203ms/step - loss: 2705.0654 - mean_absolute_error: 35.9867 - val_loss: 2413.4688 - val_mean_absolute_error: 35.7651
# Epoch 16/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 200ms/step - loss: 2793.1555 - mean_absolute_error: 36.4500 - val_loss: 2402.4094 - val_mean_absolute_error: 35.6294
# Epoch 17/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 196ms/step - loss: 2741.7644 - mean_absolute_error: 36.1266 - val_loss: 2386.5928 - val_mean_absolute_error: 35.4464
# Epoch 18/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 200ms/step - loss: 2851.1182 - mean_absolute_error: 36.5130 - val_loss: 2382.6230 - val_mean_absolute_error: 35.3412
# Epoch 19/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 200ms/step - loss: 2508.9343 - mean_absolute_error: 34.8521 - val_loss: 2383.6885 - val_mean_absolute_error: 35.4470
# Epoch 20/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 202ms/step - loss: 2732.4243 - mean_absolute_error: 36.0217 - val_loss: 2390.6453 - val_mean_absolute_error: 35.5864
# Epoch 21/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 198ms/step - loss: 2687.7756 - mean_absolute_error: 35.8965 - val_loss: 2391.5015 - val_mean_absolute_error: 35.7266
# Epoch 22/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 199ms/step - loss: 2678.4539 - mean_absolute_error: 35.7908 - val_loss: 2390.8599 - val_mean_absolute_error: 35.7601
# Epoch 23/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 199ms/step - loss: 2586.6294 - mean_absolute_error: 35.1126 - val_loss: 2386.8284 - val_mean_absolute_error: 35.6840
# Epoch 24/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 197ms/step - loss: 2843.0750 - mean_absolute_error: 36.0329 - val_loss: 2381.3865 - val_mean_absolute_error: 35.5732
# Epoch 25/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 201ms/step - loss: 2587.1267 - mean_absolute_error: 35.4117 - val_loss: 2378.2371 - val_mean_absolute_error: 35.5271
# Epoch 26/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 199ms/step - loss: 2823.0637 - mean_absolute_error: 36.2463 - val_loss: 2357.0830 - val_mean_absolute_error: 35.2755
# Epoch 27/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 199ms/step - loss: 2657.6143 - mean_absolute_error: 35.4714 - val_loss: 2355.9722 - val_mean_absolute_error: 35.2339
# Epoch 28/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 203ms/step - loss: 2477.8101 - mean_absolute_error: 34.5772 - val_loss: 2355.1575 - val_mean_absolute_error: 35.2461
# Epoch 29/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 204ms/step - loss: 2652.8232 - mean_absolute_error: 35.5624 - val_loss: 2321.2275 - val_mean_absolute_error: 34.6946
# Epoch 30/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 201ms/step - loss: 2575.1458 - mean_absolute_error: 35.3313 - val_loss: 2337.4387 - val_mean_absolute_error: 35.0463
# Epoch 31/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 198ms/step - loss: 2746.9814 - mean_absolute_error: 35.9606 - val_loss: 2348.9431 - val_mean_absolute_error: 35.1581
# Epoch 32/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 204ms/step - loss: 2717.2417 - mean_absolute_error: 35.7638 - val_loss: 2338.8909 - val_mean_absolute_error: 35.0552
# Epoch 33/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 201ms/step - loss: 2721.8313 - mean_absolute_error: 35.6075 - val_loss: 2325.2937 - val_mean_absolute_error: 34.8935
# Epoch 34/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 203ms/step - loss: 2667.8364 - mean_absolute_error: 35.7837 - val_loss: 2320.1838 - val_mean_absolute_error: 34.8529
# Epoch 35/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 205ms/step - loss: 2623.1802 - mean_absolute_error: 35.0792 - val_loss: 2330.7747 - val_mean_absolute_error: 35.0169
# Epoch 36/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 219ms/step - loss: 2571.7410 - mean_absolute_error: 35.1555 - val_loss: 2325.5876 - val_mean_absolute_error: 34.9837
# Epoch 37/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 199ms/step - loss: 2611.9612 - mean_absolute_error: 35.2600 - val_loss: 2321.4854 - val_mean_absolute_error: 34.9503
# Epoch 38/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 203ms/step - loss: 2527.9844 - mean_absolute_error: 34.6265 - val_loss: 2311.4456 - val_mean_absolute_error: 34.8756
# Epoch 39/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 204ms/step - loss: 2599.4817 - mean_absolute_error: 35.0445 - val_loss: 2293.7886 - val_mean_absolute_error: 34.5923
# Epoch 40/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 201ms/step - loss: 2543.2881 - mean_absolute_error: 34.9906 - val_loss: 2297.9341 - val_mean_absolute_error: 34.7881
# Epoch 41/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 198ms/step - loss: 2630.4558 - mean_absolute_error: 35.4192 - val_loss: 2299.0942 - val_mean_absolute_error: 34.8531
# Epoch 42/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 201ms/step - loss: 2718.7166 - mean_absolute_error: 35.8411 - val_loss: 2288.1831 - val_mean_absolute_error: 34.6210
# Epoch 43/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 200ms/step - loss: 2588.7524 - mean_absolute_error: 35.2235 - val_loss: 2275.6375 - val_mean_absolute_error: 34.3836
# Epoch 44/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 199ms/step - loss: 2581.8679 - mean_absolute_error: 34.6650 - val_loss: 2276.7314 - val_mean_absolute_error: 34.4391
# Epoch 45/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 198ms/step - loss: 2565.8442 - mean_absolute_error: 34.8500 - val_loss: 2262.8079 - val_mean_absolute_error: 34.3476
# Epoch 46/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 196ms/step - loss: 2752.6555 - mean_absolute_error: 35.6036 - val_loss: 2271.9478 - val_mean_absolute_error: 34.5421
# Epoch 47/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 199ms/step - loss: 2479.1938 - mean_absolute_error: 34.2477 - val_loss: 2265.0200 - val_mean_absolute_error: 34.6044
# Epoch 48/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 199ms/step - loss: 2577.9424 - mean_absolute_error: 34.9978 - val_loss: 2254.8335 - val_mean_absolute_error: 34.4945
# Epoch 49/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 201ms/step - loss: 2456.2512 - mean_absolute_error: 34.4053 - val_loss: 2244.1101 - val_mean_absolute_error: 34.4805
# Epoch 50/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 201ms/step - loss: 2590.9302 - mean_absolute_error: 34.8024 - val_loss: 2231.1252 - val_mean_absolute_error: 34.4186
# Epoch 51/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 200ms/step - loss: 2591.8757 - mean_absolute_error: 34.8450 - val_loss: 2236.3711 - val_mean_absolute_error: 34.4058
# Epoch 52/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 203ms/step - loss: 2451.6379 - mean_absolute_error: 34.2867 - val_loss: 2238.3499 - val_mean_absolute_error: 34.2999
# Epoch 53/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 201ms/step - loss: 2484.7588 - mean_absolute_error: 34.5462 - val_loss: 2242.0190 - val_mean_absolute_error: 34.3495
# Epoch 54/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 199ms/step - loss: 2540.8699 - mean_absolute_error: 34.2786 - val_loss: 2252.4067 - val_mean_absolute_error: 34.5825
# Epoch 55/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 201ms/step - loss: 2487.6267 - mean_absolute_error: 34.2428 - val_loss: 2250.7688 - val_mean_absolute_error: 34.5692
# Epoch 56/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 199ms/step - loss: 2535.3828 - mean_absolute_error: 34.8882 - val_loss: 2234.3320 - val_mean_absolute_error: 34.1510
# Epoch 57/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 210ms/step - loss: 2643.1084 - mean_absolute_error: 35.0612 - val_loss: 2249.5051 - val_mean_absolute_error: 34.3576
# Epoch 58/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 201ms/step - loss: 2563.7788 - mean_absolute_error: 34.7213 - val_loss: 2231.6958 - val_mean_absolute_error: 34.1840
# Epoch 59/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 199ms/step - loss: 2444.2603 - mean_absolute_error: 33.8892 - val_loss: 2224.8445 - val_mean_absolute_error: 34.1531
# Epoch 60/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 199ms/step - loss: 2521.5059 - mean_absolute_error: 34.3685 - val_loss: 2225.9377 - val_mean_absolute_error: 34.1074
# Epoch 61/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 199ms/step - loss: 2538.5017 - mean_absolute_error: 34.4774 - val_loss: 2221.2012 - val_mean_absolute_error: 34.1217
# Epoch 62/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 197ms/step - loss: 2379.0989 - mean_absolute_error: 33.8593 - val_loss: 2223.1829 - val_mean_absolute_error: 34.1665
# Epoch 63/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 195ms/step - loss: 2653.6011 - mean_absolute_error: 35.1933 - val_loss: 2194.8740 - val_mean_absolute_error: 33.9523
# Epoch 64/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 201ms/step - loss: 2412.8760 - mean_absolute_error: 33.9100 - val_loss: 2180.9221 - val_mean_absolute_error: 33.9779
# Epoch 65/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 205ms/step - loss: 2411.1084 - mean_absolute_error: 33.7729 - val_loss: 2183.1794 - val_mean_absolute_error: 33.8263
# Epoch 66/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 199ms/step - loss: 2531.8264 - mean_absolute_error: 34.5251 - val_loss: 2198.5837 - val_mean_absolute_error: 33.9861
# Epoch 67/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 207ms/step - loss: 2396.3340 - mean_absolute_error: 33.8031 - val_loss: 2188.2642 - val_mean_absolute_error: 33.9413
# Epoch 68/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 202ms/step - loss: 2696.8254 - mean_absolute_error: 35.1875 - val_loss: 2175.3796 - val_mean_absolute_error: 33.7792
# Epoch 69/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 201ms/step - loss: 2406.0906 - mean_absolute_error: 33.8374 - val_loss: 2167.1274 - val_mean_absolute_error: 33.6706
# Epoch 70/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 201ms/step - loss: 2398.0947 - mean_absolute_error: 33.5415 - val_loss: 2196.0276 - val_mean_absolute_error: 33.7934
# Epoch 71/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 204ms/step - loss: 2558.0872 - mean_absolute_error: 34.6307 - val_loss: 2197.3865 - val_mean_absolute_error: 33.8281
# Epoch 72/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 199ms/step - loss: 2422.6150 - mean_absolute_error: 33.6988 - val_loss: 2219.5071 - val_mean_absolute_error: 33.9967
# Epoch 73/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 201ms/step - loss: 2282.8572 - mean_absolute_error: 33.1423 - val_loss: 2143.2031 - val_mean_absolute_error: 33.6386
# Epoch 74/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 199ms/step - loss: 2458.1228 - mean_absolute_error: 33.8593 - val_loss: 2151.9304 - val_mean_absolute_error: 33.6915
# Epoch 75/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 201ms/step - loss: 2445.7686 - mean_absolute_error: 33.8009 - val_loss: 2155.1941 - val_mean_absolute_error: 33.6634
# Epoch 76/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 198ms/step - loss: 2475.1714 - mean_absolute_error: 34.2682 - val_loss: 2144.0767 - val_mean_absolute_error: 33.6180
# Epoch 77/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 203ms/step - loss: 2554.9626 - mean_absolute_error: 34.1472 - val_loss: 2139.4448 - val_mean_absolute_error: 33.7742
# Epoch 78/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 197ms/step - loss: 2518.1968 - mean_absolute_error: 34.2740 - val_loss: 2144.5679 - val_mean_absolute_error: 33.8536
# Epoch 79/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 201ms/step - loss: 2339.4316 - mean_absolute_error: 33.6675 - val_loss: 2141.1311 - val_mean_absolute_error: 33.7932
# Epoch 80/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 200ms/step - loss: 2396.3079 - mean_absolute_error: 33.8705 - val_loss: 2132.6982 - val_mean_absolute_error: 33.5604
# Epoch 81/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 204ms/step - loss: 2316.6938 - mean_absolute_error: 33.5202 - val_loss: 2128.2927 - val_mean_absolute_error: 33.4773
# Epoch 82/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 198ms/step - loss: 2421.1704 - mean_absolute_error: 34.0185 - val_loss: 2131.3337 - val_mean_absolute_error: 33.6033
# Epoch 83/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 208ms/step - loss: 2453.9478 - mean_absolute_error: 34.2281 - val_loss: 2122.1228 - val_mean_absolute_error: 33.6175
# Epoch 84/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 200ms/step - loss: 2534.7554 - mean_absolute_error: 34.1883 - val_loss: 2103.2141 - val_mean_absolute_error: 33.3745
# Epoch 85/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 201ms/step - loss: 2399.4641 - mean_absolute_error: 33.6404 - val_loss: 2140.7063 - val_mean_absolute_error: 33.6985
# Epoch 86/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 199ms/step - loss: 2400.9365 - mean_absolute_error: 33.6363 - val_loss: 2140.6877 - val_mean_absolute_error: 33.8188
# Epoch 87/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 197ms/step - loss: 2535.9866 - mean_absolute_error: 34.8382 - val_loss: 2158.9221 - val_mean_absolute_error: 34.0004
# Epoch 88/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 198ms/step - loss: 2323.1033 - mean_absolute_error: 33.5903 - val_loss: 2143.7219 - val_mean_absolute_error: 33.8707
# Epoch 89/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 206ms/step - loss: 2381.3091 - mean_absolute_error: 33.9089 - val_loss: 2138.8364 - val_mean_absolute_error: 33.7833
# Epoch 90/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 199ms/step - loss: 2447.5891 - mean_absolute_error: 33.5889 - val_loss: 2148.9260 - val_mean_absolute_error: 33.7493
# Epoch 91/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 199ms/step - loss: 2413.6506 - mean_absolute_error: 33.8941 - val_loss: 2125.8718 - val_mean_absolute_error: 33.4530
# Epoch 92/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 200ms/step - loss: 2380.0896 - mean_absolute_error: 33.9343 - val_loss: 2115.1685 - val_mean_absolute_error: 33.5142
# Epoch 93/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 200ms/step - loss: 2396.3804 - mean_absolute_error: 33.2781 - val_loss: 2113.3230 - val_mean_absolute_error: 33.5278
# Epoch 94/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 199ms/step - loss: 2362.1553 - mean_absolute_error: 33.6846 - val_loss: 2133.7849 - val_mean_absolute_error: 33.5262
# Epoch 95/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 198ms/step - loss: 2394.2173 - mean_absolute_error: 33.4327 - val_loss: 2182.9192 - val_mean_absolute_error: 33.8229
# Epoch 96/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 203ms/step - loss: 2529.9551 - mean_absolute_error: 34.1916 - val_loss: 2150.5515 - val_mean_absolute_error: 33.6208
#
# ================================================================================
# FIT – LSTM RepeatVector H90 (VALID ONLY)
# ================================================================================
# Epoch 1/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 210ms/step - loss: 6151.6152 - mean_absolute_error: 58.5247 - val_loss: 5021.9424 - val_mean_absolute_error: 53.3923
# Epoch 2/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 203ms/step - loss: 6252.1455 - mean_absolute_error: 59.6624 - val_loss: 5015.0615 - val_mean_absolute_error: 53.3611
# Epoch 3/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 199ms/step - loss: 6019.8281 - mean_absolute_error: 58.8587 - val_loss: 5007.3447 - val_mean_absolute_error: 53.3274
# Epoch 4/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 197ms/step - loss: 6409.8662 - mean_absolute_error: 59.9599 - val_loss: 4999.4556 - val_mean_absolute_error: 53.2943
# Epoch 5/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 201ms/step - loss: 6300.0713 - mean_absolute_error: 59.6758 - val_loss: 4993.6304 - val_mean_absolute_error: 53.2747
# Epoch 6/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 197ms/step - loss: 6179.6172 - mean_absolute_error: 59.3646 - val_loss: 4989.4653 - val_mean_absolute_error: 53.2618
# Epoch 7/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 198ms/step - loss: 6092.5742 - mean_absolute_error: 58.6427 - val_loss: 4983.9600 - val_mean_absolute_error: 53.2462
# Epoch 8/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 199ms/step - loss: 6263.3672 - mean_absolute_error: 59.8406 - val_loss: 4977.8711 - val_mean_absolute_error: 53.2298
# Epoch 9/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 198ms/step - loss: 6252.4507 - mean_absolute_error: 59.4946 - val_loss: 4963.7744 - val_mean_absolute_error: 53.1870
# Epoch 10/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 199ms/step - loss: 5947.3472 - mean_absolute_error: 58.1836 - val_loss: 4960.1353 - val_mean_absolute_error: 53.1922
# Epoch 11/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 198ms/step - loss: 6134.6104 - mean_absolute_error: 58.8337 - val_loss: 4944.6748 - val_mean_absolute_error: 53.1229
# Epoch 12/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 200ms/step - loss: 6126.5649 - mean_absolute_error: 59.0654 - val_loss: 4948.8911 - val_mean_absolute_error: 53.1640
# Epoch 13/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 201ms/step - loss: 6115.0601 - mean_absolute_error: 58.6063 - val_loss: 4931.6909 - val_mean_absolute_error: 53.0806
# Epoch 14/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 199ms/step - loss: 6071.8530 - mean_absolute_error: 59.1122 - val_loss: 4918.8462 - val_mean_absolute_error: 52.9932
# Epoch 15/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 200ms/step - loss: 5989.6416 - mean_absolute_error: 58.2942 - val_loss: 4918.6284 - val_mean_absolute_error: 53.0184
# Epoch 16/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 201ms/step - loss: 5893.4170 - mean_absolute_error: 58.0517 - val_loss: 4906.9536 - val_mean_absolute_error: 52.9398
# Epoch 17/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 207ms/step - loss: 6278.3203 - mean_absolute_error: 60.0663 - val_loss: 4894.4404 - val_mean_absolute_error: 52.8654
# Epoch 18/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 200ms/step - loss: 6040.4712 - mean_absolute_error: 59.0826 - val_loss: 4876.2471 - val_mean_absolute_error: 52.7675
# Epoch 19/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 200ms/step - loss: 5757.6030 - mean_absolute_error: 57.7975 - val_loss: 4894.7070 - val_mean_absolute_error: 52.8965
# Epoch 20/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 202ms/step - loss: 6138.2168 - mean_absolute_error: 59.2687 - val_loss: 4901.8970 - val_mean_absolute_error: 52.9601
# Epoch 21/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 199ms/step - loss: 6064.8335 - mean_absolute_error: 59.4909 - val_loss: 4890.4229 - val_mean_absolute_error: 52.9080
# Epoch 22/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 203ms/step - loss: 6054.4678 - mean_absolute_error: 58.3370 - val_loss: 4902.5737 - val_mean_absolute_error: 53.0021
# Epoch 23/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 197ms/step - loss: 6136.1099 - mean_absolute_error: 59.1901 - val_loss: 4903.9644 - val_mean_absolute_error: 53.0266
# Epoch 24/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 201ms/step - loss: 6233.0264 - mean_absolute_error: 59.3435 - val_loss: 4888.6357 - val_mean_absolute_error: 52.9668
# Epoch 25/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 202ms/step - loss: 6124.9878 - mean_absolute_error: 58.8399 - val_loss: 4881.2295 - val_mean_absolute_error: 52.9483
# Epoch 26/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 202ms/step - loss: 6003.4170 - mean_absolute_error: 58.8476 - val_loss: 4893.1631 - val_mean_absolute_error: 52.9336
# Epoch 27/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 201ms/step - loss: 5975.1455 - mean_absolute_error: 58.8408 - val_loss: 4904.2710 - val_mean_absolute_error: 52.9898
# Epoch 28/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 202ms/step - loss: 6123.3457 - mean_absolute_error: 58.8113 - val_loss: 4903.1079 - val_mean_absolute_error: 52.9651
# Epoch 29/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 197ms/step - loss: 6051.2827 - mean_absolute_error: 59.2315 - val_loss: 4883.8887 - val_mean_absolute_error: 52.8696
# Epoch 30/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 201ms/step - loss: 5827.2271 - mean_absolute_error: 58.3334 - val_loss: 4874.3931 - val_mean_absolute_error: 52.7752
# Epoch 31/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 206ms/step - loss: 5790.9868 - mean_absolute_error: 57.8524 - val_loss: 4863.2104 - val_mean_absolute_error: 52.7081
# Epoch 32/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 213ms/step - loss: 5758.4263 - mean_absolute_error: 57.8448 - val_loss: 4858.9155 - val_mean_absolute_error: 52.7586
# Epoch 33/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 208ms/step - loss: 6072.4224 - mean_absolute_error: 58.9463 - val_loss: 4847.4795 - val_mean_absolute_error: 52.8429
# Epoch 34/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 202ms/step - loss: 6100.4761 - mean_absolute_error: 58.6465 - val_loss: 4846.8994 - val_mean_absolute_error: 52.8637
# Epoch 35/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 198ms/step - loss: 6149.8994 - mean_absolute_error: 58.9358 - val_loss: 4860.2729 - val_mean_absolute_error: 52.9642
# Epoch 36/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 200ms/step - loss: 6047.0698 - mean_absolute_error: 58.6233 - val_loss: 4859.2134 - val_mean_absolute_error: 52.9478
# Epoch 37/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 202ms/step - loss: 6116.4478 - mean_absolute_error: 59.1061 - val_loss: 4857.9297 - val_mean_absolute_error: 52.9195
# Epoch 38/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 200ms/step - loss: 6018.9668 - mean_absolute_error: 58.7569 - val_loss: 4857.8940 - val_mean_absolute_error: 52.8197
# Epoch 39/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 197ms/step - loss: 6103.4727 - mean_absolute_error: 59.2796 - val_loss: 4855.0317 - val_mean_absolute_error: 52.7120
# Epoch 40/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 203ms/step - loss: 5845.5859 - mean_absolute_error: 57.9780 - val_loss: 4863.1958 - val_mean_absolute_error: 52.7320
# Epoch 41/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 200ms/step - loss: 6121.2705 - mean_absolute_error: 58.9923 - val_loss: 4888.0151 - val_mean_absolute_error: 52.8865
# Epoch 42/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 201ms/step - loss: 6081.6152 - mean_absolute_error: 58.9898 - val_loss: 4890.8916 - val_mean_absolute_error: 52.9072
# Epoch 43/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 199ms/step - loss: 5992.6831 - mean_absolute_error: 58.4878 - val_loss: 4890.9795 - val_mean_absolute_error: 52.9148
# Epoch 44/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 202ms/step - loss: 6035.7002 - mean_absolute_error: 59.1481 - val_loss: 4880.7754 - val_mean_absolute_error: 52.8461
# Epoch 45/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 200ms/step - loss: 5768.1855 - mean_absolute_error: 57.6253 - val_loss: 4876.4272 - val_mean_absolute_error: 52.8259
# Epoch 46/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 201ms/step - loss: 5909.7510 - mean_absolute_error: 57.9238 - val_loss: 4864.1582 - val_mean_absolute_error: 52.7495

# %% [markdown]
# ### **8.4. Predicción y evaluación (VALID ONLY)**

# %%
# ============================================================
# PREDICCIÓN + EVALUACIÓN (VALID ONLY) – GRU RepeatVector
# ============================================================
# Objetivo:
# - Predecir sobre VALID para H60 y H90
# - Convertir y_true/y_pred a 2D (N, H) para usar compute_seq2seq_metrics
# - Calcular métricas ML (MAE, RMSE, R2, DA_last si aplica)
# ============================================================

import numpy as np
import pandas as pd


# -------------------------
# Helpers de forma (2D / 3D)
# -------------------------
def to_2d_y(y: np.ndarray) -> np.ndarray:
    """
    Normaliza y a 2D:
      - (N, H, 1) -> (N, H)
      - (N, H)    -> (N, H)
    """
    if y.ndim == 3 and y.shape[-1] == 1:
        return y[..., 0]
    if y.ndim == 2:
        return y
    raise ValueError(f"Forma inesperada para y: {y.shape}")


# -------------------------
# Predicción genérica (RepeatVector: GRU/LSTM)
# -------------------------
def predict_seq2seq_2d(bundle_h: dict, model, *, split: str = "valid") -> tuple[np.ndarray, np.ndarray]:
    """
    Predicción para modelos RepeatVector (un solo input X).
    Retorna:
      - y_true_2d: (N, H)
      - y_pred_2d: (N, H)
    """
    # X del split
    X = bundle_h[split]["X"]

    # y verdadero desde el bundle (puede venir 2D o 3D)
    y_true_2d = to_2d_y(bundle_h[split]["y"])

    # Predicción del modelo:
    # - LSTM RepeatVector entrega (N, H, 1)
    y_pred_3d = model.predict(X, verbose=0)

    # Convertimos a 2D (N, H) para métricas
    y_pred_2d = to_2d_y(y_pred_3d)

    return y_true_2d, y_pred_2d

# %%
def metrics_to_df(metrics: dict, *, model: str, split: str, horizon: int) -> pd.DataFrame:
    """
    Convierte dict de métricas a tabla (1 fila).
    """
    return pd.DataFrame([{
        "model": model,
        "split": split,
        "horizon_min": horizon,
        "MAE": metrics["MAE"],
        "RMSE": metrics["RMSE"],
        "R2": metrics.get("R2"),
        "DA_last": metrics.get("DA_last"),
    }])

# %% [markdown]
# ### **8.5. Flujo completo para H60 y H90**

# %%
# -------------------------
# H60 (VALID ONLY)
# -------------------------
y_true_60, y_pred_60 = predict_seq2seq_2d(bundle_60, model_lstm_60, split="valid")
ml_valid_60 = compute_seq2seq_metrics(y_true_60, y_pred_60, compute_r2=True)

# %%
# -------------------------
# H90 (VALID ONLY)
# -------------------------
y_true_90, y_pred_90 = predict_seq2seq_2d(bundle_90, model_lstm_90, split="valid")
ml_valid_90 = compute_seq2seq_metrics(y_true_90, y_pred_90, compute_r2=True)

# %% [markdown]
# ## **8. Métricas ML**

# %%
# -------------------------
# Tabla final (VALID ONLY)
# -------------------------
df_valid_60 = metrics_to_df(ml_valid_60, model="lstm", split="valid", horizon=60)
df_valid_90 = metrics_to_df(ml_valid_90, model="lstm", split="valid", horizon=90)

pd.concat([df_valid_60, df_valid_90], ignore_index=True)
# Out:
#   model  split  horizon_min        MAE       RMSE        R2   DA_last
# 0  lstm  valid           60  33.374448  45.860811  0.163114  0.541237
# 1  lstm  valid           90  52.863677  69.619643  0.036110  0.515464

# %% [markdown]
# ## **10. Guardar artefactos para Stage_08**

# %%
def save_json(obj: Dict[str, Any], path: Path) -> None:
    """Guarda un diccionario como JSON, creando directorios si es necesario."""
    path.parent.mkdir(parents=True, exist_ok=True)
    with path.open("w", encoding="utf-8") as f:
        json.dump(obj, f, indent=2, ensure_ascii=False)

# %%
from pathlib import Path
from typing import Any, Dict
import numpy as np

def save_evaluation_artifacts(
    *,
    out_dir: Path,
    model_name: str,
    horizon: int,
    ml_valid: Dict[str, Any],
    y_valid: np.ndarray | None = None,
    y_pred_valid: np.ndarray | None = None,
    save_preds: bool = True,
) -> None:
    """
    Guarda SOLO artefactos de VALID (coherente con el esquema del libro):
      - metrics_ml_valid.json
      - pred_valid.npz (opcional)

    No guarda nada de TEST.
    """
    out_dir.mkdir(parents=True, exist_ok=True)

    # -------------------------
    # Métricas ML (VALID)
    # -------------------------
    save_json(
        {
            "model": model_name,
            "horizon_min": horizon,
            "split": "valid",
            **ml_valid,
        },
        out_dir / "metrics_ml_valid.json",
    )

    # -------------------------
    # Predicciones OOS (VALID) - opcional
    # -------------------------
    if save_preds:
        if y_valid is None or y_pred_valid is None:
            raise ValueError("Si save_preds=True, debe pasar y_valid y y_pred_valid.")
        np.savez_compressed(
            out_dir / "pred_valid.npz",
            y_true=np.asarray(y_valid),
            y_pred=np.asarray(y_pred_valid),
        )

    print(f"OK - artefactos guardados en: {out_dir}")

# %%
OUT_DIR_60 = Path("artifacts/04_lstm/h60")
OUT_DIR_60 = DRIVE_DIR / OUT_DIR_60 #Solo para la notebook

save_evaluation_artifacts(
    out_dir=OUT_DIR_60,
    model_name="lstm_h60",
    horizon=60,
    ml_valid=ml_valid_60,
    y_valid=y_true_60,        # ← 2D seguro
    y_pred_valid=y_pred_60,   # ← 2D
    save_preds=False,
)
# Out:
# OK - artefactos guardados en: /content/drive/MyDrive/neural_profit/artifacts/04_lstm/h60

# %%
OUT_DIR_90 = Path("artifacts/04_lstm/h90")
OUT_DIR_90 = DRIVE_DIR / OUT_DIR_90 #Solo para la notebook

save_evaluation_artifacts(
    out_dir=OUT_DIR_90,
    model_name="lstm_h90",
    horizon=90,
    ml_valid=ml_valid_90,
    y_valid=y_true_90,
    y_pred_valid=y_pred_90,
    save_preds=False,
)
# Out:
# OK - artefactos guardados en: /content/drive/MyDrive/neural_profit/artifacts/04_lstm/h90

# %% [markdown]
# ## **11. Resumen**

# %% [markdown]
# - **Métricas ML (test):** MAE, RMSE, DA_last, R2
# - **Métricas económicas como filtro (test):** Precision, Opportunity_Recall, Coverage
# - Artefactos guardados en `reports/stage_07/h{H}/<model_name>/`

# %% [markdown]
# H = 60: el LSTM mejora levemente la direccionalidad (DA ≈ 54%), pero no supera al GRU ni al MLP en error ni en R². Indica mejor captura del signo, pero con menor precisión en magnitud.
#
# H = 90: desempeño débil, con R² cercano a cero y errores altos; la memoria de largo plazo no aporta ventaja clara en este horizonte.
#
# Conclusión general: el LSTM no justifica su mayor complejidad frente a GRU/MLP en este setup intradía; aporta algo en dirección a corto plazo (H60), pero no en magnitud ni estabilidad.
