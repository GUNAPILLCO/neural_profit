# %% [markdown]
# <a href="https://colab.research.google.com/github/GUNAPILLCO/neural_profit/blob/main/stage_06_model_training/seq2one/stage_06_08_transformer_seq2one.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Stage_06_08 - SEQ2ONE - Transformer**

# %% [markdown]
# El Transformer es un modelo basado en self-attention que procesa secuencias completas en paralelo, sin recurrencia. En el esquema many-to-one, el modelo recibe una ventana temporal de múltiples pasos (many) y produce una única salida agregada (one), típicamente usando el embedding del último token o un pooling sobre la secuencia.
#
# Su ventaja clave es capturar dependencias de largo alcance de forma eficiente, con alta escalabilidad y estabilidad en el entrenamiento frente a RNN/LSTM.

# %% [markdown]
# # **BLOQUE DE EJECUCIÓN COMPLETO**

# %% [markdown]
# ## **1. Imports + paths**

# %%
# Permite anotaciones modernas en Python < 3.11.
from __future__ import annotations

import os
import json
import time
import random
from pathlib import Path
import numpy as np

import numpy as np
from typing import Any, Dict, List, Iterable, Tuple
# Si usa sklearn en algún modelo/baseline
# from sklearn.linear_model import Ridge

# Dataclass: contenedor simple e inmutable para configuración.
from dataclasses import dataclass
# Joblib para cargar scalers .pkl (sklearn).
import joblib

from pathlib import Path
import sys
import importlib

# %% [markdown]
# ## **2. Acceso a drive**

# %%
from google.colab import drive
drive.mount('/content/drive')

# --------------------------------------------------
# Ruta base en Google Drive
# --------------------------------------------------
# Ajuste si su estructura cambia
DRIVE_DIR =   Path(os.environ.get("DRIVE_DIR", "/content/drive/MyDrive/neural_profit/"))
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## **3. Rutas de ventanas seq2one y scalers**

# %%
from pathlib import Path
import os

WINDOWS_SEQ2ONE_DIR = Path(
    os.environ.get("WINDOWS_SEQ2ONE_DIR", "data/windows/seq2one/")
)

SCALERS_DIR = Path(
    os.environ.get("SCALERS_DIR", "data/scaled/")
)

window_sizes = [30, 60, 90, 120, 180]
targets = ['delta_60', 'delta_90', 'ret_60', 'ret_90']
splits = ['train', 'valid', 'test']

# %%
windows_paths = {}

for w in window_sizes:
    windows_paths[w] = {}

    for t in targets:
        windows_paths[w][t] = {}

        for s in splits:
            path = (
                DRIVE_DIR
                / WINDOWS_SEQ2ONE_DIR
                / f"L{w}"
                / f"windows_{t}_{s}.npz"
            )

            windows_paths[w][t][s] = path

#display(windows_paths)

#Como llamarlo:
#path_train_L60_delta = windows_paths[60]['delta_90']['train']
#print(path_train_L60_delta)

# %%
scalers_paths = {}
for t in targets:
  scalers_paths[t] = {}
  path = (
                DRIVE_DIR
                / SCALERS_DIR
                / f"scaler_{t}.pkl"
            )

  scalers_paths[t] = path

display(scalers_paths)
# Out:
# {'delta_60': PosixPath('/content/drive/MyDrive/neural_profit/data/scaled/scaler_delta_60.pkl'),
#  'delta_90': PosixPath('/content/drive/MyDrive/neural_profit/data/scaled/scaler_delta_90.pkl'),
#  'ret_60': PosixPath('/content/drive/MyDrive/neural_profit/data/scaled/scaler_ret_60.pkl'),
#  'ret_90': PosixPath('/content/drive/MyDrive/neural_profit/data/scaled/scaler_ret_90.pkl')}

# %% [markdown]
# ## **4. Reproducibilidad**

# %%
def set_seeds(seed: int = 42) -> None:
    random.seed(seed)
    np.random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)

set_seeds(42)

# %% [markdown]
# ## **5. Importar métricas comunes desde .py**

# %%
# 1) Define el root del proyecto (DEBE existir en esta misma celda)
DRIVE_DIR =   Path(os.environ.get("DRIVE_DIR", "/content/drive/MyDrive/neural_profit/"))

# 2) Agrega el root al PYTHONPATH (antes de importar)
if str(DRIVE_DIR) not in sys.path:
    sys.path.insert(0, str(DRIVE_DIR))  # insert(0) para priorizarlo

# 3) Asegura que metrics sea paquete Python
(DRIVE_DIR / "metrics" / "__init__.py").touch(exist_ok=True)

# 4) Invalida cachés de import (importante en Colab)
importlib.invalidate_caches()

# 5) Diagnóstico (le muestra qué ve Python)
#print("DRIVE_DIR:", DRIVE_DIR)
#print("sys.path[0]:", sys.path[0])
#print("metrics exists:", (DRIVE_DIR / "metrics").exists())
#print("metrics __init__:", (DRIVE_DIR / "metrics" / "__init__.py").exists())

# 6) Imports reales
from metrics.seq2one_metrics import compute_seq2one_metrics
#from metrics.opportunity_filter_metrics import compute_opportunity_filter_metrics

print("OK - imports metrics.*")
# Out:
# OK - imports metrics.*

# %%
print(compute_seq2one_metrics.__doc__)
# Out:
#     Calcula métricas simples y comparables para modelos seq2one.
#
#     Parámetros
#     ----------
#     y_true : np.ndarray
#         Valores reales con shape (n_samples,), (n_samples, 1)
#         (opcional) (n_samples, seq_len) si allow_seq_inputs_take_last=True.
#     y_pred : np.ndarray
#         Valores predichos con shape (n_samples,), (n_samples, 1)
#         (opcional) (n_samples, seq_len) si allow_seq_inputs_take_last=True.
#     compute_r2 : bool
#         Si True, calcula R² sobre el vector completo.
#     da_ignore_zeros : bool
#         Si True, ignora casos donde el signo sea 0 en y_true o y_pred al calcular DA.
#     allow_seq_inputs_take_last : bool
#         Si True, permite inputs 2D (n_samples, seq_len) y toma el último paso [:, -1].
#         Útil si algún modelo devuelve secuencia pero usted lo evalúa como many-to-one.
#
#     Retorna
#     -------
#     metrics : dict
#         Diccionario con métricas globales.

# %% [markdown]
# ## **6. Carga de data windows**

# %%
def load_npz_windows(path: Path) -> Tuple[np.ndarray, np.ndarray]:
    """
    Carga ventanas X e y desde un archivo .npz estándar.
    """

    if not path.exists():
        raise FileNotFoundError(f"No se encontró el archivo: {path}")

    # Usar contexto para cerrar correctamente el archivo
    with np.load(path) as data:

        if "X" not in data:
            raise KeyError(f"NPZ inválido (falta clave 'X'): {path}")
        X = data["X"]

        if "y" in data:
            y = data["y"]
        elif "Y" in data:
            y = data["Y"]
        else:
            raise KeyError(f"NPZ inválido (falta clave 'y'/'Y'): {path}")

        # Opcional pero recomendable: copiar a memoria
        X = X.copy()
        y = y.copy()

    return X, y

# %%
# --------------------------------------------------
# Función común: carga scaler .pkl (sklearn)
# --------------------------------------------------
def load_scaler(path: Path) -> Any:
    """
    Carga un scaler serializado con joblib (ej. StandardScaler/MinMaxScaler).
    """
    # Verifica existencia del archivo.
    if not path.exists():
        raise FileNotFoundError(f"No se encontró el scaler: {path}")

    # Carga el objeto scaler.
    scaler = joblib.load(path)

    # Devuelve scaler (tipo genérico).
    return scaler

# %%
from typing import Any, Dict, Mapping
from pathlib import Path

def load_windows_and_scaler(
    *,
    window_size: int,
    target: str,
    windows_paths: Mapping[int, Mapping[str, Mapping[str, Path]]],
    scalers_path: Mapping[str, Path],
    splits: tuple[str, ...] = ("train", "valid", "test"),
) -> Dict[str, Any]:
    """
    Carga X/y para los splits solicitados y el scaler correspondiente
    a un (window_size, target).

    windows_paths[L][target][split] -> Path (.npz con X,y)
    scalers_path[target] -> Path (scaler)
    """

    # --------------------------
    # 1) Validaciones base
    # --------------------------
    if window_size not in windows_paths:
        raise KeyError(f"window_size={window_size} no existe en windows_paths")

    if target not in windows_paths[window_size]:
        raise KeyError(f"target='{target}' no existe en windows_paths[{window_size}]")

    if target not in scalers_path:
        raise KeyError(f"target='{target}' no existe en scalers_path")

    valid_splits = {"train", "valid", "test"}
    splits_set = set(splits)
    unknown = splits_set - valid_splits
    if unknown:
        raise ValueError(f"splits inválidos: {sorted(unknown)}. Usar {sorted(valid_splits)}")

    # Validar que existan los splits solicitados para ese target
    available = set(windows_paths[window_size][target].keys())
    missing = splits_set - available
    if missing:
        raise KeyError(
            f"Faltan splits {sorted(missing)} en windows_paths[{window_size}]['{target}']. "
            f"Disponibles: {sorted(available)}"
        )

    # --------------------------
    # 2) Paths (solo los necesarios)
    # --------------------------
    split_paths: Dict[str, Path] = {sp: windows_paths[window_size][target][sp] for sp in splits}
    scaler_path = scalers_path[target]

    # --------------------------
    # 3) Carga por split
    # --------------------------
    out_splits: Dict[str, Dict[str, Any]] = {}
    out_paths: Dict[str, str] = {}

    for sp, p in split_paths.items():
        X, y = load_npz_windows(p)
        out_splits[sp] = {"X": X, "y": y}
        out_paths[sp] = str(p)

    scaler = load_scaler(scaler_path)
    out_paths["scaler"] = str(scaler_path)

    # --------------------------
    # 4) Inferir horizonte (robusto)
    # --------------------------
    try:
        horizon = int(target.split("_")[-1])
    except Exception as e:
        raise ValueError(f"No se pudo inferir horizon desde target='{target}'. Esperado sufijo '_<int>'") from e

    # --------------------------
    # 5) Retorno
    # --------------------------
    out: Dict[str, Any] = {
        "window_size": window_size,
        "target": target,
        "horizon": horizon,
        "paths": out_paths,
        "scaler": scaler,
    }
    out.update(out_splits)

    return out

# %%
import numpy as np

def maybe_flatten_X(X: np.ndarray, *, flatten: bool) -> np.ndarray:
    """
    Si flatten=True y X es 3D (N,L,F) -> (N, L*F)
    Si flatten=False -> retorna X tal cual.
    """
    if not flatten:
        return X
    if X.ndim == 3:
        N, L, F = X.shape
        return X.reshape(N, L * F)
    if X.ndim == 2:
        return X
    raise ValueError(f"X debe ser 2D o 3D, recibí shape={X.shape}")

# %%
def create_bundles(
    window_size,
    targets: list,
    windows_paths=windows_paths,
    scalers_paths=scalers_paths,
    *,
    flatten_X: bool = False,
    splits: tuple[str, ...] = ("train", "valid", "test"),
    verbose_shapes: bool = True,
    ):
    bundles = []
    for t in targets:
        b = load_windows_and_scaler(
            window_size=window_size,
            target=t,
            windows_paths=windows_paths,
            scalers_path=scalers_paths,
            splits=splits,
        )

        if flatten_X:
            for sp in splits:
                b[sp]["X"] = maybe_flatten_X(b[sp]["X"], flatten=True)

        bundles.append(b)

    if verbose_shapes:
        for b in bundles:
            for sp in splits:
                print(f"H{b['horizon']} {sp.capitalize():<5}:", b[sp]["X"].shape, b[sp]["y"].shape)
            print(f"Scaler H{b['horizon']}:", type(b["scaler"]).__name__)

    return tuple(bundles)

# %% [markdown]
# NOTA IMPORTANTE: COMO ACCEDER A LAS VENTANAS
#
# Para el horizonte: `h`
#
#   - Train
#     - `X`: `bundle_h["train"]["X"]`
#     - `y`: `bundle_h["train"]["y"]`
#
#   - Valid
#     - `X`: `bundle_h["valid"]["X"]`
#     - `y`:`bundle_h["valid"]["y"]`
#
#   - Test
#     - `X`: `bundle_h["test"]["X"]`
#     - `y`: `bundle_h["test"]["y"]`
#
#   - Scaler
#     - `bundle_h["scaler"]`

# %% [markdown]
# ## **7. Sanity Check**

# %%
from __future__ import annotations

from typing import Any, Dict, Optional, Tuple
import numpy as np


# ============================================================
# 1) Utilidades internas (inferencias y normalización)
# ============================================================

def _as_float_array(a: Any, *, name: str) -> np.ndarray:
    """Convierte a np.ndarray float64 y valida finitud."""
    arr = np.asarray(a, dtype=np.float64)
    if arr.size == 0:
        raise ValueError(f"{name} está vacío. shape={arr.shape}")
    if not np.isfinite(arr).all():
        raise ValueError(f"{name} contiene NaN/inf. Limpie antes de continuar. shape={arr.shape}")
    return arr


def _normalize_y_seq2one(y: np.ndarray, *, name: str = "y") -> np.ndarray:
    """
    Normaliza y para seq2one a shape (n_samples,).
    Acepta: (n,), (n,1). Rechaza shapes incompatibles.
    """
    if y.ndim == 1:
        return y
    if y.ndim == 2 and y.shape[1] == 1:
        return y.squeeze(1)
    raise ValueError(f"{name} shape inválido para seq2one. Se esperaba (n,) o (n,1). Recibido {y.shape}")


def _infer_seq_len_and_n_features(X: np.ndarray) -> Tuple[int, Optional[int], str]:
    """
    Infiera (seq_len, n_features, mode) desde X.
    mode:
      - "3d": X=(n, seq_len, n_features)
      - "2d": X=(n, d_flat)  -> n_features=None
    """
    if X.ndim == 3:
        return int(X.shape[1]), int(X.shape[2]), "3d"
    if X.ndim == 2:
        return int(X.shape[1]), None, "2d"
    raise ValueError(f"X.ndim inválido. Se esperaba 2D o 3D. Recibido X.shape={X.shape}")

# %%
# ============================================================
# 2) Sanity check principal (seq2one)
# ============================================================

def sanity_check_seq2one(
    X: Any,
    y: Any,
    split_name: str,
    *,
    expected_seq_len: Optional[int] = None,
    expected_n_features: Optional[int] = None,
    expected_flat_dim: Optional[int] = None,
    allow_seq_inputs_take_last: bool = False,
    verbose: bool = True,
) -> Dict[str, Any]:
    """
    Sanity check para datasets seq2one.

    Soporta:
      - X 3D: (n, seq_len, n_features)
      - X 2D: (n, d_flat)  [ventana aplanada]

    y soporta:
      - y 1D: (n,)
      - y 2D: (n,1)

    Parámetros
    ----------
    expected_seq_len:
        Para X 3D: valida seq_len.
        Para X 2D: si expected_flat_dim no está, puede usarse como "d_flat" esperado.
    expected_n_features:
        Solo aplica a X 3D.
    expected_flat_dim:
        Solo aplica a X 2D (d_flat esperado). Ej: 60*20=1200.
    allow_seq_inputs_take_last:
        Si y viniera como (n, seq_len) (caso raro), permite tomar y[:, -1].
        Por defecto False (recomendado).
    """
    X = _as_float_array(X, name=f"X[{split_name}]")
    y = _as_float_array(y, name=f"y[{split_name}]")

    # Normalizar y
    if y.ndim == 2 and y.shape[1] != 1 and allow_seq_inputs_take_last:
        # caso tolerante: y=(n,seq_len) -> tomar último
        y = y[:, -1]
    y = _normalize_y_seq2one(y, name=f"y[{split_name}]")

    # Inferir modo y dimensiones de X
    seq_len, n_features, mode = _infer_seq_len_and_n_features(X)
    n_samples = int(X.shape[0])

    # Validaciones básicas n_samples
    if y.shape[0] != n_samples:
        raise ValueError(
            f"Mismatch n_samples en {split_name}: X tiene n={n_samples}, y tiene n={y.shape[0]}"
        )

    # Validación de shapes según modo
    if mode == "3d":
        # expected_seq_len / expected_n_features
        if expected_seq_len is not None and seq_len != int(expected_seq_len):
            raise ValueError(
                f"{split_name}: seq_len esperado={expected_seq_len}, recibido={seq_len}. X.shape={X.shape}"
            )
        if expected_n_features is not None and n_features != int(expected_n_features):
            raise ValueError(
                f"{split_name}: n_features esperado={expected_n_features}, recibido={n_features}. X.shape={X.shape}"
            )

    elif mode == "2d":
        d_flat = int(X.shape[1])

        # Si expected_flat_dim está, valida contra eso
        if expected_flat_dim is not None and d_flat != int(expected_flat_dim):
            raise ValueError(
                f"{split_name}: d_flat esperado={expected_flat_dim}, recibido={d_flat}. X.shape={X.shape}"
            )

        # Si no hay expected_flat_dim pero sí expected_seq_len, úselo como d_flat esperado
        if expected_flat_dim is None and expected_seq_len is not None and d_flat != int(expected_seq_len):
            raise ValueError(
                f"{split_name}: d_flat esperado={expected_seq_len}, recibido={d_flat}. X.shape={X.shape}"
            )

        # expected_n_features no aplica en 2D
        if expected_n_features is not None:
            raise ValueError(
                f"{split_name}: expected_n_features no aplica para X 2D. "
                f"Use expected_flat_dim (ej: 1200) o pase X en 3D."
            )

    # Validación extra: varianza de y (para detectar targets constantes)
    y_std = float(np.std(y))
    if verbose:
        info = {
            "split": split_name,
            "X_shape": tuple(X.shape),
            "y_shape": tuple(y.shape),
            "mode": mode,
            "seq_len": seq_len if mode == "3d" else None,
            "n_features": n_features if mode == "3d" else None,
            "flat_dim": int(X.shape[1]) if mode == "2d" else None,
            "y_mean": float(np.mean(y)),
            "y_std": y_std,
            "y_min": float(np.min(y)),
            "y_max": float(np.max(y)),
        }
        print(
            f"[sanity_check_seq2one] {split_name} | X={info['X_shape']} | y={info['y_shape']} | "
            f"mode={mode} | y_std={y_std:.6f}"
        )

    return {
        "split": split_name,
        "X_shape": tuple(X.shape),
        "y_shape": tuple(y.shape),
        "mode": mode,
        "seq_len": seq_len if mode == "3d" else None,
        "n_features": n_features if mode == "3d" else None,
        "flat_dim": int(X.shape[1]) if mode == "2d" else None,
        "y_mean": float(np.mean(y)),
        "y_std": float(np.std(y)),
        "y_min": float(np.min(y)),
        "y_max": float(np.max(y)),
    }

# %%
# ============================================================
# 3) Sanity checks por bundle (train/valid/test)
# ============================================================

def run_sanity_checks_for_bundle_seq2one(
    bundle: Dict[str, Any],
    *,
    tag: str,
    expected_seq_len: Optional[int] = None,
    expected_n_features: Optional[int] = None,
    expected_flat_dim: Optional[int] = None,
    verbose: bool = True,
) -> Dict[str, Any]:
    """
    Ejecuta sanity checks para un bundle con estructura:

    {
      "horizon": 60,
      "train": {"X":..., "y":...},
      "valid": {"X":..., "y":...},
      "test":  {"X":..., "y":...},
    }

    Detecta automáticamente si X es 2D o 3D, y usa TRAIN como referencia
    si no se pasan expected_*.
    """
    X_tr = bundle["train"]["X"]
    y_tr = bundle["train"]["y"]
    X_va = bundle["valid"]["X"]
    y_va = bundle["valid"]["y"]
    X_te = bundle["test"]["X"]
    y_te = bundle["test"]["y"]

    X_tr_arr = np.asarray(X_tr)
    seq_len_tr, n_feat_tr, mode_tr = _infer_seq_len_and_n_features(X_tr_arr)

    # Setear esperados desde TRAIN si no se dieron
    if mode_tr == "3d":
        if expected_seq_len is None:
            expected_seq_len = seq_len_tr
        if expected_n_features is None:
            expected_n_features = n_feat_tr
        # En 3D no hace falta expected_flat_dim
        expected_flat_dim = None
    else:
        d_flat_tr = int(X_tr_arr.shape[1])
        if expected_flat_dim is None:
            expected_flat_dim = d_flat_tr
        # Para evitar confusión, no usamos expected_seq_len/n_features en 2D
        expected_seq_len = expected_seq_len  # puede quedar None
        expected_n_features = None

    # Ejecutar checks
    out_tr = sanity_check_seq2one(
        X_tr, y_tr, f"train_{tag}",
        expected_seq_len=expected_seq_len,
        expected_n_features=expected_n_features,
        expected_flat_dim=expected_flat_dim,
        verbose=verbose,
    )
    out_va = sanity_check_seq2one(
        X_va, y_va, f"valid_{tag}",
        expected_seq_len=expected_seq_len,
        expected_n_features=expected_n_features,
        expected_flat_dim=expected_flat_dim,
        verbose=verbose,
    )
    out_te = sanity_check_seq2one(
        X_te, y_te, f"test_{tag}",
        expected_seq_len=expected_seq_len,
        expected_n_features=expected_n_features,
        expected_flat_dim=expected_flat_dim,
        verbose=verbose,
    )

    h = bundle.get("horizon", "NA")
    if verbose:
        print(f"OK {tag} (h={h})")

    return {"train": out_tr, "valid": out_va, "test": out_te, "horizon": h}


def run_sanity_checks_all_horizons_seq2one(
    bundle_60: Dict[str, Any],
    bundle_90: Dict[str, Any],
    *,
    verbose: bool = True,
) -> Dict[str, Any]:
    """Corre sanity checks para ambos horizontes (ej: 60 y 90)."""
    out_60 = run_sanity_checks_for_bundle_seq2one(bundle_60, tag="h60", verbose=verbose)
    out_90 = run_sanity_checks_for_bundle_seq2one(bundle_90, tag="h90", verbose=verbose)
    return {"h60": out_60, "h90": out_90}

# %%
#summary_delta = run_sanity_checks_all_horizons_seq2one(bundle_delta_60, bundle_delta_90)
#summary_ret = run_sanity_checks_all_horizons_seq2one(bundle_ret_60, bundle_ret_90)

# %% [markdown]
# ## **8. Métricas ML**

# %%
import pandas as pd

def metrics_to_df(
    metrics: dict,
    *,
    model: str,
    split: str,
    horizon: int,
    window_size: int,
    target: str,
) -> pd.DataFrame:
    """
    Convierte un dict de métricas seq2one en una fila de DataFrame.
    """

    return pd.DataFrame([{
        "model": model,
        "split": split,
        "window_size": window_size,
        "target": target,
        "horizon_min": horizon,
        "MAE": metrics["MAE"],
        "RMSE": metrics["RMSE"],
        "R2": metrics.get("R2"),
        "DA": metrics.get("DA"),
    }])

# %% [markdown]
# ## **9. Gestión de dataset de métricas**

# %%
def load_seq2one_metrics_if_exists(
    *,
    name: str,
    base_dir: str = "/content/drive/MyDrive/neural_profit/metrics/seq2one_metrics",
) -> pd.DataFrame:
    path = Path(base_dir) / f"seq2one_{name}_metrics.parquet"
    if path.exists():
        return pd.read_parquet(path)
    return pd.DataFrame()

# %%
from pathlib import Path
import pandas as pd

def save_seq2one_metrics(
    df_metrics: pd.DataFrame,
    *,
    name: str,
    base_dir: str = "/content/drive/MyDrive/neural_profit/metrics/seq2one_metrics",
) -> Path:
    """
    Guarda un DataFrame de métricas seq2one en formato Parquet.

    Parámetros
    ----------
    df_metrics : pd.DataFrame
        DataFrame con métricas (una fila por modelo/horizonte/split).
    name : str
        Nombre identificador del archivo (ej: 'naive_valid', 'ridge_valid').
        No incluir extensión.
    base_dir : str
        Directorio base donde se almacenan todas las métricas seq2one.

    Retorna
    -------
    out_path : Path
        Ruta completa del archivo guardado.
    """
    out_dir = Path(base_dir)
    out_dir.mkdir(parents=True, exist_ok=True)

    out_path = out_dir / f"seq2one_{name}_metrics.parquet"
    df_metrics.to_parquet(out_path, index=False)

    print(f"[OK] Métricas guardadas en: {out_path}")
    return out_path

# %%
import gc, torch
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

gc.collect()
torch.cuda.empty_cache()

# %% [markdown]
# # **DEFINICIÓN DE MODELO**

# %% [markdown]
# ## **10. Definición del modelo — placeholder**

# %% [markdown]
# ### **10.1. Modelo Transformer — seq2one**

# %% [markdown]
# **Idea básica**
#
# El **Transformer** es un modelo de aprendizaje profundo basado en el
# mecanismo de **self-attention**, diseñado para modelar dependencias
# temporales **sin recurrencia** y con procesamiento completamente
# paralelo de la secuencia de entrada.
#
# En el esquema **many-to-one**, el modelo recibe una **ventana temporal**
# de múltiples pasos (many) y produce **un único valor escalar futuro**
# (one), asociado al final de la ventana.
#
# A diferencia del MLP, el Transformer **preserva explícitamente la
# estructura temporal**, permitiendo que cada instante de la secuencia
# atienda a cualquier otro instante según su relevancia para la
# predicción final.
#
# Formalmente, el modelo puede representarse como:
#
# $$
# \hat{y}_t = g\Big( \text{Pool}\big( \text{TransformerEncoder}(X_t) \big) \Big)
# $$
#
# donde:
# - $X_t \in \mathbb{R}^{T \times F}$ es la ventana temporal (longitud $T$, $F$ features),
# - $\text{TransformerEncoder}(\cdot)$ aplica capas de self-attention y feedforward,
# - $\text{Pool}(\cdot)$ es una agregación temporal (último token, mean pooling, etc.),
# - $g(\cdot)$ es una capa densa final que produce el target escalar.
#
# ---
#
# **Regularización (Transformer)**
#
# **Riesgo:** Alto, debido a la elevada capacidad del modelo.
#
# El Transformer incorpora **regularización parcial de forma intrínseca**,
# pero requiere control explícito:
#
# - **Dropout (intrínseco):**
#   - Aplicado en self-attention y capas feedforward.
# - **Early stopping:**
#   - Fundamental para evitar sobreajuste.
# - **Dimensión del embedding controlada:**
#   - Evita representaciones excesivamente complejas.
# - **Número limitado de capas encoder:**
#   - 1–3 capas en escenarios de datos financieros.
# - **Weight decay (opcional):**
#   - Refuerza la estabilidad del entrenamiento.
#
# ---
#
# **Por qué el Transformer es relevante en este proyecto**
#
# - Capacidad para capturar:
#   - dependencias **de largo alcance**,
#   - relaciones temporales no locales.
# - Adecuado para:
#   - ventanas largas (60–90 minutos),
#   - múltiples indicadores técnicos simultáneos.
# - Entrenamiento:
#   - paralelo y estable,
#   - más escalable que LSTM/GRU.
#
# El Transformer representa el **primer modelo plenamente atencional**
# del pipeline, sirviendo como referencia frente a arquitecturas
# secuenciales (LSTM, GRU) y convolucionales (TCN).
#
# ---
#
# **Hiperparámetros iniciales**
#
# Para este stage (sin tuning):
#
# - Número de capas encoder: 1–2
# - Dimensión del embedding: moderada (32–64)
# - Número de cabezas de atención: 2–4
# - Dropout: activado
# - Pooling temporal: último token o mean pooling
# - Early stopping: activado
# - **Sin tuning exhaustivo** (optimización posterior)
#
# El ajuste fino de profundidad, atención y regularización se aborda en
# etapas posteriores del proyecto.

# %% [markdown]
# ### **10.2. Imports y “seed” (base reproducible)**

# %%
# Paso 1: imports básicos + reproducibilidad (sin tqdm)
import os
import json
import random
from pathlib import Path
from typing import Dict, Any, Tuple

import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset

# %%
def set_seed(seed: int = 42) -> None:
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    # reproducibilidad (puede bajar performance, pero estable)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(42)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("device:", device)
# Out:
# device: cuda

# %% [markdown]
# ### **10.3. TensorDataset + DataLoader (PyTorch)**

# %%
# Paso 3: TensorDataset y DataLoaders para H60 y H90 (sin tqdm)

import numpy as np
import torch
from torch.utils.data import DataLoader, TensorDataset

def make_loaders_from_bundle_3d(
    bundle: dict,
    *,
    seq_len: int | None = None,
    n_features: int | None = None,
    batch_size: int = 1024,
    num_workers: int = 2,
) -> dict:
    """
    Crea loaders train/valid/test para TRANSFORMER many-to-one.

    Espera:
      - X: (n, seq_len, n_features)  (ya 3D)
      - y: (n,) o (n,1)  -> (n,1)

    Si seq_len/n_features se pasan, valida consistencia.
    """
    loaders = {}

    for split in ["train", "valid", "test"]:
        X = np.asarray(bundle[split]["X"], dtype=np.float32)
        y = np.asarray(bundle[split]["y"], dtype=np.float32).reshape(-1, 1)

        if X.ndim != 3:
            raise ValueError(
                f"[{split}] Se esperaba X 3D (n, seq_len, n_features). "
                f"Recibido shape={X.shape} (ndim={X.ndim})."
            )

        n, sl, nf = X.shape

        if seq_len is not None and sl != int(seq_len):
            raise ValueError(f"[{split}] seq_len esperado={seq_len}, recibido={sl}. shape={X.shape}")

        if n_features is not None and nf != int(n_features):
            raise ValueError(f"[{split}] n_features esperado={n_features}, recibido={nf}. shape={X.shape}")

        if y.shape[0] != n:
            raise ValueError(f"[{split}] X e y no alinean: X n={n}, y n={y.shape[0]}.")

        ds = TensorDataset(torch.from_numpy(X), torch.from_numpy(y))
        shuffle = (split == "train")

        loaders[split] = DataLoader(
            ds,
            batch_size=batch_size,
            shuffle=shuffle,
            num_workers=num_workers,
            pin_memory=torch.cuda.is_available(),
            drop_last=False,
        )

    return loaders

# %% [markdown]
# ### **10.4. Definición de modelo Transformer (many-to-one)**

# %%
import math
import torch
import torch.nn as nn

class PositionalEncoding(nn.Module):
    def __init__(self, d_model: int, dropout: float = 0.1, max_len: int = 2048):
        super().__init__()
        self.dropout = nn.Dropout(dropout)

        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float32).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2, dtype=torch.float32) * (-math.log(10000.0) / d_model))

        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)

        self.register_buffer("pe", pe.unsqueeze(0))  # (1, max_len, d_model)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        # x: (B, L, d_model)
        L = x.size(1)
        x = x + self.pe[:, :L, :]
        return self.dropout(x)

class TransformerManyToOne(nn.Module):
    def __init__(
        self,
        *,
        n_features: int,
        d_model: int = 64,
        nhead: int = 4,
        num_layers: int = 2,
        dim_ff: int = 128,
        dropout: float = 0.1,
        pooling: str = "mean",  # "mean" o "last"
    ):
        super().__init__()
        self.pooling = pooling

        self.in_proj = nn.Linear(n_features, d_model)
        self.pos_enc = PositionalEncoding(d_model=d_model, dropout=dropout)

        enc_layer = nn.TransformerEncoderLayer(
            d_model=d_model,
            nhead=nhead,
            dim_feedforward=dim_ff,
            dropout=dropout,
            batch_first=True,   # (B, L, D)
            activation="gelu",
            norm_first=True,
        )
        self.encoder = nn.TransformerEncoder(enc_layer, num_layers=num_layers)
        self.head = nn.Linear(d_model, 1)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        # x: (B, L, F)
        z = self.in_proj(x)          # (B, L, D)
        z = self.pos_enc(z)          # (B, L, D)
        z = self.encoder(z)          # (B, L, D)

        if self.pooling == "last":
            pooled = z[:, -1, :]     # (B, D)
        else:
            pooled = z.mean(dim=1)   # (B, D)

        out = self.head(pooled)      # (B, 1)
        return out

# %% [markdown]
# Esta implementación usa:
# - Proyección: 20 → d_model
# - Positional encoding (sin metadata)
# - TransformerEncoder
# - Pooling: mean sobre el tiempo
# - Head: salida escalar

# %%
# ============================================================
# 2) Modelo: factory (misma idea que antes)
# ============================================================
def make_transformer_model(*, n_features: int, device: torch.device) -> nn.Module:
    model = TransformerManyToOne(
        n_features=n_features,
        d_model=64,
        nhead=4,
        num_layers=2,
        dim_ff=128,
        dropout=0.1,
        pooling="mean",
    ).to(device)
    return model

# %%
# ------------------------------------------------------------
# Modelos independientes (H60 y H90)
# IMPORTANTE: n_features debe coincidir con tu X 3D: (B, L, F)
# ------------------------------------------------------------
n_features = 36

# %%
# ------------------------------------------------------------
# Smoke test robusto (por horizonte)
# ------------------------------------------------------------
def smoke_test(model, loader, device, name: str):
    model.eval()
    xb, yb = next(iter(loader))
    xb = xb.to(device)
    yb = yb.to(device)

    with torch.no_grad():
        out = model(xb)

    print(f"[{name}] X:", tuple(xb.shape), xb.dtype)
    print(f"[{name}] y:", tuple(yb.shape), yb.dtype)
    print(f"[{name}] out:", tuple(out.shape), out.dtype)

    assert xb.ndim == 3, "X debe ser 3D: (B, L, F)"
    assert out.ndim == 2 and out.shape[1] == 1, "Salida debe ser (B, 1)"
    assert yb.ndim in (1, 2), "y debe ser (B,) o (B,1)"

# %% [markdown]
# ### **10.5. Definición de loss, optimizer y funciones de train / eval (sin tqdm)**

# %%
# ============================================================
# loss, optimizer y funciones de entrenamiento / evaluación
# (preparado para múltiples targets / horizontes / window_size)
# ============================================================

import torch
import torch.nn as nn
from typing import Optional


# ------------------------------------------------------------
# Factory: Loss (regresión)
# ------------------------------------------------------------
def make_criterion() -> nn.Module:
    return nn.MSELoss()


# ------------------------------------------------------------
# Factory: Optimizer (uno por corrida/modelo)
# ------------------------------------------------------------
def make_optimizer(
    model: nn.Module,
    *,
    lr: float = 1e-3,
    weight_decay: float = 1e-4,
) -> torch.optim.Optimizer:
    return torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay)


# ------------------------------------------------------------
# Función de entrenamiento (1 epoch)
# ------------------------------------------------------------
def train_one_epoch(
    model: nn.Module,
    loader,
    optimizer: torch.optim.Optimizer,
    criterion: nn.Module,
    device: torch.device,
    *,
    clip_grad_norm: Optional[float] = None,
) -> float:
    model.train()
    total_loss = 0.0
    n_samples = 0

    for xb, yb in loader:
        xb = xb.to(device)
        yb = yb.to(device)

        optimizer.zero_grad(set_to_none=True)

        y_hat = model(xb)
        loss = criterion(y_hat, yb)

        loss.backward()

        if clip_grad_norm is not None and clip_grad_norm > 0:
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=clip_grad_norm)

        optimizer.step()

        bs = xb.size(0)
        total_loss += loss.item() * bs
        n_samples += bs

    return total_loss / max(n_samples, 1)


# ------------------------------------------------------------
# Función de evaluación (1 epoch)
# ------------------------------------------------------------
@torch.no_grad()
def eval_one_epoch(
    model: nn.Module,
    loader,
    criterion: nn.Module,
    device: torch.device,
) -> float:
    model.eval()
    total_loss = 0.0
    n_samples = 0

    for xb, yb in loader:
        xb = xb.to(device)
        yb = yb.to(device)

        y_hat = model(xb)
        loss = criterion(y_hat, yb)

        bs = xb.size(0)
        total_loss += loss.item() * bs
        n_samples += bs

    return total_loss / max(n_samples, 1)


# ------------------------------------------------------------
# Ejemplo de uso (por corrida / por horizonte)
# ------------------------------------------------------------
# criterion = make_criterion()
# optimizer_60 = make_optimizer(model_60, lr=1e-3, weight_decay=1e-4)
# train_loss = train_one_epoch(model_60, loaders_60["train"], optimizer_60, criterion, device, clip_grad_norm=1.0)
# valid_loss = eval_one_epoch(model_60, loaders_60["valid"], criterion, device)

# %% [markdown]
# ### **10.6. Loop de entrenamiento completo con early stopping**

# %%
import math
import torch
import torch.nn as nn
from typing import Optional, Dict, Any


def fit_one_run(
    *,
    model: nn.Module,
    train_loader,
    valid_loader,
    device: torch.device,
    lr: float = 1e-3,
    weight_decay: float = 1e-4,
    max_epochs: int = 30,
    patience: int = 5,
    min_delta: float = 0.0,
    save_best: bool = True,
    best_path: Optional[str] = None,
    clip_grad_norm: Optional[float] = None,
    verbose: bool = True,
) -> Dict[str, Any]:
    """
    Entrena 1 modelo (1 target/horizonte/window_size) con early stopping en VALID.
    Retorna: history + best info. Deja el modelo restaurado al mejor estado si save_best=True.
    """
    criterion = make_criterion()
    optimizer = make_optimizer(model, lr=lr, weight_decay=weight_decay)

    best_val = math.inf
    best_epoch = -1
    patience_left = patience

    history = {"train_loss": [], "valid_loss": []}
    best_state = None

    for epoch in range(1, max_epochs + 1):
        train_loss = train_one_epoch(
            model, train_loader, optimizer, criterion, device, clip_grad_norm=clip_grad_norm
        )
        val_loss = eval_one_epoch(
            model, valid_loader, criterion, device
        )

        history["train_loss"].append(float(train_loss))
        history["valid_loss"].append(float(val_loss))

        improved = (best_val - val_loss) > min_delta
        if improved:
            best_val = float(val_loss)
            best_epoch = epoch
            patience_left = patience

            if save_best:
                best_state = {k: v.detach().cpu().clone() for k, v in model.state_dict().items()}
                if best_path is not None:
                    torch.save(model.state_dict(), best_path)
        else:
            patience_left -= 1

        if verbose:
            print(
                f"epoch {epoch:02d} | "
                f"train_loss={train_loss:.6f} | "
                f"valid_loss={val_loss:.6f} | "
                f"patience_left={patience_left}"
            )

        if patience_left <= 0:
            if verbose:
                print(f"Early stopping: best_valid_loss={best_val:.6f} at epoch {best_epoch}")
            break

    if save_best and best_state is not None:
        model.load_state_dict(best_state)
        model.to(device)
        if verbose:
            print(f"Modelo restaurado: epoch {best_epoch} | best_valid_loss={best_val:.6f}")

    return {
        "best_valid_loss": best_val,
        "best_epoch": best_epoch,
        "epochs_ran": epoch,
        "history": history,
    }

# %% [markdown]
# ### **10.7. Predicciones Transformer**

# %% [markdown]
# Función de predicción (seq2one) -> y_true, y_pred

# %%
import numpy as np
import torch

@torch.no_grad()
def predict_seq2one(
    model,
    loader,
    device: torch.device,
) -> tuple[np.ndarray, np.ndarray]:
    model.eval()

    y_true_list = []
    y_pred_list = []

    for xb, yb in loader:
        xb = xb.to(device)

        y_hat = model(xb).detach().cpu().numpy()   # (B,1) típico
        y_true = yb.detach().cpu().numpy()         # (B,1) o (B,)

        y_pred_list.append(y_hat)
        y_true_list.append(y_true)

    y_true_all = np.concatenate(y_true_list, axis=0)
    y_pred_all = np.concatenate(y_pred_list, axis=0)

    return y_true_all, y_pred_all

# %%
def get_metrics_torch_from_loaders(
    loaders: dict,
    model,
    *,
    device: torch.device,
    predict_loader_fn=predict_seq2one,
    compute_r2: bool = True,
) -> tuple[dict, dict]:
    """
    Calcula métricas valid/test para modelos seq2one usando DataLoaders.
    Espera loaders con keys: 'valid' y 'test'.
    predict_loader_fn debe devolver (y_true_all, y_pred_all).
    """

    # -------- VALID --------
    y_true_valid, y_pred_valid = predict_loader_fn(model, loaders["valid"], device=device)
    y_true_valid = np.asarray(y_true_valid).reshape(-1)
    y_pred_valid = np.asarray(y_pred_valid).reshape(-1)

    metrics_valid = compute_seq2one_metrics(y_true_valid, y_pred_valid, compute_r2=compute_r2)

    # -------- TEST --------
    y_true_test, y_pred_test = predict_loader_fn(model, loaders["test"], device=device)
    y_true_test = np.asarray(y_true_test).reshape(-1)
    y_pred_test = np.asarray(y_pred_test).reshape(-1)

    metrics_test = compute_seq2one_metrics(y_true_test, y_pred_test, compute_r2=compute_r2)

    return metrics_valid, metrics_test

# %% [markdown]
# ### **11 Funciones de intregación**

# %% [markdown]
# ### **11.1. Función `train_transformer`**

# %%
from typing import Any, Dict, Tuple
import torch
import torch.nn as nn

def train_transformer(
    loaders: dict,
    *,
    n_features: int,
    device: torch.device,

    # ---- hiperparámetros Transformer ----
    d_model: int = 64,
    nhead: int = 4,
    num_layers: int = 2,
    dim_ff: int = 128,
    dropout: float = 0.1,
    pooling: str = "mean",

    # ---- optim / early stopping ----
    lr: float = 1e-3,
    weight_decay: float = 1e-4,
    max_epochs: int = 30,
    patience: int = 5,
    min_delta: float = 0.0,
    clip_grad_norm: float | None = 1.0,
    use_scheduler: bool = False,   # por ahora lo ignoramos (para no mezclar pasos)
    save_best: bool = True,
    best_path: str | None = None,
    verbose: bool = True,
) -> Tuple[nn.Module, Dict[str, Any], Dict, Dict]:
    """
    Entrena 1 Transformer (1 target/horizonte/window_size) y devuelve:
      (model, hist, metrics_valid, metrics_test)
    """
    # 1) modelo
    model = TransformerManyToOne(
        n_features=n_features,
        d_model=d_model,
        nhead=nhead,
        num_layers=num_layers,
        dim_ff=dim_ff,
        dropout=dropout,
        pooling=pooling,
    ).to(device)

    # 2) fit (early stopping en VALID)
    hist = fit_one_run(
        model=model,
        train_loader=loaders["train"],
        valid_loader=loaders["valid"],
        device=device,
        lr=lr,
        weight_decay=weight_decay,
        max_epochs=max_epochs,
        patience=patience,
        min_delta=min_delta,
        save_best=save_best,
        best_path=best_path,
        clip_grad_norm=clip_grad_norm,
        verbose=verbose,
    )

    # 3) métricas VALID/TEST usando loaders
    metrics_valid, metrics_test = get_metrics_torch_from_loaders(
        {"valid": loaders["valid"], "test": loaders["test"]},
        model,
        device=device,
        predict_loader_fn=predict_seq2one,
        compute_r2=True,
    )

    return model, hist, metrics_valid, metrics_test

# %% [markdown]
# ### **11.2. Función `run_transformer`**

# %%
import pandas as pd
import torch
import gc
import time

def _ts():
    return time.strftime("%H:%M:%S")


def run_transformer(
    window_size: int,
    *,
    n_features: int = 36,
    batch_size_train: int = 4096,
    batch_size_pred: int = 32768,

    # ---- hiperparámetros Transformer ----
    d_model: int = 64,
    nhead: int = 4,
    num_layers: int = 2,
    dim_ff: int = 128,
    dropout: float = 0.1,
    pooling: str = "mean",

    # ---- optim ----
    lr: float = 1e-3,
    weight_decay: float = 1e-4,
    max_epochs: int = 30,
    patience: int = 5,
    clip_grad_norm: float = 1.0,
    use_scheduler: bool = True,

    verbose: bool = True,
):
    L = int(window_size)

    if verbose:
        print("\n" + "=" * 80)
        print(
            f"[{_ts()}] TRANSFORMER | SEQ2ONE | WINDOW_SIZE=L{L} | (L,F)=({L},{n_features}) "
            f"| d_model={d_model} | head={nhead} | layers={num_layers} | ff={dim_ff} | do={dropout} "
            f"| wd={weight_decay}"
        )
        print("=" * 80)

    targets = ["delta_60", "delta_90", "ret_60", "ret_90"]
    rows = []
    t_global = time.perf_counter()

    for i, target in enumerate(targets, start=1):
        t_target = time.perf_counter()

        if verbose:
            print(f"\n[{_ts()}] [{i}/{len(targets)}] START target='{target}' | L{L}")

        bundle = None
        loaders = None
        model = None
        hist = None
        metrics_valid = None
        metrics_test = None

        try:
            # -------------------------
            # BUILD BUNDLE (3D)
            # -------------------------
            if verbose:
                print(f"[{_ts()}]   [BUILD] Creando bundle (flatten_X=False) ...")
            t0 = time.perf_counter()

            (bundle,) = create_bundles(
                window_size=L,
                targets=[target],
                windows_paths=windows_paths,
                scalers_paths=scalers_paths,
                flatten_X=False,  # Transformer necesita 3D
            )

            if verbose:
                dt = time.perf_counter() - t0
                try:
                    xshape = bundle["train"]["X"].shape
                    yshape = bundle["train"]["y"].shape
                    print(f"[{_ts()}]   [BUILD] OK | train X={xshape} y={yshape} | dt={dt:.2f}s")
                except Exception:
                    print(f"[{_ts()}]   [BUILD] OK | dt={dt:.2f}s")

            # -------------------------
            # LOADERS (train)
            # -------------------------
            if verbose:
                print(f"[{_ts()}]   [LOADERS] Creando DataLoaders (3D) ...")
            t0 = time.perf_counter()

            loaders = make_loaders_from_bundle_3d(
                bundle,
                seq_len=L,
                n_features=n_features,
                batch_size=batch_size_train,
            )

            if verbose:
                dt = time.perf_counter() - t0
                try:
                    ntr = len(loaders["train"].dataset)
                    nva = len(loaders["valid"].dataset)
                    nte = len(loaders["test"].dataset)
                    print(f"[{_ts()}]   [LOADERS] OK | n(train/valid/test)=({ntr}/{nva}/{nte}) | dt={dt:.2f}s")
                except Exception:
                    print(f"[{_ts()}]   [LOADERS] OK | dt={dt:.2f}s")

            # -------------------------
            # TRAIN
            # -------------------------
            if verbose:
                print(f"[{_ts()}]   [TRAIN] Iniciando entrenamiento ...")
            t0 = time.perf_counter()

            model, hist, metrics_valid, metrics_test = train_transformer(
                loaders,
                n_features=n_features,
                device=device,
                d_model=64,
                nhead=4,
                num_layers=2,
                dim_ff=128,
                dropout=0.1,
                pooling="mean",
                lr=1e-3,
                weight_decay=1e-4,
                max_epochs=30,
                patience=5,
                clip_grad_norm=1.0,
                verbose=verbose,
            )

            if verbose:
                dt = time.perf_counter() - t0
                print(f"[{_ts()}]   [TRAIN] FIN entrenamiento | dt={dt:.2f}s")

            # liberar TRAIN (opcional, igual que GRU)
            if verbose:
                print(f"[{_ts()}]   [MEM] Liberando bundle['train'] y gc.collect() ...")
            del bundle["train"]
            gc.collect()

            # -------------------------
            # PRED LOADERS (valid/test) con batch grande
            # -------------------------
            # Creamos loaders solo para valid/test con batch_size_pred
            if verbose:
                print(f"[{_ts()}]   [PRED] Preparando loaders valid/test (batch_size_pred={batch_size_pred}) ...")
            t0 = time.perf_counter()

            pred_bundle = {
                "valid": bundle["valid"],
                "test": bundle["test"],
                # dummy para cumplir interfaz sin usar train
                "train": {"X": bundle["valid"]["X"][:1], "y": bundle["valid"]["y"][:1]},
            }
            pred_loaders = make_loaders_from_bundle_3d(
                pred_bundle,
                seq_len=L,
                n_features=n_features,
                batch_size=batch_size_pred,
                num_workers=0,  # pred suele ser más estable con 0
            )

            if verbose:
                dt = time.perf_counter() - t0
                print(f"[{_ts()}]   [PRED] Loaders OK | dt={dt:.2f}s")

            # -------------------------
            # METRICS (valid/test) usando loaders
            # -------------------------
            if verbose:
                print(f"[{_ts()}]   [METRICS] Calculando métricas (valid/test) ...")
            t0 = time.perf_counter()

            metrics_valid, metrics_test = get_metrics_torch_from_loaders(
                {"valid": pred_loaders["valid"], "test": pred_loaders["test"]},
                model,
                device=device,
                predict_loader_fn=predict_seq2one,
                compute_r2=True,
            )

            if verbose:
                dt = time.perf_counter() - t0
                print(f"[{_ts()}]   [METRICS] OK (valid/test) | dt={dt:.2f}s")

            # -------------------------
            # DF APPEND
            # -------------------------
            if verbose:
                print(f"[{_ts()}]   [DF] Agregando filas a la tabla ...")
            t0 = time.perf_counter()

            df_v = metrics_to_df(
                metrics_valid,
                model="transformer",
                split="valid",
                horizon=bundle["horizon"],
                window_size=bundle["window_size"],
                target=bundle["target"],
            )

            df_t = metrics_to_df(
                metrics_test,
                model="transformer",
                split="test",
                horizon=bundle["horizon"],
                window_size=bundle["window_size"],
                target=bundle["target"],
            )

            for df_ in (df_v, df_t):
                df_["d_model"] = d_model
                df_["nhead"] = nhead
                df_["num_layers"] = num_layers
                df_["dim_ff"] = dim_ff
                df_["dropout"] = dropout
                df_["pooling"] = pooling
                df_["lr"] = lr
                df_["weight_decay"] = weight_decay
                if isinstance(hist, dict):
                    df_["best_valid_mse"] = hist.get("best_valid_mse")
                    df_["epochs_ran"] = hist.get("epochs_ran")
                    df_["final_lr"] = hist.get("final_lr")

            rows.append(df_v)
            rows.append(df_t)

            if verbose:
                dt = time.perf_counter() - t0
                print(f"[{_ts()}]   [DF] OK | dt={dt:.2f}s")

            if verbose:
                dt_target = time.perf_counter() - t_target
                print(f"[{_ts()}] [{i}/{len(targets)}] DONE target='{target}' | dt_total={dt_target:.2f}s")

        finally:
            if verbose:
                print(f"[{_ts()}]   [CLEAN] Liberando objetos ...")

            bundle = loaders = model = hist = metrics_valid = metrics_test = None
            gc.collect()
            if torch.cuda.is_available():
                torch.cuda.empty_cache()

    # -------------------------
    # FINAL DF
    # -------------------------
    if verbose:
        print(f"\n[{_ts()}] [FINAL] Concatenando resultados ...")
    t0 = time.perf_counter()

    df_transformer_metrics = (
        pd.concat(rows, ignore_index=True)
          .sort_values(["window_size", "target", "split", "horizon_min", "model"])
          .reset_index(drop=True)
    )

    if verbose:
        dt = time.perf_counter() - t0
        dt_all = time.perf_counter() - t_global
        print(f"[{_ts()}] [FINAL] OK | rows={len(df_transformer_metrics)} | dt_concat={dt:.2f}s | dt_total={dt_all:.2f}s")
        print(df_transformer_metrics[["window_size", "target", "split", "horizon_min", "model"]]
              .drop_duplicates()
              .to_string(index=False))

    return df_transformer_metrics

# %% [markdown]
# ### **11.3. Función `train_transformer_row`**

# %%
import math
import torch
import torch.nn as nn
from typing import Any, Dict, List

def train_transformer_row(
    *,
    loaders: dict,
    window_size: int,
    model_name: str,
    n_features: int = 36,
    device: torch.device,

    # ---- hiperparámetros Transformer ----
    d_model: int = 64,
    nhead: int = 4,
    num_layers: int = 2,
    dim_ff: int = 128,
    dropout: float = 0.1,
    pooling: str = "mean",

    # ---- optim / early stopping ----
    lr: float = 1e-3,
    weight_decay: float = 1e-4,
    max_epochs: int = 30,
    patience: int = 5,
    min_delta: float = 0.0,
    clip_grad_norm: float | None = 1.0,
    use_scheduler: bool = False,   # por ahora no lo usamos
    verbose: bool = True,

    # ---- metadata extra (target/horizon/etc.) ----
    target: str | None = None,
    horizon_min: int | None = None,
) -> List[Dict[str, Any]]:
    """
    Entrena 1 corrida y retorna 2 rows (valid/test) como dicts listos para DataFrame.
    Requiere que existan: fit_one_run, get_metrics_torch_from_loaders, predict_seq2one, metrics_to_df.
    """

    # 1) crear modelo
    model = TransformerManyToOne(
        n_features=n_features,
        d_model=d_model,
        nhead=nhead,
        num_layers=num_layers,
        dim_ff=dim_ff,
        dropout=dropout,
        pooling=pooling,
    ).to(device)

    # 2) entrenar (early stopping en VALID)
    hist = fit_one_run(
        model=model,
        train_loader=loaders["train"],
        valid_loader=loaders["valid"],
        device=device,
        lr=lr,
        weight_decay=weight_decay,
        max_epochs=max_epochs,
        patience=patience,
        min_delta=min_delta,
        save_best=True,
        best_path=None,
        clip_grad_norm=clip_grad_norm,
        verbose=verbose,
    )

    # 3) métricas VALID/TEST (usando loaders)
    metrics_valid, metrics_test = get_metrics_torch_from_loaders(
        {"valid": loaders["valid"], "test": loaders["test"]},
        model,
        device=device,
        predict_loader_fn=predict_seq2one,
        compute_r2=True,
    )

    # 4) pasar a DF (como en GRU) y luego a dict rows
    df_v = metrics_to_df(
        metrics_valid,
        model=model_name,
        split="valid",
        horizon=horizon_min if horizon_min is not None else loaders.get("horizon"),
        window_size=window_size,
        target=target if target is not None else loaders.get("target"),
    )

    df_t = metrics_to_df(
        metrics_test,
        model=model_name,
        split="test",
        horizon=horizon_min if horizon_min is not None else loaders.get("horizon"),
        window_size=window_size,
        target=target if target is not None else loaders.get("target"),
    )

    # 5) anexar hiperparámetros + hist (nombres consistentes con GRU)
    for df_ in (df_v, df_t):
        df_["d_model"] = d_model
        df_["nhead"] = nhead
        df_["num_layers"] = num_layers
        df_["dim_ff"] = dim_ff
        df_["dropout"] = dropout
        df_["pooling"] = pooling
        df_["lr"] = lr
        df_["weight_decay"] = weight_decay

        df_["best_valid_mse"] = hist.get("best_valid_loss")  # (es MSELoss)
        df_["epochs_ran"] = hist.get("epochs_ran")
        df_["best_epoch"] = hist.get("best_epoch")

    # liberar un poco
    del model
    if torch.cuda.is_available():
        torch.cuda.empty_cache()

    return [df_v.iloc[0].to_dict(), df_t.iloc[0].to_dict()]

# %% [markdown]
# ### **11.4. Función `run_transformer_incremental`**

# %%
from pathlib import Path
import pandas as pd

def run_transformer_incremental(
    *,
    window_sizes: list[int],

    # ---- hiperparámetros Transformer ----
    d_model: int = 64,
    nhead: int = 4,
    num_layers: int = 2,
    dim_ff: int = 128,
    dropout: float = 0.1,
    pooling: str = "mean",

    lr: float = 1e-3,
    weight_decay: float = 1e-4,
    max_epochs: int = 30,
    patience: int = 5,
    clip_grad_norm: float = 1.0,
    use_scheduler: bool = True,

    # ---- data ----
    n_features: int = 36,
    batch_size_train: int = 4096,
    batch_size_pred: int = 32768,

    # ---- persistencia ----
    name: str = "transformer",
    verbose: bool = True,
) -> pd.DataFrame:

    # ------------------------------------------------------------
    # Cargar histórico desde su carpeta Drive (si existe)
    # ------------------------------------------------------------
    metrics_dir = Path("/content/drive/MyDrive/neural_profit/metrics/seq2one_metrics")
    metrics_path = metrics_dir / f"seq2one_{name}_metrics.parquet"

    if metrics_path.exists():
        df_hist = pd.read_parquet(metrics_path)
    else:
        df_hist = pd.DataFrame()

    expected_targets = {"delta_60", "delta_90", "ret_60", "ret_90"}
    expected_splits = {"valid", "test"}

    dfs_new = []

    for L in window_sizes:
        L = int(L)

        # ---- Skip robusto ----
        if not df_hist.empty:
            dfL = df_hist[(df_hist["model"] == name) & (df_hist["window_size"] == L)]
            done_targets = set(dfL["target"].unique()) if not dfL.empty else set()
            done_splits = set(dfL["split"].unique()) if not dfL.empty else set()

            if expected_targets.issubset(done_targets) and expected_splits.issubset(done_splits):
                if verbose:
                    print(f"[SKIP] {name} L={L} ya existe completo en Drive")
                continue

        # ---- Ejecutar entrenamiento completo para L ----
        df_L = run_transformer(
            window_size=L,
            n_features=n_features,
            batch_size_train=batch_size_train,
            batch_size_pred=batch_size_pred,
            d_model=d_model,
            nhead=nhead,
            num_layers=num_layers,
            dim_ff=dim_ff,
            dropout=dropout,
            pooling=pooling,
            lr=lr,
            weight_decay=weight_decay,
            max_epochs=max_epochs,
            patience=patience,
            clip_grad_norm=clip_grad_norm,
            use_scheduler=use_scheduler,
            verbose=verbose,
        )

        df_L["model"] = name
        dfs_new.append(df_L)

        # actualizar histórico en memoria
        if df_hist.empty:
            df_hist = df_L.copy()
        else:
            df_hist = pd.concat([df_hist, df_L], ignore_index=True)

        # ---- Guardar usando SU función ----
        save_seq2one_metrics(df_hist, name=name)

    return df_hist.sort_values(
        ["window_size", "target", "split", "horizon_min", "model"]
    ).reset_index(drop=True)

# %% [markdown]
# ## **12. Aplicación**

# %%
df_transformer_all_sizes = run_transformer_incremental(
    window_sizes=[30, 60, 90, 120, 180],
    d_model=64,
    nhead=4,
    num_layers=2,
    dim_ff=128,
    dropout=0.1,
    pooling="mean",
    lr=1e-3,
    weight_decay=1e-4,
    max_epochs=30,
    patience=5,
    clip_grad_norm=1.0,
    use_scheduler=True,
    name="transformer",
    verbose=True,
)
# Out:
# ================================================================================
# [20:03:40] TRANSFORMER | SEQ2ONE | WINDOW_SIZE=L30 | (L,F)=(30,36) | d_model=64 | head=4 | layers=2 | ff=128 | do=0.1 | wd=0.0001
# ================================================================================
#
# [20:03:40] [1/4] START target='delta_60' | L30
# [20:03:40]   [BUILD] Creando bundle (flatten_X=False) ...
# H60 Train: (463872, 30, 36) (463872,)
# H60 Valid: (99328, 30, 36) (99328,)
# H60 Test : (99840, 30, 36) (99840,)
# Scaler H60: StandardScaler
# [20:03:51]   [BUILD] OK | train X=(463872, 30, 36) y=(463872,) | dt=11.47s
# [20:03:51]   [LOADERS] Creando DataLoaders (3D) ...
# [20:03:54]   [LOADERS] OK | n(train/valid/test)=(463872/99328/99840) | dt=2.61s
# [20:03:54]   [TRAIN] Iniciando entrenamiento ...
# /tmp/ipython-input-3848978488.py:52: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(enc_layer, num_layers=num_layers)
# epoch 01 | train_loss=2478.028996 | valid_loss=2030.929202 | patience_left=5
# epoch 02 | train_loss=2256.252445 | valid_loss=1901.912669 | patience_left=5
# epoch 03 | train_loss=2123.174903 | valid_loss=1839.402388 | patience_left=5
# epoch 04 | train_loss=2010.083346 | valid_loss=1821.349165 | patience_left=5
# epoch 05 | train_loss=1918.507565 | valid_loss=1697.118357 | patience_left=5
# epoch 06 | train_loss=1848.877802 | valid_loss=1799.983970 | patience_left=4
# epoch 07 | train_loss=1791.084676 | valid_loss=1782.505791 | patience_left=3
# epoch 08 | train_loss=1737.695919 | valid_loss=1785.882385 | patience_left=2
# epoch 09 | train_loss=1697.838516 | valid_loss=1775.826466 | patience_left=1
# epoch 10 | train_loss=1664.790179 | valid_loss=1809.483922 | patience_left=0
# Early stopping: best_valid_loss=1697.118357 at epoch 5
# Modelo restaurado: epoch 5 | best_valid_loss=1697.118357
# [20:05:24]   [TRAIN] FIN entrenamiento | dt=89.81s
# [20:05:24]   [MEM] Liberando bundle['train'] y gc.collect() ...
# [20:05:24]   [PRED] Preparando loaders valid/test (batch_size_pred=32768) ...
# [20:05:25]   [PRED] Loaders OK | dt=0.78s
# [20:05:25]   [METRICS] Calculando métricas (valid/test) ...
# [20:05:28]   [METRICS] OK (valid/test) | dt=3.19s
# [20:05:28]   [DF] Agregando filas a la tabla ...
# [20:05:28]   [DF] OK | dt=0.01s
# [20:05:28] [1/4] DONE target='delta_60' | dt_total=108.05s
# [20:05:28]   [CLEAN] Liberando objetos ...
#
# [20:05:28] [2/4] START target='delta_90' | L30
# [20:05:28]   [BUILD] Creando bundle (flatten_X=False) ...
# H90 Train: (463872, 30, 36) (463872,)
# H90 Valid: (99328, 30, 36) (99328,)
# H90 Test : (99840, 30, 36) (99840,)
# Scaler H90: StandardScaler
# [20:05:35]   [BUILD] OK | train X=(463872, 30, 36) y=(463872,) | dt=6.99s
# [20:05:35]   [LOADERS] Creando DataLoaders (3D) ...
# [20:05:38]   [LOADERS] OK | n(train/valid/test)=(463872/99328/99840) | dt=2.58s
# [20:05:38]   [TRAIN] Iniciando entrenamiento ...
# /tmp/ipython-input-3848978488.py:52: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(enc_layer, num_layers=num_layers)
# epoch 01 | train_loss=3834.574099 | valid_loss=3250.721871 | patience_left=5
# epoch 02 | train_loss=3472.280329 | valid_loss=2949.978495 | patience_left=5
# epoch 03 | train_loss=3249.246944 | valid_loss=2875.859790 | patience_left=5
# epoch 04 | train_loss=3105.724534 | valid_loss=2955.564436 | patience_left=4
# epoch 05 | train_loss=3002.361659 | valid_loss=2749.652998 | patience_left=5
# epoch 06 | train_loss=2920.440385 | valid_loss=3356.426239 | patience_left=4
# epoch 07 | train_loss=2857.699408 | valid_loss=3455.732855 | patience_left=3
# epoch 08 | train_loss=2804.562829 | valid_loss=3142.958504 | patience_left=2
# epoch 09 | train_loss=2754.339279 | valid_loss=3749.811710 | patience_left=1
# epoch 10 | train_loss=2706.398439 | valid_loss=3741.445151 | patience_left=0
# Early stopping: best_valid_loss=2749.652998 at epoch 5
# Modelo restaurado: epoch 5 | best_valid_loss=2749.652998
# [20:07:01]   [TRAIN] FIN entrenamiento | dt=83.56s
# [20:07:01]   [MEM] Liberando bundle['train'] y gc.collect() ...
# [20:07:01]   [PRED] Preparando loaders valid/test (batch_size_pred=32768) ...
# [20:07:02]   [PRED] Loaders OK | dt=0.78s
# [20:07:02]   [METRICS] Calculando métricas (valid/test) ...
# [20:07:05]   [METRICS] OK (valid/test) | dt=3.06s
# [20:07:05]   [DF] Agregando filas a la tabla ...
# [20:07:05]   [DF] OK | dt=0.01s
# [20:07:05] [2/4] DONE target='delta_90' | dt_total=97.16s
# [20:07:05]   [CLEAN] Liberando objetos ...
#
# [20:07:05] [3/4] START target='ret_60' | L30
# [20:07:05]   [BUILD] Creando bundle (flatten_X=False) ...
# H60 Train: (463872, 30, 36) (463872,)
# H60 Valid: (99328, 30, 36) (99328,)
# H60 Test : (99840, 30, 36) (99840,)
# Scaler H60: StandardScaler
# [20:07:13]   [BUILD] OK | train X=(463872, 30, 36) y=(463872,) | dt=7.18s
# [20:07:13]   [LOADERS] Creando DataLoaders (3D) ...
# [20:07:15]   [LOADERS] OK | n(train/valid/test)=(463872/99328/99840) | dt=2.58s
# [20:07:15]   [TRAIN] Iniciando entrenamiento ...
# /tmp/ipython-input-3848978488.py:52: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(enc_layer, num_layers=num_layers)
# epoch 01 | train_loss=0.011636 | valid_loss=0.000119 | patience_left=5
# epoch 02 | train_loss=0.000297 | valid_loss=0.000039 | patience_left=5
# epoch 03 | train_loss=0.000198 | valid_loss=0.000025 | patience_left=5
# epoch 04 | train_loss=0.000147 | valid_loss=0.000020 | patience_left=5
# epoch 05 | train_loss=0.000119 | valid_loss=0.000020 | patience_left=5
# epoch 06 | train_loss=0.000096 | valid_loss=0.000013 | patience_left=5
# epoch 07 | train_loss=0.000083 | valid_loss=0.000018 | patience_left=4
# epoch 08 | train_loss=0.000079 | valid_loss=0.000012 | patience_left=5
# epoch 09 | train_loss=0.000070 | valid_loss=0.000010 | patience_left=5
# epoch 10 | train_loss=0.000064 | valid_loss=0.000009 | patience_left=5
# epoch 11 | train_loss=0.000064 | valid_loss=0.000014 | patience_left=4
# epoch 12 | train_loss=0.000057 | valid_loss=0.000024 | patience_left=3
# epoch 13 | train_loss=0.000056 | valid_loss=0.000009 | patience_left=2
# epoch 14 | train_loss=0.000049 | valid_loss=0.000048 | patience_left=1
# epoch 15 | train_loss=0.000049 | valid_loss=0.000020 | patience_left=0
# Early stopping: best_valid_loss=0.000009 at epoch 10
# Modelo restaurado: epoch 10 | best_valid_loss=0.000009
# [20:09:20]   [TRAIN] FIN entrenamiento | dt=124.83s
# [20:09:20]   [MEM] Liberando bundle['train'] y gc.collect() ...
# [20:09:20]   [PRED] Preparando loaders valid/test (batch_size_pred=32768) ...
# [20:09:21]   [PRED] Loaders OK | dt=0.78s
# [20:09:21]   [METRICS] Calculando métricas (valid/test) ...
# [20:09:24]   [METRICS] OK (valid/test) | dt=3.09s
# [20:09:24]   [DF] Agregando filas a la tabla ...
# [20:09:24]   [DF] OK | dt=0.01s
# [20:09:24] [3/4] DONE target='ret_60' | dt_total=138.64s
# [20:09:24]   [CLEAN] Liberando objetos ...
#
# [20:09:24] [4/4] START target='ret_90' | L30
# [20:09:24]   [BUILD] Creando bundle (flatten_X=False) ...
# H90 Train: (463872, 30, 36) (463872,)
# H90 Valid: (99328, 30, 36) (99328,)
# H90 Test : (99840, 30, 36) (99840,)
# Scaler H90: StandardScaler
# [20:09:32]   [BUILD] OK | train X=(463872, 30, 36) y=(463872,) | dt=8.10s
# [20:09:32]   [LOADERS] Creando DataLoaders (3D) ...
# [20:09:35]   [LOADERS] OK | n(train/valid/test)=(463872/99328/99840) | dt=2.59s
# [20:09:35]   [TRAIN] Iniciando entrenamiento ...
# /tmp/ipython-input-3848978488.py:52: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(enc_layer, num_layers=num_layers)
# epoch 01 | train_loss=0.006279 | valid_loss=0.000092 | patience_left=5
# epoch 02 | train_loss=0.000293 | valid_loss=0.000031 | patience_left=5
# epoch 03 | train_loss=0.000191 | valid_loss=0.000068 | patience_left=4
# epoch 04 | train_loss=0.000146 | valid_loss=0.000031 | patience_left=5
# epoch 05 | train_loss=0.000120 | valid_loss=0.000034 | patience_left=4
# epoch 06 | train_loss=0.000105 | valid_loss=0.000015 | patience_left=5
# epoch 07 | train_loss=0.000090 | valid_loss=0.000048 | patience_left=4
# epoch 08 | train_loss=0.000082 | valid_loss=0.000015 | patience_left=3
# epoch 09 | train_loss=0.000079 | valid_loss=0.000073 | patience_left=2
# epoch 10 | train_loss=0.000067 | valid_loss=0.000043 | patience_left=1
# epoch 11 | train_loss=0.000068 | valid_loss=0.000056 | patience_left=0
# Early stopping: best_valid_loss=0.000015 at epoch 6
# Modelo restaurado: epoch 6 | best_valid_loss=0.000015
# [20:11:07]   [TRAIN] FIN entrenamiento | dt=91.75s
# [20:11:07]   [MEM] Liberando bundle['train'] y gc.collect() ...
# [20:11:07]   [PRED] Preparando loaders valid/test (batch_size_pred=32768) ...
# [20:11:08]   [PRED] Loaders OK | dt=0.78s
# [20:11:08]   [METRICS] Calculando métricas (valid/test) ...
# [20:11:11]   [METRICS] OK (valid/test) | dt=3.12s
# [20:11:11]   [DF] Agregando filas a la tabla ...
# [20:11:11]   [DF] OK | dt=0.01s
# [20:11:11] [4/4] DONE target='ret_90' | dt_total=106.52s
# [20:11:11]   [CLEAN] Liberando objetos ...
#
# [20:11:11] [FINAL] Concatenando resultados ...
# [20:11:11] [FINAL] OK | rows=8 | dt_concat=0.01s | dt_total=451.16s
#  window_size   target split  horizon_min       model
#           30 delta_60  test           60 transformer
#           30 delta_60 valid           60 transformer
#           30 delta_90  test           90 transformer
#           30 delta_90 valid           90 transformer
#           30   ret_60  test           60 transformer
#           30   ret_60 valid           60 transformer
#           30   ret_90  test           90 transformer
#           30   ret_90 valid           90 transformer
# [OK] Métricas guardadas en: /content/drive/MyDrive/neural_profit/metrics/seq2one_metrics/seq2one_transformer_metrics.parquet
#
# ================================================================================
# [20:11:11] TRANSFORMER | SEQ2ONE | WINDOW_SIZE=L60 | (L,F)=(60,36) | d_model=64 | head=4 | layers=2 | ff=128 | do=0.1 | wd=0.0001
# ================================================================================
#
# [20:11:11] [1/4] START target='delta_60' | L60
# [20:11:11]   [BUILD] Creando bundle (flatten_X=False) ...
# H60 Train: (436692, 60, 36) (436692,)
# H60 Valid: (93508, 60, 36) (93508,)
# H60 Test : (93990, 60, 36) (93990,)
# Scaler H60: StandardScaler
# [20:11:21]   [BUILD] OK | train X=(436692, 60, 36) y=(436692,) | dt=10.26s
# [20:11:21]   [LOADERS] Creando DataLoaders (3D) ...
# [20:11:26]   [LOADERS] OK | n(train/valid/test)=(436692/93508/93990) | dt=4.87s
# [20:11:26]   [TRAIN] Iniciando entrenamiento ...
# /tmp/ipython-input-3848978488.py:52: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(enc_layer, num_layers=num_layers)
# epoch 01 | train_loss=2368.261716 | valid_loss=1851.734307 | patience_left=5
# epoch 02 | train_loss=1919.771535 | valid_loss=1637.114794 | patience_left=5
# epoch 03 | train_loss=1721.150052 | valid_loss=1640.790497 | patience_left=4
# epoch 04 | train_loss=1632.094764 | valid_loss=1582.179371 | patience_left=5
# epoch 05 | train_loss=1556.857969 | valid_loss=1626.414326 | patience_left=4
# epoch 06 | train_loss=1495.430292 | valid_loss=1547.598946 | patience_left=5
# epoch 07 | train_loss=1434.769405 | valid_loss=1579.482275 | patience_left=4
# epoch 08 | train_loss=1396.595269 | valid_loss=1646.405489 | patience_left=3
# epoch 09 | train_loss=1356.457057 | valid_loss=1794.215291 | patience_left=2
# epoch 10 | train_loss=1318.662107 | valid_loss=1752.071364 | patience_left=1
# epoch 11 | train_loss=1285.541494 | valid_loss=1797.660609 | patience_left=0
# Early stopping: best_valid_loss=1547.598946 at epoch 6
# Modelo restaurado: epoch 6 | best_valid_loss=1547.598946
# [20:14:05]   [TRAIN] FIN entrenamiento | dt=158.77s
# [20:14:05]   [MEM] Liberando bundle['train'] y gc.collect() ...
# [20:14:05]   [PRED] Preparando loaders valid/test (batch_size_pred=32768) ...
# [20:14:07]   [PRED] Loaders OK | dt=1.46s
# [20:14:07]   [METRICS] Calculando métricas (valid/test) ...
# [20:14:11]   [METRICS] OK (valid/test) | dt=4.22s
# [20:14:11]   [DF] Agregando filas a la tabla ...
# [20:14:11]   [DF] OK | dt=0.01s
# [20:14:11] [1/4] DONE target='delta_60' | dt_total=179.77s
# [20:14:11]   [CLEAN] Liberando objetos ...
#
# [20:14:11] [2/4] START target='delta_90' | L60
# [20:14:11]   [BUILD] Creando bundle (flatten_X=False) ...
# H90 Train: (436692, 60, 36) (436692,)
# H90 Valid: (93508, 60, 36) (93508,)
# H90 Test : (93990, 60, 36) (93990,)
# Scaler H90: StandardScaler
# [20:14:22]   [BUILD] OK | train X=(436692, 60, 36) y=(436692,) | dt=10.44s
# [20:14:22]   [LOADERS] Creando DataLoaders (3D) ...
# [20:14:26]   [LOADERS] OK | n(train/valid/test)=(436692/93508/93990) | dt=4.86s
# [20:14:26]   [TRAIN] Iniciando entrenamiento ...
# /tmp/ipython-input-3848978488.py:52: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(enc_layer, num_layers=num_layers)
# epoch 01 | train_loss=3682.426826 | valid_loss=2928.971473 | patience_left=5
# epoch 02 | train_loss=3085.254876 | valid_loss=2778.446900 | patience_left=5
# epoch 03 | train_loss=2859.703459 | valid_loss=2857.177347 | patience_left=4
# epoch 04 | train_loss=2710.933767 | valid_loss=2666.750728 | patience_left=5
# epoch 05 | train_loss=2582.089576 | valid_loss=2627.572378 | patience_left=5
# epoch 06 | train_loss=2482.024669 | valid_loss=2708.147397 | patience_left=4
# epoch 07 | train_loss=2397.358142 | valid_loss=2924.190245 | patience_left=3
# epoch 08 | train_loss=2335.754976 | valid_loss=3383.090438 | patience_left=2
# epoch 09 | train_loss=2282.785680 | valid_loss=2997.440538 | patience_left=1
# epoch 10 | train_loss=2232.234047 | valid_loss=4014.764851 | patience_left=0
# Early stopping: best_valid_loss=2627.572378 at epoch 5
# Modelo restaurado: epoch 5 | best_valid_loss=2627.572378
# [20:16:49]   [TRAIN] FIN entrenamiento | dt=142.72s
# [20:16:49]   [MEM] Liberando bundle['train'] y gc.collect() ...
# [20:16:49]   [PRED] Preparando loaders valid/test (batch_size_pred=32768) ...
# [20:16:51]   [PRED] Loaders OK | dt=1.47s
# [20:16:51]   [METRICS] Calculando métricas (valid/test) ...
# [20:16:55]   [METRICS] OK (valid/test) | dt=4.05s
# [20:16:55]   [DF] Agregando filas a la tabla ...
# [20:16:55]   [DF] OK | dt=0.01s
# [20:16:55] [2/4] DONE target='delta_90' | dt_total=163.72s
# [20:16:55]   [CLEAN] Liberando objetos ...
#
# [20:16:55] [3/4] START target='ret_60' | L60
# [20:16:55]   [BUILD] Creando bundle (flatten_X=False) ...
# H60 Train: (436692, 60, 36) (436692,)
# H60 Valid: (93508, 60, 36) (93508,)
# H60 Test : (93990, 60, 36) (93990,)
# Scaler H60: StandardScaler
# [20:17:05]   [BUILD] OK | train X=(436692, 60, 36) y=(436692,) | dt=9.64s
# [20:17:05]   [LOADERS] Creando DataLoaders (3D) ...
# [20:17:10]   [LOADERS] OK | n(train/valid/test)=(436692/93508/93990) | dt=4.85s
# [20:17:10]   [TRAIN] Iniciando entrenamiento ...
# /tmp/ipython-input-3848978488.py:52: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(enc_layer, num_layers=num_layers)
# epoch 01 | train_loss=0.010767 | valid_loss=0.000157 | patience_left=5
# epoch 02 | train_loss=0.000253 | valid_loss=0.000070 | patience_left=5
# epoch 03 | train_loss=0.000178 | valid_loss=0.000029 | patience_left=5
# epoch 04 | train_loss=0.000141 | valid_loss=0.000093 | patience_left=4
# epoch 05 | train_loss=0.000120 | valid_loss=0.000014 | patience_left=5
# epoch 06 | train_loss=0.000107 | valid_loss=0.000025 | patience_left=4
# epoch 07 | train_loss=0.000092 | valid_loss=0.000022 | patience_left=3
# epoch 08 | train_loss=0.000079 | valid_loss=0.000011 | patience_left=5
# epoch 09 | train_loss=0.000075 | valid_loss=0.000014 | patience_left=4
# epoch 10 | train_loss=0.000064 | valid_loss=0.000049 | patience_left=3
# epoch 11 | train_loss=0.000061 | valid_loss=0.000081 | patience_left=2
# epoch 12 | train_loss=0.000061 | valid_loss=0.000023 | patience_left=1
# epoch 13 | train_loss=0.000054 | valid_loss=0.000012 | patience_left=0
# Early stopping: best_valid_loss=0.000011 at epoch 8
# Modelo restaurado: epoch 8 | best_valid_loss=0.000011
# [20:20:14]   [TRAIN] FIN entrenamiento | dt=184.88s
# [20:20:14]   [MEM] Liberando bundle['train'] y gc.collect() ...
# [20:20:15]   [PRED] Preparando loaders valid/test (batch_size_pred=32768) ...
# [20:20:16]   [PRED] Loaders OK | dt=1.49s
# [20:20:16]   [METRICS] Calculando métricas (valid/test) ...
# [20:20:20]   [METRICS] OK (valid/test) | dt=3.98s
# [20:20:20]   [DF] Agregando filas a la tabla ...
# [20:20:20]   [DF] OK | dt=0.01s
# [20:20:20] [3/4] DONE target='ret_60' | dt_total=205.03s
# [20:20:20]   [CLEAN] Liberando objetos ...
#
# [20:20:20] [4/4] START target='ret_90' | L60
# [20:20:20]   [BUILD] Creando bundle (flatten_X=False) ...
# H90 Train: (436692, 60, 36) (436692,)
# H90 Valid: (93508, 60, 36) (93508,)
# H90 Test : (93990, 60, 36) (93990,)
# Scaler H90: StandardScaler
# [20:20:30]   [BUILD] OK | train X=(436692, 60, 36) y=(436692,) | dt=10.09s
# [20:20:30]   [LOADERS] Creando DataLoaders (3D) ...
# [20:20:35]   [LOADERS] OK | n(train/valid/test)=(436692/93508/93990) | dt=4.85s
# [20:20:35]   [TRAIN] Iniciando entrenamiento ...
# /tmp/ipython-input-3848978488.py:52: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(enc_layer, num_layers=num_layers)
# epoch 01 | train_loss=0.029424 | valid_loss=0.000276 | patience_left=5
# epoch 02 | train_loss=0.000238 | valid_loss=0.000138 | patience_left=5
# epoch 03 | train_loss=0.000177 | valid_loss=0.000105 | patience_left=5
# epoch 04 | train_loss=0.000143 | valid_loss=0.000062 | patience_left=5
# epoch 05 | train_loss=0.000119 | valid_loss=0.000034 | patience_left=5
# epoch 06 | train_loss=0.000102 | valid_loss=0.000039 | patience_left=4
# epoch 07 | train_loss=0.000091 | valid_loss=0.000025 | patience_left=5
# epoch 08 | train_loss=0.000081 | valid_loss=0.000024 | patience_left=5
# epoch 09 | train_loss=0.000074 | valid_loss=0.000021 | patience_left=5
# epoch 10 | train_loss=0.000068 | valid_loss=0.000016 | patience_left=5
# epoch 11 | train_loss=0.000064 | valid_loss=0.000015 | patience_left=5
# epoch 12 | train_loss=0.000060 | valid_loss=0.000020 | patience_left=4
# epoch 13 | train_loss=0.000056 | valid_loss=0.000015 | patience_left=3
# epoch 14 | train_loss=0.000055 | valid_loss=0.000039 | patience_left=2
# epoch 15 | train_loss=0.000053 | valid_loss=0.000020 | patience_left=1
# epoch 16 | train_loss=0.000049 | valid_loss=0.000013 | patience_left=5
# epoch 17 | train_loss=0.000049 | valid_loss=0.000014 | patience_left=4
# epoch 18 | train_loss=0.000049 | valid_loss=0.000012 | patience_left=5
# epoch 19 | train_loss=0.000045 | valid_loss=0.000013 | patience_left=4
# epoch 20 | train_loss=0.000047 | valid_loss=0.000012 | patience_left=5
# epoch 21 | train_loss=0.000041 | valid_loss=0.000011 | patience_left=5
# epoch 22 | train_loss=0.000040 | valid_loss=0.000011 | patience_left=5
# epoch 23 | train_loss=0.000041 | valid_loss=0.000013 | patience_left=4
# epoch 24 | train_loss=0.000040 | valid_loss=0.000010 | patience_left=5
# epoch 25 | train_loss=0.000036 | valid_loss=0.000015 | patience_left=4
# epoch 26 | train_loss=0.000039 | valid_loss=0.000010 | patience_left=3
# epoch 27 | train_loss=0.000036 | valid_loss=0.000010 | patience_left=5
# epoch 28 | train_loss=0.000036 | valid_loss=0.000011 | patience_left=4
# epoch 29 | train_loss=0.000035 | valid_loss=0.000015 | patience_left=3
# epoch 30 | train_loss=0.000034 | valid_loss=0.000021 | patience_left=2
# Modelo restaurado: epoch 27 | best_valid_loss=0.000010
# [20:27:39]   [TRAIN] FIN entrenamiento | dt=424.20s
# [20:27:39]   [MEM] Liberando bundle['train'] y gc.collect() ...
# [20:27:40]   [PRED] Preparando loaders valid/test (batch_size_pred=32768) ...
# [20:27:41]   [PRED] Loaders OK | dt=1.47s
# [20:27:41]   [METRICS] Calculando métricas (valid/test) ...
# [20:27:45]   [METRICS] OK (valid/test) | dt=3.99s
# [20:27:45]   [DF] Agregando filas a la tabla ...
# [20:27:45]   [DF] OK | dt=0.01s
# [20:27:45] [4/4] DONE target='ret_90' | dt_total=444.78s
# [20:27:45]   [CLEAN] Liberando objetos ...
#
# [20:27:45] [FINAL] Concatenando resultados ...
# [20:27:45] [FINAL] OK | rows=8 | dt_concat=0.00s | dt_total=994.15s
#  window_size   target split  horizon_min       model
#           60 delta_60  test           60 transformer
#           60 delta_60 valid           60 transformer
#           60 delta_90  test           90 transformer
#           60 delta_90 valid           90 transformer
#           60   ret_60  test           60 transformer
#           60   ret_60 valid           60 transformer
#           60   ret_90  test           90 transformer
#           60   ret_90 valid           90 transformer
# [OK] Métricas guardadas en: /content/drive/MyDrive/neural_profit/metrics/seq2one_metrics/seq2one_transformer_metrics.parquet
#
# ================================================================================
# [20:27:45] TRANSFORMER | SEQ2ONE | WINDOW_SIZE=L90 | (L,F)=(90,36) | d_model=64 | head=4 | layers=2 | ff=128 | do=0.1 | wd=0.0001
# ================================================================================
#
# [20:27:45] [1/4] START target='delta_60' | L90
# [20:27:45]   [BUILD] Creando bundle (flatten_X=False) ...
# H60 Train: (409512, 90, 36) (409512,)
# H60 Valid: (87688, 90, 36) (87688,)
# H60 Test : (88140, 90, 36) (88140,)
# Scaler H60: StandardScaler
# [20:27:59]   [BUILD] OK | train X=(409512, 90, 36) y=(409512,) | dt=13.37s
# [20:27:59]   [LOADERS] Creando DataLoaders (3D) ...
# [20:28:06]   [LOADERS] OK | n(train/valid/test)=(409512/87688/88140) | dt=6.82s
# [20:28:06]   [TRAIN] Iniciando entrenamiento ...
# /tmp/ipython-input-3848978488.py:52: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(enc_layer, num_layers=num_layers)
# epoch 01 | train_loss=2253.817269 | valid_loss=1634.284490 | patience_left=5
# epoch 02 | train_loss=1670.204235 | valid_loss=1492.470525 | patience_left=5
# epoch 03 | train_loss=1444.833997 | valid_loss=1278.079034 | patience_left=5
# epoch 04 | train_loss=1346.011915 | valid_loss=1266.216223 | patience_left=5
# epoch 05 | train_loss=1283.309954 | valid_loss=1244.149555 | patience_left=5
# epoch 06 | train_loss=1235.178217 | valid_loss=1270.623396 | patience_left=4
# epoch 07 | train_loss=1194.760768 | valid_loss=1255.039237 | patience_left=3
# epoch 08 | train_loss=1167.347682 | valid_loss=1293.223711 | patience_left=2
# epoch 09 | train_loss=1134.348386 | valid_loss=1313.316351 | patience_left=1
# epoch 10 | train_loss=1111.349689 | valid_loss=1343.198175 | patience_left=0
# Early stopping: best_valid_loss=1244.149555 at epoch 5
# Modelo restaurado: epoch 5 | best_valid_loss=1244.149555
# [20:31:59]   [TRAIN] FIN entrenamiento | dt=233.94s
# [20:31:59]   [MEM] Liberando bundle['train'] y gc.collect() ...
# [20:32:00]   [PRED] Preparando loaders valid/test (batch_size_pred=32768) ...
# [20:32:02]   [PRED] Loaders OK | dt=2.05s
# [20:32:02]   [METRICS] Calculando métricas (valid/test) ...
# [20:32:07]   [METRICS] OK (valid/test) | dt=5.21s
# [20:32:07]   [DF] Agregando filas a la tabla ...
# [20:32:07]   [DF] OK | dt=0.01s
# [20:32:07] [1/4] DONE target='delta_60' | dt_total=261.56s
# [20:32:07]   [CLEAN] Liberando objetos ...
#
# [20:32:07] [2/4] START target='delta_90' | L90
# [20:32:07]   [BUILD] Creando bundle (flatten_X=False) ...
# H90 Train: (409512, 90, 36) (409512,)
# H90 Valid: (87688, 90, 36) (87688,)
# H90 Test : (88140, 90, 36) (88140,)
# Scaler H90: StandardScaler
# [20:32:19]   [BUILD] OK | train X=(409512, 90, 36) y=(409512,) | dt=12.15s
# [20:32:19]   [LOADERS] Creando DataLoaders (3D) ...
# [20:32:26]   [LOADERS] OK | n(train/valid/test)=(409512/87688/88140) | dt=6.82s
# [20:32:26]   [TRAIN] Iniciando entrenamiento ...
# /tmp/ipython-input-3848978488.py:52: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(enc_layer, num_layers=num_layers)
# epoch 01 | train_loss=3429.656845 | valid_loss=2700.447930 | patience_left=5
# epoch 02 | train_loss=2717.394517 | valid_loss=2380.835339 | patience_left=5
# epoch 03 | train_loss=2496.180932 | valid_loss=2374.773799 | patience_left=5
# epoch 04 | train_loss=2369.840877 | valid_loss=2451.414289 | patience_left=4
# epoch 05 | train_loss=2289.342479 | valid_loss=2476.210842 | patience_left=3
# epoch 06 | train_loss=2215.119240 | valid_loss=2317.511101 | patience_left=5
# epoch 07 | train_loss=2158.177074 | valid_loss=2359.170502 | patience_left=4
# epoch 08 | train_loss=2108.847273 | valid_loss=2342.726122 | patience_left=3
# epoch 09 | train_loss=2069.194794 | valid_loss=2526.868132 | patience_left=2
# epoch 10 | train_loss=2024.655167 | valid_loss=2663.803246 | patience_left=1
# epoch 11 | train_loss=1982.010336 | valid_loss=2851.469065 | patience_left=0
# Early stopping: best_valid_loss=2317.511101 at epoch 6
# Modelo restaurado: epoch 6 | best_valid_loss=2317.511101
# [20:36:43]   [TRAIN] FIN entrenamiento | dt=257.20s
# [20:36:43]   [MEM] Liberando bundle['train'] y gc.collect() ...
# [20:36:43]   [PRED] Preparando loaders valid/test (batch_size_pred=32768) ...
# [20:36:46]   [PRED] Loaders OK | dt=2.06s
# [20:36:46]   [METRICS] Calculando métricas (valid/test) ...
# [20:36:51]   [METRICS] OK (valid/test) | dt=5.21s
# [20:36:51]   [DF] Agregando filas a la tabla ...
# [20:36:51]   [DF] OK | dt=0.01s
# [20:36:51] [2/4] DONE target='delta_90' | dt_total=283.62s
# [20:36:51]   [CLEAN] Liberando objetos ...
#
# [20:36:51] [3/4] START target='ret_60' | L90
# [20:36:51]   [BUILD] Creando bundle (flatten_X=False) ...
# H60 Train: (409512, 90, 36) (409512,)
# H60 Valid: (87688, 90, 36) (87688,)
# H60 Test : (88140, 90, 36) (88140,)
# Scaler H60: StandardScaler
# [20:37:04]   [BUILD] OK | train X=(409512, 90, 36) y=(409512,) | dt=12.94s
# [20:37:04]   [LOADERS] Creando DataLoaders (3D) ...
# [20:37:11]   [LOADERS] OK | n(train/valid/test)=(409512/87688/88140) | dt=6.82s
# [20:37:11]   [TRAIN] Iniciando entrenamiento ...
# /tmp/ipython-input-3848978488.py:52: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(enc_layer, num_layers=num_layers)
# epoch 01 | train_loss=0.005817 | valid_loss=0.000061 | patience_left=5
# epoch 02 | train_loss=0.000168 | valid_loss=0.000040 | patience_left=5
# epoch 03 | train_loss=0.000125 | valid_loss=0.000028 | patience_left=5
# epoch 04 | train_loss=0.000103 | valid_loss=0.000016 | patience_left=5
# epoch 05 | train_loss=0.000087 | valid_loss=0.000021 | patience_left=4
# epoch 06 | train_loss=0.000075 | valid_loss=0.000013 | patience_left=5
# epoch 07 | train_loss=0.000067 | valid_loss=0.000021 | patience_left=4
# epoch 08 | train_loss=0.000062 | valid_loss=0.000009 | patience_left=5
# epoch 09 | train_loss=0.000057 | valid_loss=0.000021 | patience_left=4
# epoch 10 | train_loss=0.000054 | valid_loss=0.000022 | patience_left=3
# epoch 11 | train_loss=0.000047 | valid_loss=0.000010 | patience_left=2
# epoch 12 | train_loss=0.000048 | valid_loss=0.000008 | patience_left=5
# epoch 13 | train_loss=0.000042 | valid_loss=0.000009 | patience_left=4
# epoch 14 | train_loss=0.000042 | valid_loss=0.000018 | patience_left=3
# epoch 15 | train_loss=0.000040 | valid_loss=0.000007 | patience_left=5
# epoch 16 | train_loss=0.000039 | valid_loss=0.000017 | patience_left=4
# epoch 17 | train_loss=0.000033 | valid_loss=0.000027 | patience_left=3
# epoch 18 | train_loss=0.000032 | valid_loss=0.000011 | patience_left=2
# epoch 19 | train_loss=0.000032 | valid_loss=0.000006 | patience_left=5
# epoch 20 | train_loss=0.000031 | valid_loss=0.000015 | patience_left=4
# epoch 21 | train_loss=0.000029 | valid_loss=0.000006 | patience_left=3
# epoch 22 | train_loss=0.000029 | valid_loss=0.000011 | patience_left=2
# epoch 23 | train_loss=0.000026 | valid_loss=0.000009 | patience_left=1
# epoch 24 | train_loss=0.000025 | valid_loss=0.000006 | patience_left=0
# Early stopping: best_valid_loss=0.000006 at epoch 19
# Modelo restaurado: epoch 19 | best_valid_loss=0.000006
# [20:46:28]   [TRAIN] FIN entrenamiento | dt=557.71s
# [20:46:28]   [MEM] Liberando bundle['train'] y gc.collect() ...
# [20:46:29]   [PRED] Preparando loaders valid/test (batch_size_pred=32768) ...
# [20:46:31]   [PRED] Loaders OK | dt=2.05s
# [20:46:31]   [METRICS] Calculando métricas (valid/test) ...
# [20:46:36]   [METRICS] OK (valid/test) | dt=5.21s
# [20:46:36]   [DF] Agregando filas a la tabla ...
# [20:46:36]   [DF] OK | dt=0.01s
# [20:46:36] [3/4] DONE target='ret_60' | dt_total=584.93s
# [20:46:36]   [CLEAN] Liberando objetos ...
#
# [20:46:36] [4/4] START target='ret_90' | L90
# [20:46:36]   [BUILD] Creando bundle (flatten_X=False) ...
# H90 Train: (409512, 90, 36) (409512,)
# H90 Valid: (87688, 90, 36) (87688,)
# H90 Test : (88140, 90, 36) (88140,)
# Scaler H90: StandardScaler
# [20:46:49]   [BUILD] OK | train X=(409512, 90, 36) y=(409512,) | dt=12.56s
# [20:46:49]   [LOADERS] Creando DataLoaders (3D) ...
# [20:46:55]   [LOADERS] OK | n(train/valid/test)=(409512/87688/88140) | dt=6.84s
# [20:46:55]   [TRAIN] Iniciando entrenamiento ...
# /tmp/ipython-input-3848978488.py:52: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(enc_layer, num_layers=num_layers)
# epoch 01 | train_loss=0.018595 | valid_loss=0.000154 | patience_left=5
# epoch 02 | train_loss=0.000251 | valid_loss=0.000074 | patience_left=5
# epoch 03 | train_loss=0.000182 | valid_loss=0.000058 | patience_left=5
# epoch 04 | train_loss=0.000140 | valid_loss=0.000026 | patience_left=5
# epoch 05 | train_loss=0.000116 | valid_loss=0.000030 | patience_left=4
# epoch 06 | train_loss=0.000105 | valid_loss=0.000182 | patience_left=3
# epoch 07 | train_loss=0.000099 | valid_loss=0.000048 | patience_left=2
# epoch 08 | train_loss=0.000086 | valid_loss=0.000012 | patience_left=5
# epoch 09 | train_loss=0.000108 | valid_loss=0.000028 | patience_left=4
# epoch 10 | train_loss=0.000064 | valid_loss=0.000022 | patience_left=3
# epoch 11 | train_loss=0.000062 | valid_loss=0.000016 | patience_left=2
# epoch 12 | train_loss=0.000067 | valid_loss=0.000159 | patience_left=1
# epoch 13 | train_loss=0.000061 | valid_loss=0.000016 | patience_left=0
# Early stopping: best_valid_loss=0.000012 at epoch 8
# Modelo restaurado: epoch 8 | best_valid_loss=0.000012
# [20:51:59]   [TRAIN] FIN entrenamiento | dt=303.44s
# [20:51:59]   [MEM] Liberando bundle['train'] y gc.collect() ...
# [20:51:59]   [PRED] Preparando loaders valid/test (batch_size_pred=32768) ...
# [20:52:01]   [PRED] Loaders OK | dt=2.06s
# [20:52:01]   [METRICS] Calculando métricas (valid/test) ...
# [20:52:06]   [METRICS] OK (valid/test) | dt=5.21s
# [20:52:06]   [DF] Agregando filas a la tabla ...
# [20:52:06]   [DF] OK | dt=0.01s
# [20:52:06] [4/4] DONE target='ret_90' | dt_total=330.29s
# [20:52:06]   [CLEAN] Liberando objetos ...
#
# [20:52:07] [FINAL] Concatenando resultados ...
# [20:52:07] [FINAL] OK | rows=8 | dt_concat=0.00s | dt_total=1461.28s
#  window_size   target split  horizon_min       model
#           90 delta_60  test           60 transformer
#           90 delta_60 valid           60 transformer
#           90 delta_90  test           90 transformer
#           90 delta_90 valid           90 transformer
#           90   ret_60  test           60 transformer
#           90   ret_60 valid           60 transformer
#           90   ret_90  test           90 transformer
#           90   ret_90 valid           90 transformer
# [OK] Métricas guardadas en: /content/drive/MyDrive/neural_profit/metrics/seq2one_metrics/seq2one_transformer_metrics.parquet
#
# ================================================================================
# [20:52:07] TRANSFORMER | SEQ2ONE | WINDOW_SIZE=L120 | (L,F)=(120,36) | d_model=64 | head=4 | layers=2 | ff=128 | do=0.1 | wd=0.0001
# ================================================================================
#
# [20:52:07] [1/4] START target='delta_60' | L120
# [20:52:07]   [BUILD] Creando bundle (flatten_X=False) ...
# H60 Train: (382332, 120, 36) (382332,)
# H60 Valid: (81868, 120, 36) (81868,)
# H60 Test : (82290, 120, 36) (82290,)
# Scaler H60: StandardScaler
# [20:52:22]   [BUILD] OK | train X=(382332, 120, 36) y=(382332,) | dt=15.45s
# [20:52:22]   [LOADERS] Creando DataLoaders (3D) ...
# [20:52:31]   [LOADERS] OK | n(train/valid/test)=(382332/81868/82290) | dt=8.46s
# [20:52:31]   [TRAIN] Iniciando entrenamiento ...
# /tmp/ipython-input-3848978488.py:52: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(enc_layer, num_layers=num_layers)
# epoch 01 | train_loss=2307.792761 | valid_loss=1769.281647 | patience_left=5
# epoch 02 | train_loss=1818.784085 | valid_loss=1509.328628 | patience_left=5
# epoch 03 | train_loss=1525.067476 | valid_loss=1357.649797 | patience_left=5
# epoch 04 | train_loss=1391.530004 | valid_loss=1287.623825 | patience_left=5
# epoch 05 | train_loss=1337.211335 | valid_loss=1428.014953 | patience_left=4
# epoch 06 | train_loss=1295.465353 | valid_loss=1363.193230 | patience_left=3
# epoch 07 | train_loss=1262.749902 | valid_loss=1273.962353 | patience_left=5
# epoch 08 | train_loss=1234.710884 | valid_loss=1387.825321 | patience_left=4
# epoch 09 | train_loss=1208.733494 | valid_loss=1369.382143 | patience_left=3
# epoch 10 | train_loss=1184.570763 | valid_loss=1377.303731 | patience_left=2
# epoch 11 | train_loss=1162.133129 | valid_loss=1523.851127 | patience_left=1
# epoch 12 | train_loss=1138.289108 | valid_loss=1633.817970 | patience_left=0
# Early stopping: best_valid_loss=1273.962353 at epoch 7
# Modelo restaurado: epoch 7 | best_valid_loss=1273.962353
# [20:58:05]   [TRAIN] FIN entrenamiento | dt=334.35s
# [20:58:05]   [MEM] Liberando bundle['train'] y gc.collect() ...
# [20:58:05]   [PRED] Preparando loaders valid/test (batch_size_pred=32768) ...
# [20:58:08]   [PRED] Loaders OK | dt=2.55s
# [20:58:08]   [METRICS] Calculando métricas (valid/test) ...
# [20:58:14]   [METRICS] OK (valid/test) | dt=6.26s
# [20:58:14]   [DF] Agregando filas a la tabla ...
# [20:58:14]   [DF] OK | dt=0.01s
# [20:58:14] [1/4] DONE target='delta_60' | dt_total=367.27s
# [20:58:14]   [CLEAN] Liberando objetos ...
#
# [20:58:14] [2/4] START target='delta_90' | L120
# [20:58:14]   [BUILD] Creando bundle (flatten_X=False) ...
# H90 Train: (382332, 120, 36) (382332,)
# H90 Valid: (81868, 120, 36) (81868,)
# H90 Test : (82290, 120, 36) (82290,)
# Scaler H90: StandardScaler
# [20:58:29]   [BUILD] OK | train X=(382332, 120, 36) y=(382332,) | dt=14.83s
# [20:58:29]   [LOADERS] Creando DataLoaders (3D) ...
# [20:58:38]   [LOADERS] OK | n(train/valid/test)=(382332/81868/82290) | dt=8.56s
# [20:58:38]   [TRAIN] Iniciando entrenamiento ...
# /tmp/ipython-input-3848978488.py:52: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(enc_layer, num_layers=num_layers)
# epoch 01 | train_loss=3578.211820 | valid_loss=2845.379461 | patience_left=5
# epoch 02 | train_loss=2954.644233 | valid_loss=2618.335175 | patience_left=5
# epoch 03 | train_loss=2681.680531 | valid_loss=2606.267175 | patience_left=5
# epoch 04 | train_loss=2510.259999 | valid_loss=2383.820747 | patience_left=5
# epoch 05 | train_loss=2395.679118 | valid_loss=2500.751461 | patience_left=4
# epoch 06 | train_loss=2301.052974 | valid_loss=2607.506271 | patience_left=3
# epoch 07 | train_loss=2229.853943 | valid_loss=2625.821610 | patience_left=2
# epoch 08 | train_loss=2175.934124 | valid_loss=2740.911025 | patience_left=1
# epoch 09 | train_loss=2117.938368 | valid_loss=2821.667352 | patience_left=0
# Early stopping: best_valid_loss=2383.820747 at epoch 4
# Modelo restaurado: epoch 4 | best_valid_loss=2383.820747
# [21:02:49]   [TRAIN] FIN entrenamiento | dt=251.47s
# [21:02:49]   [MEM] Liberando bundle['train'] y gc.collect() ...
# [21:02:49]   [PRED] Preparando loaders valid/test (batch_size_pred=32768) ...
# [21:02:52]   [PRED] Loaders OK | dt=2.56s
# [21:02:52]   [METRICS] Calculando métricas (valid/test) ...
# [21:02:58]   [METRICS] OK (valid/test) | dt=5.84s
# [21:02:58]   [DF] Agregando filas a la tabla ...
# [21:02:58]   [DF] OK | dt=0.01s
# [21:02:58] [2/4] DONE target='delta_90' | dt_total=283.44s
# [21:02:58]   [CLEAN] Liberando objetos ...
#
# [21:02:58] [3/4] START target='ret_60' | L120
# [21:02:58]   [BUILD] Creando bundle (flatten_X=False) ...
# H60 Train: (382332, 120, 36) (382332,)
# H60 Valid: (81868, 120, 36) (81868,)
# H60 Test : (82290, 120, 36) (82290,)
# Scaler H60: StandardScaler
# [21:03:12]   [BUILD] OK | train X=(382332, 120, 36) y=(382332,) | dt=14.56s
# [21:03:12]   [LOADERS] Creando DataLoaders (3D) ...
# [21:03:21]   [LOADERS] OK | n(train/valid/test)=(382332/81868/82290) | dt=8.48s
# [21:03:21]   [TRAIN] Iniciando entrenamiento ...
# /tmp/ipython-input-3848978488.py:52: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(enc_layer, num_layers=num_layers)
# epoch 01 | train_loss=0.016221 | valid_loss=0.000096 | patience_left=5
# epoch 02 | train_loss=0.000180 | valid_loss=0.000108 | patience_left=4
# epoch 03 | train_loss=0.000131 | valid_loss=0.000111 | patience_left=3
# epoch 04 | train_loss=0.000103 | valid_loss=0.000036 | patience_left=5
# epoch 05 | train_loss=0.000086 | valid_loss=0.000053 | patience_left=4
# epoch 06 | train_loss=0.000073 | valid_loss=0.000053 | patience_left=3
# epoch 07 | train_loss=0.000065 | valid_loss=0.000028 | patience_left=5
# epoch 08 | train_loss=0.000062 | valid_loss=0.000028 | patience_left=4
# epoch 09 | train_loss=0.000057 | valid_loss=0.000021 | patience_left=5
# epoch 10 | train_loss=0.000057 | valid_loss=0.000013 | patience_left=5
# epoch 11 | train_loss=0.000054 | valid_loss=0.000020 | patience_left=4
# epoch 12 | train_loss=0.000048 | valid_loss=0.000009 | patience_left=5
# epoch 13 | train_loss=0.000047 | valid_loss=0.000008 | patience_left=5
# epoch 14 | train_loss=0.000045 | valid_loss=0.000009 | patience_left=4
# epoch 15 | train_loss=0.000047 | valid_loss=0.000018 | patience_left=3
# epoch 16 | train_loss=0.000038 | valid_loss=0.000013 | patience_left=2
# epoch 17 | train_loss=0.000044 | valid_loss=0.000016 | patience_left=1
# epoch 18 | train_loss=0.000036 | valid_loss=0.000009 | patience_left=0
# Early stopping: best_valid_loss=0.000008 at epoch 13
# Modelo restaurado: epoch 13 | best_valid_loss=0.000008
# [21:11:41]   [TRAIN] FIN entrenamiento | dt=499.76s
# [21:11:41]   [MEM] Liberando bundle['train'] y gc.collect() ...
# [21:11:41]   [PRED] Preparando loaders valid/test (batch_size_pred=32768) ...
# [21:11:43]   [PRED] Loaders OK | dt=2.57s
# [21:11:43]   [METRICS] Calculando métricas (valid/test) ...
# [21:11:49]   [METRICS] OK (valid/test) | dt=5.88s
# [21:11:49]   [DF] Agregando filas a la tabla ...
# [21:11:49]   [DF] OK | dt=0.01s
# [21:11:49] [3/4] DONE target='ret_60' | dt_total=531.44s
# [21:11:49]   [CLEAN] Liberando objetos ...
#
# [21:11:49] [4/4] START target='ret_90' | L120
# [21:11:49]   [BUILD] Creando bundle (flatten_X=False) ...
# H90 Train: (382332, 120, 36) (382332,)
# H90 Valid: (81868, 120, 36) (81868,)
# H90 Test : (82290, 120, 36) (82290,)
# Scaler H90: StandardScaler
# [21:12:04]   [BUILD] OK | train X=(382332, 120, 36) y=(382332,) | dt=14.38s
# [21:12:04]   [LOADERS] Creando DataLoaders (3D) ...
# [21:12:12]   [LOADERS] OK | n(train/valid/test)=(382332/81868/82290) | dt=8.51s
# [21:12:12]   [TRAIN] Iniciando entrenamiento ...
# /tmp/ipython-input-3848978488.py:52: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(enc_layer, num_layers=num_layers)
# epoch 01 | train_loss=0.015378 | valid_loss=0.000089 | patience_left=5
# epoch 02 | train_loss=0.000172 | valid_loss=0.000056 | patience_left=5
# epoch 03 | train_loss=0.000132 | valid_loss=0.000025 | patience_left=5
# epoch 04 | train_loss=0.000106 | valid_loss=0.000021 | patience_left=5
# epoch 05 | train_loss=0.000091 | valid_loss=0.000020 | patience_left=5
# epoch 06 | train_loss=0.000079 | valid_loss=0.000019 | patience_left=5
# epoch 07 | train_loss=0.000071 | valid_loss=0.000020 | patience_left=4
# epoch 08 | train_loss=0.000065 | valid_loss=0.000016 | patience_left=5
# epoch 09 | train_loss=0.000060 | valid_loss=0.000018 | patience_left=4
# epoch 10 | train_loss=0.000056 | valid_loss=0.000032 | patience_left=3
# epoch 11 | train_loss=0.000053 | valid_loss=0.000038 | patience_left=2
# epoch 12 | train_loss=0.000052 | valid_loss=0.000013 | patience_left=5
# epoch 13 | train_loss=0.000053 | valid_loss=0.000023 | patience_left=4
# epoch 14 | train_loss=0.000048 | valid_loss=0.000013 | patience_left=3
# epoch 15 | train_loss=0.000045 | valid_loss=0.000033 | patience_left=2
# epoch 16 | train_loss=0.000048 | valid_loss=0.000020 | patience_left=1
# epoch 17 | train_loss=0.000043 | valid_loss=0.000011 | patience_left=5
# epoch 18 | train_loss=0.000042 | valid_loss=0.000022 | patience_left=4
# epoch 19 | train_loss=0.000042 | valid_loss=0.000021 | patience_left=3
# epoch 20 | train_loss=0.000042 | valid_loss=0.000031 | patience_left=2
# epoch 21 | train_loss=0.000041 | valid_loss=0.000020 | patience_left=1
# epoch 22 | train_loss=0.000037 | valid_loss=0.000018 | patience_left=0
# Early stopping: best_valid_loss=0.000011 at epoch 17
# Modelo restaurado: epoch 17 | best_valid_loss=0.000011
# [21:22:23]   [TRAIN] FIN entrenamiento | dt=610.19s
# [21:22:23]   [MEM] Liberando bundle['train'] y gc.collect() ...
# [21:22:23]   [PRED] Preparando loaders valid/test (batch_size_pred=32768) ...
# [21:22:25]   [PRED] Loaders OK | dt=2.56s
# [21:22:25]   [METRICS] Calculando métricas (valid/test) ...
# [21:22:31]   [METRICS] OK (valid/test) | dt=5.80s
# [21:22:31]   [DF] Agregando filas a la tabla ...
# [21:22:31]   [DF] OK | dt=0.01s
# [21:22:31] [4/4] DONE target='ret_90' | dt_total=641.63s
# [21:22:31]   [CLEAN] Liberando objetos ...
#
# [21:22:31] [FINAL] Concatenando resultados ...
# [21:22:31] [FINAL] OK | rows=8 | dt_concat=0.00s | dt_total=1824.68s
#  window_size   target split  horizon_min       model
#          120 delta_60  test           60 transformer
#          120 delta_60 valid           60 transformer
#          120 delta_90  test           90 transformer
#          120 delta_90 valid           90 transformer
#          120   ret_60  test           60 transformer
#          120   ret_60 valid           60 transformer
#          120   ret_90  test           90 transformer
#          120   ret_90 valid           90 transformer
# [OK] Métricas guardadas en: /content/drive/MyDrive/neural_profit/metrics/seq2one_metrics/seq2one_transformer_metrics.parquet
#
# ================================================================================
# [21:22:31] TRANSFORMER | SEQ2ONE | WINDOW_SIZE=L180 | (L,F)=(180,36) | d_model=64 | head=4 | layers=2 | ff=128 | do=0.1 | wd=0.0001
# ================================================================================
#
# [21:22:31] [1/4] START target='delta_60' | L180
# [21:22:31]   [BUILD] Creando bundle (flatten_X=False) ...
# H60 Train: (327972, 180, 36) (327972,)
# H60 Valid: (70228, 180, 36) (70228,)
# H60 Test : (70590, 180, 36) (70590,)
# Scaler H60: StandardScaler
# [21:22:49]   [BUILD] OK | train X=(327972, 180, 36) y=(327972,) | dt=18.01s
# [21:22:49]   [LOADERS] Creando DataLoaders (3D) ...
# [21:23:00]   [LOADERS] OK | n(train/valid/test)=(327972/70228/70590) | dt=10.87s
# [21:23:00]   [TRAIN] Iniciando entrenamiento ...
# /tmp/ipython-input-3848978488.py:52: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(enc_layer, num_layers=num_layers)
# epoch 01 | train_loss=2289.015574 | valid_loss=1683.307902 | patience_left=5
# epoch 02 | train_loss=1752.313493 | valid_loss=1423.768105 | patience_left=5
# epoch 03 | train_loss=1424.697634 | valid_loss=1210.374553 | patience_left=5
# epoch 04 | train_loss=1283.030984 | valid_loss=1227.360292 | patience_left=4
# epoch 05 | train_loss=1217.808529 | valid_loss=1197.708920 | patience_left=5
# epoch 06 | train_loss=1163.370767 | valid_loss=1413.118740 | patience_left=4
# epoch 07 | train_loss=1127.142988 | valid_loss=1266.190760 | patience_left=3
# epoch 08 | train_loss=1099.603469 | valid_loss=1473.736678 | patience_left=2
# epoch 09 | train_loss=1071.948172 | valid_loss=1528.027093 | patience_left=1
# epoch 10 | train_loss=1039.507344 | valid_loss=2157.029348 | patience_left=0
# Early stopping: best_valid_loss=1197.708920 at epoch 5
# Modelo restaurado: epoch 5 | best_valid_loss=1197.708920
# [21:29:51]   [TRAIN] FIN entrenamiento | dt=410.84s
# [21:29:51]   [MEM] Liberando bundle['train'] y gc.collect() ...
# [21:29:51]   [PRED] Preparando loaders valid/test (batch_size_pred=32768) ...
# [21:29:55]   [PRED] Loaders OK | dt=3.28s
# [21:29:55]   [METRICS] Calculando métricas (valid/test) ...
# [21:30:02]   [METRICS] OK (valid/test) | dt=7.15s
# [21:30:02]   [DF] Agregando filas a la tabla ...
# [21:30:02]   [DF] OK | dt=0.01s
# [21:30:02] [1/4] DONE target='delta_60' | dt_total=450.34s
# [21:30:02]   [CLEAN] Liberando objetos ...
#
# [21:30:02] [2/4] START target='delta_90' | L180
# [21:30:02]   [BUILD] Creando bundle (flatten_X=False) ...
# H90 Train: (327972, 180, 36) (327972,)
# H90 Valid: (70228, 180, 36) (70228,)
# H90 Test : (70590, 180, 36) (70590,)
# Scaler H90: StandardScaler
# [21:30:20]   [BUILD] OK | train X=(327972, 180, 36) y=(327972,) | dt=17.57s
# [21:30:20]   [LOADERS] Creando DataLoaders (3D) ...
# [21:30:30]   [LOADERS] OK | n(train/valid/test)=(327972/70228/70590) | dt=10.89s
# [21:30:30]   [TRAIN] Iniciando entrenamiento ...
# /tmp/ipython-input-3848978488.py:52: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(enc_layer, num_layers=num_layers)
# epoch 01 | train_loss=3571.715178 | valid_loss=2799.892104 | patience_left=5
# epoch 02 | train_loss=2852.163797 | valid_loss=2397.082244 | patience_left=5
# epoch 03 | train_loss=2517.648373 | valid_loss=2369.643574 | patience_left=5
# epoch 04 | train_loss=2346.573814 | valid_loss=2495.156480 | patience_left=4
# epoch 05 | train_loss=2253.363715 | valid_loss=2320.589029 | patience_left=5
# epoch 06 | train_loss=2161.188099 | valid_loss=2458.551169 | patience_left=4
# epoch 07 | train_loss=2082.965277 | valid_loss=2621.199172 | patience_left=3
# epoch 08 | train_loss=2029.133512 | valid_loss=2646.081203 | patience_left=2
# epoch 09 | train_loss=1984.950486 | valid_loss=2523.773140 | patience_left=1
# epoch 10 | train_loss=1937.784688 | valid_loss=2731.970312 | patience_left=0
# Early stopping: best_valid_loss=2320.589029 at epoch 5
# Modelo restaurado: epoch 5 | best_valid_loss=2320.589029
# [21:37:21]   [TRAIN] FIN entrenamiento | dt=410.84s
# [21:37:21]   [MEM] Liberando bundle['train'] y gc.collect() ...
# [21:37:21]   [PRED] Preparando loaders valid/test (batch_size_pred=32768) ...
# [21:37:25]   [PRED] Loaders OK | dt=3.28s
# [21:37:25]   [METRICS] Calculando métricas (valid/test) ...
# [21:37:32]   [METRICS] OK (valid/test) | dt=7.10s
# [21:37:32]   [DF] Agregando filas a la tabla ...
# [21:37:32]   [DF] OK | dt=0.01s
# [21:37:32] [2/4] DONE target='delta_90' | dt_total=449.87s
# [21:37:32]   [CLEAN] Liberando objetos ...
#
# [21:37:32] [3/4] START target='ret_60' | L180
# [21:37:32]   [BUILD] Creando bundle (flatten_X=False) ...
# H60 Train: (327972, 180, 36) (327972,)
# H60 Valid: (70228, 180, 36) (70228,)
# H60 Test : (70590, 180, 36) (70590,)
# Scaler H60: StandardScaler
# [21:37:50]   [BUILD] OK | train X=(327972, 180, 36) y=(327972,) | dt=17.54s
# [21:37:50]   [LOADERS] Creando DataLoaders (3D) ...
# [21:38:00]   [LOADERS] OK | n(train/valid/test)=(327972/70228/70590) | dt=10.90s
# [21:38:00]   [TRAIN] Iniciando entrenamiento ...
# /tmp/ipython-input-3848978488.py:52: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(enc_layer, num_layers=num_layers)
# epoch 01 | train_loss=0.006953 | valid_loss=0.000096 | patience_left=5
# epoch 02 | train_loss=0.000210 | valid_loss=0.000048 | patience_left=5
# epoch 03 | train_loss=0.000160 | valid_loss=0.000054 | patience_left=4
# epoch 04 | train_loss=0.000127 | valid_loss=0.000023 | patience_left=5
# epoch 05 | train_loss=0.000106 | valid_loss=0.000064 | patience_left=4
# epoch 06 | train_loss=0.000091 | valid_loss=0.000027 | patience_left=3
# epoch 07 | train_loss=0.000083 | valid_loss=0.000087 | patience_left=2
# epoch 08 | train_loss=0.000078 | valid_loss=0.000134 | patience_left=1
# epoch 09 | train_loss=0.000078 | valid_loss=0.000160 | patience_left=0
# Early stopping: best_valid_loss=0.000023 at epoch 4
# Modelo restaurado: epoch 4 | best_valid_loss=0.000023
# [21:44:11]   [TRAIN] FIN entrenamiento | dt=370.12s
# [21:44:11]   [MEM] Liberando bundle['train'] y gc.collect() ...
# [21:44:11]   [PRED] Preparando loaders valid/test (batch_size_pred=32768) ...
# [21:44:14]   [PRED] Loaders OK | dt=3.28s
# [21:44:14]   [METRICS] Calculando métricas (valid/test) ...
# [21:44:21]   [METRICS] OK (valid/test) | dt=7.07s
# [21:44:21]   [DF] Agregando filas a la tabla ...
# [21:44:21]   [DF] OK | dt=0.01s
# [21:44:21] [3/4] DONE target='ret_60' | dt_total=409.11s
# [21:44:21]   [CLEAN] Liberando objetos ...
#
# [21:44:21] [4/4] START target='ret_90' | L180
# [21:44:21]   [BUILD] Creando bundle (flatten_X=False) ...
# H90 Train: (327972, 180, 36) (327972,)
# H90 Valid: (70228, 180, 36) (70228,)
# H90 Test : (70590, 180, 36) (70590,)
# Scaler H90: StandardScaler
# [21:44:39]   [BUILD] OK | train X=(327972, 180, 36) y=(327972,) | dt=17.64s
# [21:44:39]   [LOADERS] Creando DataLoaders (3D) ...
# [21:44:50]   [LOADERS] OK | n(train/valid/test)=(327972/70228/70590) | dt=10.89s
# [21:44:50]   [TRAIN] Iniciando entrenamiento ...
# /tmp/ipython-input-3848978488.py:52: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.encoder = nn.TransformerEncoder(enc_layer, num_layers=num_layers)
# epoch 01 | train_loss=0.007390 | valid_loss=0.000481 | patience_left=5
# epoch 02 | train_loss=0.000163 | valid_loss=0.000600 | patience_left=4
# epoch 03 | train_loss=0.000119 | valid_loss=0.000441 | patience_left=5
# epoch 04 | train_loss=0.000093 | valid_loss=0.000325 | patience_left=5
# epoch 05 | train_loss=0.000077 | valid_loss=0.000362 | patience_left=4
# epoch 06 | train_loss=0.000069 | valid_loss=0.000421 | patience_left=3
# epoch 07 | train_loss=0.000069 | valid_loss=0.000235 | patience_left=5
# epoch 08 | train_loss=0.000065 | valid_loss=0.000168 | patience_left=5
# epoch 09 | train_loss=0.000066 | valid_loss=0.000192 | patience_left=4
# epoch 10 | train_loss=0.000059 | valid_loss=0.000200 | patience_left=3
# epoch 11 | train_loss=0.000059 | valid_loss=0.000151 | patience_left=5
# epoch 12 | train_loss=0.000051 | valid_loss=0.000399 | patience_left=4
# epoch 13 | train_loss=0.000054 | valid_loss=0.000188 | patience_left=3
# epoch 14 | train_loss=0.000045 | valid_loss=0.000118 | patience_left=5
# epoch 15 | train_loss=0.000064 | valid_loss=0.000151 | patience_left=4
# epoch 16 | train_loss=0.000041 | valid_loss=0.000113 | patience_left=5
# epoch 17 | train_loss=0.000044 | valid_loss=0.000147 | patience_left=4
# epoch 18 | train_loss=0.000056 | valid_loss=0.000207 | patience_left=3
# epoch 19 | train_loss=0.000037 | valid_loss=0.000143 | patience_left=2
# epoch 20 | train_loss=0.000036 | valid_loss=0.000148 | patience_left=1
# epoch 21 | train_loss=0.000038 | valid_loss=0.000276 | patience_left=0
# Early stopping: best_valid_loss=0.000113 at epoch 16
# Modelo restaurado: epoch 16 | best_valid_loss=0.000113
# [21:59:08]   [TRAIN] FIN entrenamiento | dt=857.77s
# [21:59:08]   [MEM] Liberando bundle['train'] y gc.collect() ...
# [21:59:08]   [PRED] Preparando loaders valid/test (batch_size_pred=32768) ...
# [21:59:11]   [PRED] Loaders OK | dt=3.29s
# [21:59:11]   [METRICS] Calculando métricas (valid/test) ...
# [21:59:18]   [METRICS] OK (valid/test) | dt=7.15s
# [21:59:18]   [DF] Agregando filas a la tabla ...
# [21:59:18]   [DF] OK | dt=0.01s
# [21:59:18] [4/4] DONE target='ret_90' | dt_total=896.93s
# [21:59:18]   [CLEAN] Liberando objetos ...
#
# [21:59:19] [FINAL] Concatenando resultados ...
# [21:59:19] [FINAL] OK | rows=8 | dt_concat=0.00s | dt_total=2207.19s
#  window_size   target split  horizon_min       model
#          180 delta_60  test           60 transformer
#          180 delta_60 valid           60 transformer
#          180 delta_90  test           90 transformer
#          180 delta_90 valid           90 transformer
#          180   ret_60  test           60 transformer
#          180   ret_60 valid           60 transformer
#          180   ret_90  test           90 transformer
#          180   ret_90 valid           90 transformer
# [OK] Métricas guardadas en: /content/drive/MyDrive/neural_profit/metrics/seq2one_metrics/seq2one_transformer_metrics.parquet

# %%
save_seq2one_metrics(
    df_transformer_all_sizes,
    name="transformer"
)
# Out:
# [OK] Métricas guardadas en: /content/drive/MyDrive/neural_profit/metrics/seq2one_metrics/seq2one_transformer_metrics.parquet
# PosixPath('/content/drive/MyDrive/neural_profit/metrics/seq2one_metrics/seq2one_transformer_metrics.parquet')

# %%
df_transformer_all_sizes
# Out:
#           model  split  window_size    target  horizon_min        MAE  \
# 0   transformer   test           30  delta_60           60  46.236110
# 1   transformer  valid           30  delta_60           60  28.447738
# 2   transformer   test           30  delta_90           90  57.645429
# 3   transformer  valid           30  delta_90           90  35.875813
# 4   transformer   test           30    ret_60           60   0.003202
# 5   transformer  valid           30    ret_60           60   0.002261
# 6   transformer   test           30    ret_90           90   0.004092
# 7   transformer  valid           30    ret_90           90   0.003020
# 8   transformer   test           60  delta_60           60  46.705269
# 9   transformer  valid           60  delta_60           60  25.525815
# 10  transformer   test           60  delta_90           90  57.564732
# 11  transformer  valid           60  delta_90           90  34.308975
# 12  transformer   test           60    ret_60           60   0.004160
# 13  transformer  valid           60    ret_60           60   0.002450
# 14  transformer   test           60    ret_90           90   0.003227
# 15  transformer  valid           60    ret_90           90   0.002230
# 16  transformer   test           90  delta_60           60  37.112484
# 17  transformer  valid           90  delta_60           60  21.960556
# 18  transformer   test           90  delta_90           90  50.591780
# 19  transformer  valid           90  delta_90           90  30.810244
# 20  transformer   test           90    ret_60           60   0.002841
# 21  transformer  valid           90    ret_60           60   0.001729
# 22  transformer   test           90    ret_90           90   0.003511
# 23  transformer  valid           90    ret_90           90   0.002563
# 24  transformer   test          120  delta_60           60  36.410344
# 25  transformer  valid          120  delta_60           60  22.154948
# 26  transformer   test          120  delta_90           90  48.823340
# 27  transformer  valid          120  delta_90           90  31.617258
# 28  transformer   test          120    ret_60           60   0.003970
# 29  transformer  valid          120    ret_60           60   0.002117
# 30  transformer   test          120    ret_90           90   0.003288
# 31  transformer  valid          120    ret_90           90   0.002398
# 32  transformer   test          180  delta_60           60  36.447433
# 33  transformer  valid          180  delta_60           60  21.494710
# 34  transformer   test          180  delta_90           90  49.885593
# 35  transformer  valid          180  delta_90           90  31.532164
# 36  transformer   test          180    ret_60           60   0.005443
# 37  transformer  valid          180    ret_60           60   0.003852
# 38  transformer   test          180    ret_90           90   0.009241
# 39  transformer  valid          180    ret_90           90   0.010126
#
#          RMSE        R2        DA  d_model  nhead  num_layers  dim_ff  \
# 0   74.636551  0.168560  0.645634       64      4           2     128
# 1   41.196097  0.297724  0.660466       64      4           2     128
# 2   93.981765  0.157045  0.644381       64      4           2     128
# 3   52.437134  0.273773  0.658311       64      4           2     128
# 4    0.005072 -0.451118  0.513453       64      4           2     128
# 5    0.003005 -0.220678  0.526014       64      4           2     128
# 6    0.008756 -1.758403  0.524363       64      4           2     128
# 7    0.003885 -0.302365  0.527507       64      4           2     128
# 8   76.101668  0.142876  0.686346       64      4           2     128
# 9   39.339534  0.363398  0.713213       64      4           2     128
# 10  90.977825  0.195689  0.656985       64      4           2     128
# 11  51.259851  0.309020  0.687362       64      4           2     128
# 12   0.011002 -5.756404  0.541288       64      4           2     128
# 13   0.003312 -0.472759  0.554930       64      4           2     128
# 14   0.006247 -0.439008  0.624305       64      4           2     128
# 15   0.003140  0.153667  0.638918       64      4           2     128
# 16  66.567553  0.340788  0.731175       64      4           2     128
# 17  35.272504  0.476141  0.746148       64      4           2     128
# 18  83.090415  0.330366  0.711179       64      4           2     128
# 19  48.140534  0.381994  0.728020       64      4           2     128
# 20   0.006312 -1.231974  0.634197       64      4           2     128
# 21   0.002454  0.175027  0.638132       64      4           2     128
# 22   0.006623 -0.611926  0.582415       64      4           2     128
# 23   0.003487 -0.054328  0.605229       64      4           2     128
# 24  63.578248  0.396531  0.722886       64      4           2     128
# 25  35.692609  0.449670  0.744470       64      4           2     128
# 26  82.784002  0.337327  0.715084       64      4           2     128
# 27  48.824387  0.355949  0.717203       64      4           2     128
# 28   0.006723 -1.536273  0.545615       64      4           2     128
# 29   0.002854 -0.140876  0.598079       64      4           2     128
# 30   0.006712 -0.649095  0.620481       64      4           2     128
# 31   0.003292  0.050249  0.600461       64      4           2     128
# 32  64.587958  0.388957  0.738173       64      4           2     128
# 33  34.607932  0.472837  0.743578       64      4           2     128
# 34  83.023449  0.341823  0.719172       64      4           2     128
# 35  48.172492  0.369248  0.716830       64      4           2     128
# 36   0.008678 -3.120200  0.530955       64      4           2     128
# 37   0.004837 -2.334733  0.554008       64      4           2     128
# 38   0.011280 -3.576115  0.534092       64      4           2     128
# 39   0.010609 -8.929236  0.554627       64      4           2     128
#
#     dropout pooling     lr  weight_decay best_valid_mse  epochs_ran final_lr
# 0       0.1    mean  0.001        0.0001           None          10     None
# 1       0.1    mean  0.001        0.0001           None          10     None
# 2       0.1    mean  0.001        0.0001           None          10     None
# 3       0.1    mean  0.001        0.0001           None          10     None
# 4       0.1    mean  0.001        0.0001           None          15     None
# 5       0.1    mean  0.001        0.0001           None          15     None
# 6       0.1    mean  0.001        0.0001           None          11     None
# 7       0.1    mean  0.001        0.0001           None          11     None
# 8       0.1    mean  0.001        0.0001           None          11     None
# 9       0.1    mean  0.001        0.0001           None          11     None
# 10      0.1    mean  0.001        0.0001           None          10     None
# 11      0.1    mean  0.001        0.0001           None          10     None
# 12      0.1    mean  0.001        0.0001           None          13     None
# 13      0.1    mean  0.001        0.0001           None          13     None
# 14      0.1    mean  0.001        0.0001           None          30     None
# 15      0.1    mean  0.001        0.0001           None          30     None
# 16      0.1    mean  0.001        0.0001           None          10     None
# 17      0.1    mean  0.001        0.0001           None          10     None
# 18      0.1    mean  0.001        0.0001           None          11     None
# 19      0.1    mean  0.001        0.0001           None          11     None
# 20      0.1    mean  0.001        0.0001           None          24     None
# 21      0.1    mean  0.001        0.0001           None          24     None
# 22      0.1    mean  0.001        0.0001           None          13     None
# 23      0.1    mean  0.001        0.0001           None          13     None
# 24      0.1    mean  0.001        0.0001           None          12     None
# 25      0.1    mean  0.001        0.0001           None          12     None
# 26      0.1    mean  0.001        0.0001           None           9     None
# 27      0.1    mean  0.001        0.0001           None           9     None
# 28      0.1    mean  0.001        0.0001           None          18     None
# 29      0.1    mean  0.001        0.0001           None          18     None
# 30      0.1    mean  0.001        0.0001           None          22     None
# 31      0.1    mean  0.001        0.0001           None          22     None
# 32      0.1    mean  0.001        0.0001           None          10     None
# 33      0.1    mean  0.001        0.0001           None          10     None
# 34      0.1    mean  0.001        0.0001           None          10     None
# 35      0.1    mean  0.001        0.0001           None          10     None
# 36      0.1    mean  0.001        0.0001           None           9     None
# 37      0.1    mean  0.001        0.0001           None           9     None
# 38      0.1    mean  0.001        0.0001           None          21     None
# 39      0.1    mean  0.001        0.0001           None          21     None
